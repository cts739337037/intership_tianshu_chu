# %%
import pandas as pd
import numpy as np
import datetime
from pandas_datareader import data#Download data from the web via this package
# %matplotlib inline

# %%
start = '2017-01-01'
end = '2019-01-01'
GSPC_index = data.DataReader("^GSPC","yahoo",start,end)#Choose the data that Exercise 3 asked
print(GSPC_index.head())#show data form
GSPC_index.shape
# Out:
#                    High          Low         Open        Close      Volume  \
# Date
# 2017-01-03  2263.879883  2245.129883  2251.570068  2257.830078  3770530000
# 2017-01-04  2272.820068  2261.600098  2261.600098  2270.750000  3764890000
# 2017-01-05  2271.500000  2260.449951  2268.179932  2269.000000  3761820000
# 2017-01-06  2282.100098  2264.060059  2271.139893  2276.979980  3339890000
# 2017-01-09  2275.489990  2268.899902  2273.590088  2268.899902  3217610000
#
#               Adj Close
# Date
# 2017-01-03  2257.830078
# 2017-01-04  2270.750000
# 2017-01-05  2269.000000
# 2017-01-06  2276.979980
# 2017-01-09  2268.899902
# (502, 6)

# %%
GSPC_index.isnull().sum().sort_values(ascending = False)
# Out:
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Adj Close    0
# dtype: int64

# %%
GSPC_index2 = pd.DataFrame(GSPC_index.values.T, index=GSPC_index.columns, columns=GSPC_index.index)
GSPC_index2
# Out:
# Date         2017-01-03    2017-01-04    2017-01-05    2017-01-06  \
# High       2.263880e+03  2.272820e+03  2.271500e+03  2.282100e+03
# Low        2.245130e+03  2.261600e+03  2.260450e+03  2.264060e+03
# Open       2.251570e+03  2.261600e+03  2.268180e+03  2.271140e+03
# Close      2.257830e+03  2.270750e+03  2.269000e+03  2.276980e+03
# Volume     3.770530e+09  3.764890e+09  3.761820e+09  3.339890e+09
# Adj Close  2.257830e+03  2.270750e+03  2.269000e+03  2.276980e+03
#
# Date         2017-01-09    2017-01-10    2017-01-11    2017-01-12  \
# High       2.275490e+03  2.279270e+03  2.275320e+03  2.271780e+03
# Low        2.268900e+03  2.265270e+03  2.260830e+03  2.254250e+03
# Open       2.273590e+03  2.269720e+03  2.268600e+03  2.271140e+03
# Close      2.268900e+03  2.268900e+03  2.275320e+03  2.270440e+03
# Volume     3.217610e+09  3.638790e+09  3.620410e+09  3.462130e+09
# Adj Close  2.268900e+03  2.268900e+03  2.275320e+03  2.270440e+03
#
# Date         2017-01-13    2017-01-17  ...    2018-12-17    2018-12-18  \
# High       2.278680e+03  2.272080e+03  ...  2.601130e+03  2.573990e+03
# Low        2.271510e+03  2.262810e+03  ...  2.530540e+03  2.528710e+03
# Open       2.272740e+03  2.269140e+03  ...  2.590750e+03  2.559900e+03
# Close      2.274640e+03  2.267890e+03  ...  2.545940e+03  2.546160e+03
# Volume     3.081270e+09  3.584990e+09  ...  4.616350e+09  4.470880e+09
# Adj Close  2.274640e+03  2.267890e+03  ...  2.545940e+03  2.546160e+03
#
# Date         2018-12-19    2018-12-20    2018-12-21    2018-12-24  \
# High       2.585290e+03  2.509630e+03  2.504410e+03  2.410340e+03
# Low        2.488960e+03  2.441180e+03  2.408550e+03  2.351100e+03
# Open       2.547050e+03  2.496770e+03  2.465380e+03  2.400560e+03
# Close      2.506960e+03  2.467420e+03  2.416620e+03  2.351100e+03
# Volume     5.127940e+09  5.585780e+09  7.609010e+09  2.613930e+09
# Adj Close  2.506960e+03  2.467420e+03  2.416620e+03  2.351100e+03
#
# Date         2018-12-26    2018-12-27    2018-12-28    2018-12-31
# High       2.467760e+03  2.489100e+03  2.520270e+03  2.509240e+03
# Low        2.346580e+03  2.397940e+03  2.472890e+03  2.482820e+03
# Open       2.363120e+03  2.442500e+03  2.498770e+03  2.498940e+03
# Close      2.467700e+03  2.488830e+03  2.485740e+03  2.506850e+03
# Volume     4.233990e+09  4.096610e+09  3.702620e+09  3.442870e+09
# Adj Close  2.467700e+03  2.488830e+03  2.485740e+03  2.506850e+03
#
# [6 rows x 502 columns]

# %%
GSPC_index2_close = pd.DataFrame(GSPC_index2.iloc[3])
GSPC_index2_close
# Out:
#                   Close
# Date
# 2017-01-03  2257.830078
# 2017-01-04  2270.750000
# 2017-01-05  2269.000000
# 2017-01-06  2276.979980
# 2017-01-09  2268.899902
# ...                 ...
# 2018-12-24  2351.100098
# 2018-12-26  2467.699951
# 2018-12-27  2488.830078
# 2018-12-28  2485.739990
# 2018-12-31  2506.850098
#
# [502 rows x 1 columns]

# %%
GSPC_index2_close.to_csv('GSPC_index_close.csv')
