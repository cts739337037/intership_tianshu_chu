# %%
import pandas as pd
import numpy as np
import datetime
from pandas_datareader import data#Download data from the web via this package
# %matplotlib inline

# %%
start = '2019-01-01'
end = '2022-01-01'
GSPC_index = data.DataReader("^GSPC","yahoo",start,end)#Choose the data that Exercise 3 asked
print(GSPC_index.head())#show data form
GSPC_index.shape
# Out:
#                    High          Low         Open        Close      Volume  \
# Date
# 2019-01-02  2519.489990  2467.469971  2476.959961  2510.030029  3733160000
# 2019-01-03  2493.139893  2443.959961  2491.919922  2447.889893  3822860000
# 2019-01-04  2538.070068  2474.330078  2474.330078  2531.939941  4213410000
# 2019-01-07  2566.159912  2524.560059  2535.610107  2549.689941  4104710000
# 2019-01-08  2579.820068  2547.560059  2568.110107  2574.409912  4083030000
#
#               Adj Close
# Date
# 2019-01-02  2510.030029
# 2019-01-03  2447.889893
# 2019-01-04  2531.939941
# 2019-01-07  2549.689941
# 2019-01-08  2574.409912
# (757, 6)

# %%
GSPC_index.isnull().sum().sort_values(ascending = False)
# Out:
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Adj Close    0
# dtype: int64

# %%
GSPC_index2 = pd.DataFrame(GSPC_index.values.T, index=GSPC_index.columns, columns=GSPC_index.index)
GSPC_index2
# Out:
# Date         2019-01-02    2019-01-03    2019-01-04    2019-01-07  \
# High       2.519490e+03  2.493140e+03  2.538070e+03  2.566160e+03
# Low        2.467470e+03  2.443960e+03  2.474330e+03  2.524560e+03
# Open       2.476960e+03  2.491920e+03  2.474330e+03  2.535610e+03
# Close      2.510030e+03  2.447890e+03  2.531940e+03  2.549690e+03
# Volume     3.733160e+09  3.822860e+09  4.213410e+09  4.104710e+09
# Adj Close  2.510030e+03  2.447890e+03  2.531940e+03  2.549690e+03
#
# Date         2019-01-08    2019-01-09    2019-01-10    2019-01-11  \
# High       2.579820e+03  2.595320e+03  2.597820e+03  2.596270e+03
# Low        2.547560e+03  2.568890e+03  2.562020e+03  2.577400e+03
# Open       2.568110e+03  2.580000e+03  2.573510e+03  2.588110e+03
# Close      2.574410e+03  2.584960e+03  2.596640e+03  2.596260e+03
# Volume     4.083030e+09  4.052480e+09  3.704500e+09  3.434490e+09
# Adj Close  2.574410e+03  2.584960e+03  2.596640e+03  2.596260e+03
#
# Date         2019-01-14    2019-01-15  ...    2021-12-17    2021-12-20  \
# High       2.589320e+03  2.613080e+03  ...  4.666700e+03  4.587900e+03
# Low        2.570410e+03  2.585100e+03  ...  4.600220e+03  4.531100e+03
# Open       2.580310e+03  2.585100e+03  ...  4.652500e+03  4.587900e+03
# Close      2.582610e+03  2.610300e+03  ...  4.620640e+03  4.568020e+03
# Volume     3.664450e+09  3.572330e+09  ...  5.609780e+09  3.395780e+09
# Adj Close  2.582610e+03  2.610300e+03  ...  4.620640e+03  4.568020e+03
#
# Date         2021-12-21    2021-12-22    2021-12-23    2021-12-27  \
# High       4.651140e+03  4.697670e+03  4.740740e+03  4.791490e+03
# Low        4.583160e+03  4.645530e+03  4.703960e+03  4.733990e+03
# Open       4.594960e+03  4.650360e+03  4.703960e+03  4.733990e+03
# Close      4.649230e+03  4.696560e+03  4.725790e+03  4.791190e+03
# Volume     2.564370e+09  2.439570e+09  2.194630e+09  2.264120e+09
# Adj Close  4.649230e+03  4.696560e+03  4.725790e+03  4.791190e+03
#
# Date         2021-12-28    2021-12-29    2021-12-30    2021-12-31
# High       4.807020e+03  4.804060e+03  4.808930e+03  4.786830e+03
# Low        4.780040e+03  4.778080e+03  4.775330e+03  4.765750e+03
# Open       4.795490e+03  4.788640e+03  4.794230e+03  4.775210e+03
# Close      4.786350e+03  4.793060e+03  4.778730e+03  4.766180e+03
# Volume     2.217050e+09  2.369370e+09  2.390990e+09  2.446190e+09
# Adj Close  4.786350e+03  4.793060e+03  4.778730e+03  4.766180e+03
#
# [6 rows x 757 columns]

# %%
GSPC_index2_close = pd.DataFrame(GSPC_index2.iloc[3])
GSPC_index2_close
# Out:
#                   Close
# Date
# 2019-01-02  2510.030029
# 2019-01-03  2447.889893
# 2019-01-04  2531.939941
# 2019-01-07  2549.689941
# 2019-01-08  2574.409912
# ...                 ...
# 2021-12-27  4791.189941
# 2021-12-28  4786.350098
# 2021-12-29  4793.060059
# 2021-12-30  4778.729980
# 2021-12-31  4766.180176
#
# [757 rows x 1 columns]

# %%
GSPC_index2_close.to_csv('GSPC_index_close_test_201922.csv')
