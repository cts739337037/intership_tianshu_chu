# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 

import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"  
import keras
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC
from sklearn.metrics import f1_score
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Conv1D, Dropout,  Input, Layer
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers.schedules import LearningRateSchedule
from tensorflow.keras.optimizers import Adam


from pandas_datareader import data

from PyEMD import EMD,EEMD,CEEMDAN,Visualisation

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
start = '2017-01-01'
end = '2019-01-01'
GSPC = pd.DataFrame(data.DataReader("^GSPC","yahoo",start,end)['Adj Close'])#Choose the data
print(GSPC)
GSPC.isnull().sum().sort_values(ascending = False)
# Out:
#               Adj Close
# Date
# 2017-01-03  2257.830078
# 2017-01-04  2270.750000
# 2017-01-05  2269.000000
# 2017-01-06  2276.979980
# 2017-01-09  2268.899902
# ...                 ...
# 2018-12-24  2351.100098
# 2018-12-26  2467.699951
# 2018-12-27  2488.830078
# 2018-12-28  2485.739990
# 2018-12-31  2506.850098
#
# [502 rows x 1 columns]
# Adj Close    0
# dtype: int64

# %%
def emd_calculate(data,emdtype=EMD, plots=True):
    EMD_C=emdtype()#EMD,EEMD,CEEMDAN
    imfs = EMD_C(data.values.reshape(len(data)))
        
    if plots:
        series_index = data.index
        fig = plt.figure(figsize=(16,2*len(imfs)))
        plt.subplot(1+len(imfs), 1, 1 )
        plt.plot(series_index, data, color='#0070C0') #F27F19 orange #0070C0 blue
        plt.ylabel('Original data')

        # Plot IMFs
        for i in range(len(imfs)):
            plt.subplot(1 +len(imfs),1,2 + i)
            plt.plot(series_index, imfs[i, :], color='#F27F19')
            plt.ylabel('IMF'+str(i))
        plt.show()
    imfs=pd.DataFrame(imfs,columns=data.index)
    return imfs

# %%
def create_noisy(data,percentage=0.5,size=10):
    data_noisy = pd.DataFrame()
    window=int(len(data) * percentage)
    for i in range(window,len(data),size):
        data_noisy= pd.concat([data_noisy,pd.Series(data.values[i-window:i,0])], axis=1)
    return data_noisy.T

# %%
def create_pure(data,percentage=0.5,size=10,emdtype=EMD,emdsum=1):
    data_pure = pd.DataFrame()
    window=int(len(data) * percentage)
    for i in range(window,len(data),size):
        temp=emd_calculate(data[i-window:i],plots=False,emdtype=emdtype)
        temp_1= reconstruction(temp)
        data_pure= pd.concat([data_pure,pd.Series(temp_1.values[emdsum,:])], axis=1)
    return data_pure.T

# %%
def reconstruction(data_emd):
    reconstruction = pd.DataFrame()
    for i in range(len(data_emd)):
        reconstruction['sum'+str(i)]=data_emd.iloc[i:,:].sum(axis=0)
    return reconstruction.T

# %%
GSPC_pure=create_pure(GSPC)

GSPC_noisy=create_noisy(GSPC)

# %%
mm_t_g = MinMaxScaler()
noise_mm = mm_t_g.fit_transform(GSPC_noisy.T).T
prue_mm=mm_t_g.fit_transform(GSPC_pure.T).T
print(prue_mm.shape)
print(noise_mm.shape)
# Out:
# (26, 251)
# (26, 251)

# %%
X_train_mm = np.asarray(noise_mm)
X_train_mm=X_train_mm.reshape((len(X_train_mm), len(X_train_mm[0]), 1))
Y_train_mm = np.asarray(prue_mm)
Y_train_mm=Y_train_mm.reshape((len(Y_train_mm), len(Y_train_mm[0]), 1))
X_train_mm, X_val_mm, Y_train_mm, Y_val_mm = train_test_split(X_train_mm, Y_train_mm, test_size=0.2,random_state=0,shuffle=False)

# %%
keras.backend.clear_session()

# %%
def set_model_encoding_mm():
    model = Sequential()
    model.add(Conv1D(128, kernel_size=3, activation='relu', padding='same',input_shape=(None, 1)))
    model.add(Conv1D(64, kernel_size=3,activation='relu',padding='same'))
    model.add(Conv1D(64, kernel_size=3, activation='relu', padding='same'))
    model.add(Conv1D(128, kernel_size=3,activation='relu',padding='same'))
    model.add(Conv1D(1,kernel_size=1,activation='sigmoid', padding='same'))
    model.compile(optimizer='adam' , loss='mse', metrics=['mae'])
    
    return model
modelen_mm = set_model_encoding_mm()
modelen_mm.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, None, 128)         512
#
#  conv1d_1 (Conv1D)           (None, None, 64)          24640
#
#  conv1d_2 (Conv1D)           (None, None, 64)          12352
#
#  conv1d_3 (Conv1D)           (None, None, 128)         24704
#
#  conv1d_4 (Conv1D)           (None, None, 1)           129
#
# =================================================================
# Total params: 62,337
# Trainable params: 62,337
# Non-trainable params: 0
# _________________________________________________________________

# %%
callback = EarlyStopping(monitor='loss', patience=10)
history_mm = modelen_mm.fit(X_train_mm, Y_train_mm, validation_data = (X_val_mm, Y_val_mm), epochs=400, batch_size=32, verbose=1, callbacks=[callback])
# Out:
# Epoch 1/400
# 1/1 [==============================] - 1s 569ms/step - loss: 0.0738 - mae: 0.2314 - val_loss: 0.0672 - val_mae: 0.2167
# Epoch 2/400
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0726 - mae: 0.2294 - val_loss: 0.0661 - val_mae: 0.2150
# Epoch 3/400
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0715 - mae: 0.2277 - val_loss: 0.0646 - val_mae: 0.2127
# Epoch 4/400
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0702 - mae: 0.2255 - val_loss: 0.0629 - val_mae: 0.2098
# Epoch 5/400
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0686 - mae: 0.2228 - val_loss: 0.0608 - val_mae: 0.2065
# Epoch 6/400
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0667 - mae: 0.2196 - val_loss: 0.0584 - val_mae: 0.2023
# Epoch 7/400
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0645 - mae: 0.2157 - val_loss: 0.0555 - val_mae: 0.1972
# Epoch 8/400
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0619 - mae: 0.2109 - val_loss: 0.0522 - val_mae: 0.1911
# Epoch 9/400
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0589 - mae: 0.2051 - val_loss: 0.0488 - val_mae: 0.1844
# Epoch 10/400
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0557 - mae: 0.1987 - val_loss: 0.0453 - val_mae: 0.1775
# Epoch 11/400
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0523 - mae: 0.1917 - val_loss: 0.0419 - val_mae: 0.1704
# Epoch 12/400
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0487 - mae: 0.1841 - val_loss: 0.0383 - val_mae: 0.1627
# Epoch 13/400
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0449 - mae: 0.1756 - val_loss: 0.0343 - val_mae: 0.1531
# Epoch 14/400
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0406 - mae: 0.1655 - val_loss: 0.0300 - val_mae: 0.1418
# Epoch 15/400
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0361 - mae: 0.1541 - val_loss: 0.0255 - val_mae: 0.1289
# Epoch 16/400
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0315 - mae: 0.1413 - val_loss: 0.0211 - val_mae: 0.1151
# Epoch 17/400
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0266 - mae: 0.1263 - val_loss: 0.0171 - val_mae: 0.1022
# Epoch 18/400
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0218 - mae: 0.1098 - val_loss: 0.0133 - val_mae: 0.0888
# Epoch 19/400
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0173 - mae: 0.0925 - val_loss: 0.0093 - val_mae: 0.0673
# Epoch 20/400
# 1/1 [==============================] - 0s 49ms/step - loss: 0.0132 - mae: 0.0715 - val_loss: 0.0067 - val_mae: 0.0542
# Epoch 21/400
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0101 - mae: 0.0612 - val_loss: 0.0063 - val_mae: 0.0589
# Epoch 22/400
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0081 - mae: 0.0603 - val_loss: 0.0050 - val_mae: 0.0540
# Epoch 23/400
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0070 - mae: 0.0618 - val_loss: 0.0055 - val_mae: 0.0605
# Epoch 24/400
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0069 - mae: 0.0673 - val_loss: 0.0072 - val_mae: 0.0712
# Epoch 25/400
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0074 - mae: 0.0743 - val_loss: 0.0064 - val_mae: 0.0691
# Epoch 26/400
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0079 - mae: 0.0751 - val_loss: 0.0077 - val_mae: 0.0757
# Epoch 27/400
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0078 - mae: 0.0774 - val_loss: 0.0069 - val_mae: 0.0719
# Epoch 28/400
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0074 - mae: 0.0746 - val_loss: 0.0058 - val_mae: 0.0654
# Epoch 29/400
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0066 - mae: 0.0697 - val_loss: 0.0063 - val_mae: 0.0666
# Epoch 30/400
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0056 - mae: 0.0659 - val_loss: 0.0038 - val_mae: 0.0520
# Epoch 31/400
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0044 - mae: 0.0563 - val_loss: 0.0043 - val_mae: 0.0542
# Epoch 32/400
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0033 - mae: 0.0496 - val_loss: 0.0026 - val_mae: 0.0420
# Epoch 33/400
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0024 - mae: 0.0399 - val_loss: 0.0032 - val_mae: 0.0461
# Epoch 34/400
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0018 - mae: 0.0334 - val_loss: 0.0023 - val_mae: 0.0372
# Epoch 35/400
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0016 - mae: 0.0289 - val_loss: 0.0045 - val_mae: 0.0570
# Epoch 36/400
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0019 - mae: 0.0321 - val_loss: 0.0030 - val_mae: 0.0421
# Epoch 37/400
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0034 - mae: 0.0487 - val_loss: 0.0104 - val_mae: 0.0924
# Epoch 38/400
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0051 - mae: 0.0657 - val_loss: 0.0036 - val_mae: 0.0486
# Epoch 39/400
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0018 - mae: 0.0288 - val_loss: 0.0047 - val_mae: 0.0552
# Epoch 40/400
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0053 - mae: 0.0621 - val_loss: 0.0058 - val_mae: 0.0670
# Epoch 41/400
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0025 - mae: 0.0416 - val_loss: 0.0088 - val_mae: 0.0844
# Epoch 42/400
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0040 - mae: 0.0571 - val_loss: 0.0027 - val_mae: 0.0392
# Epoch 43/400
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0016 - mae: 0.0275 - val_loss: 0.0032 - val_mae: 0.0442
# Epoch 44/400
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0036 - mae: 0.0515 - val_loss: 0.0037 - val_mae: 0.0510
# Epoch 45/400
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0013 - mae: 0.0263 - val_loss: 0.0075 - val_mae: 0.0759
# Epoch 46/400
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0030 - mae: 0.0460 - val_loss: 0.0033 - val_mae: 0.0475
# Epoch 47/400
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0012 - mae: 0.0252 - val_loss: 0.0022 - val_mae: 0.0360
# Epoch 48/400
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0026 - mae: 0.0444 - val_loss: 0.0020 - val_mae: 0.0352
# Epoch 49/400
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0013 - mae: 0.0279 - val_loss: 0.0052 - val_mae: 0.0611
# Epoch 50/400
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0019 - mae: 0.0351 - val_loss: 0.0049 - val_mae: 0.0592
# Epoch 51/400
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0018 - mae: 0.0341 - val_loss: 0.0019 - val_mae: 0.0349
# Epoch 52/400
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0012 - mae: 0.0273 - val_loss: 0.0018 - val_mae: 0.0321
# Epoch 53/400
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0019 - mae: 0.0372 - val_loss: 0.0026 - val_mae: 0.0419
# Epoch 54/400
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0010 - mae: 0.0244 - val_loss: 0.0049 - val_mae: 0.0591
# Epoch 55/400
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0017 - mae: 0.0327 - val_loss: 0.0033 - val_mae: 0.0479
# Epoch 56/400
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0011 - mae: 0.0252 - val_loss: 0.0018 - val_mae: 0.0320
# Epoch 57/400
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0013 - mae: 0.0282 - val_loss: 0.0018 - val_mae: 0.0324
# Epoch 58/400
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0012 - mae: 0.0264 - val_loss: 0.0033 - val_mae: 0.0477
# Epoch 59/400
# 1/1 [==============================] - 0s 35ms/step - loss: 9.6438e-04 - mae: 0.0232 - val_loss: 0.0041 - val_mae: 0.0546
# Epoch 60/400
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0012 - mae: 0.0269 - val_loss: 0.0024 - val_mae: 0.0399
# Epoch 61/400
# 1/1 [==============================] - 0s 36ms/step - loss: 8.0651e-04 - mae: 0.0199 - val_loss: 0.0018 - val_mae: 0.0321
# Epoch 62/400
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0012 - mae: 0.0261 - val_loss: 0.0022 - val_mae: 0.0374
# Epoch 63/400
# 1/1 [==============================] - 0s 35ms/step - loss: 8.1508e-04 - mae: 0.0197 - val_loss: 0.0036 - val_mae: 0.0511
# Epoch 64/400
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0010 - mae: 0.0237 - val_loss: 0.0033 - val_mae: 0.0481
# Epoch 65/400
# 1/1 [==============================] - 0s 33ms/step - loss: 8.9365e-04 - mae: 0.0217 - val_loss: 0.0021 - val_mae: 0.0353
# Epoch 66/400
# 1/1 [==============================] - 0s 34ms/step - loss: 8.5303e-04 - mae: 0.0204 - val_loss: 0.0019 - val_mae: 0.0337
# Epoch 67/400
# 1/1 [==============================] - 0s 36ms/step - loss: 9.2884e-04 - mae: 0.0218 - val_loss: 0.0028 - val_mae: 0.0433
# Epoch 68/400
# 1/1 [==============================] - 0s 31ms/step - loss: 7.6457e-04 - mae: 0.0193 - val_loss: 0.0034 - val_mae: 0.0495
# Epoch 69/400
# 1/1 [==============================] - 0s 35ms/step - loss: 9.1282e-04 - mae: 0.0223 - val_loss: 0.0025 - val_mae: 0.0406
# Epoch 70/400
# 1/1 [==============================] - 0s 33ms/step - loss: 7.2422e-04 - mae: 0.0185 - val_loss: 0.0019 - val_mae: 0.0336
# Epoch 71/400
# 1/1 [==============================] - 0s 33ms/step - loss: 8.6092e-04 - mae: 0.0210 - val_loss: 0.0022 - val_mae: 0.0374
# Epoch 72/400
# 1/1 [==============================] - 0s 35ms/step - loss: 7.2186e-04 - mae: 0.0186 - val_loss: 0.0030 - val_mae: 0.0462
# Epoch 73/400
# 1/1 [==============================] - 0s 33ms/step - loss: 7.9136e-04 - mae: 0.0205 - val_loss: 0.0028 - val_mae: 0.0440
# Epoch 74/400
# 1/1 [==============================] - 0s 34ms/step - loss: 7.3712e-04 - mae: 0.0195 - val_loss: 0.0020 - val_mae: 0.0355
# Epoch 75/400
# 1/1 [==============================] - 0s 32ms/step - loss: 7.3119e-04 - mae: 0.0191 - val_loss: 0.0020 - val_mae: 0.0348
# Epoch 76/400
# 1/1 [==============================] - 0s 32ms/step - loss: 7.4261e-04 - mae: 0.0194 - val_loss: 0.0026 - val_mae: 0.0419
# Epoch 77/400
# 1/1 [==============================] - 0s 38ms/step - loss: 6.9374e-04 - mae: 0.0189 - val_loss: 0.0029 - val_mae: 0.0446
# Epoch 78/400
# 1/1 [==============================] - 0s 37ms/step - loss: 7.3880e-04 - mae: 0.0199 - val_loss: 0.0022 - val_mae: 0.0380
# Epoch 79/400
# 1/1 [==============================] - 0s 33ms/step - loss: 6.7030e-04 - mae: 0.0183 - val_loss: 0.0019 - val_mae: 0.0345
# Epoch 80/400
# 1/1 [==============================] - 0s 33ms/step - loss: 7.2565e-04 - mae: 0.0193 - val_loss: 0.0023 - val_mae: 0.0388
# Epoch 81/400
# 1/1 [==============================] - 0s 33ms/step - loss: 6.5966e-04 - mae: 0.0182 - val_loss: 0.0027 - val_mae: 0.0436
# Epoch 82/400
# 1/1 [==============================] - 0s 35ms/step - loss: 7.0480e-04 - mae: 0.0194 - val_loss: 0.0024 - val_mae: 0.0400
# Epoch 83/400
# 1/1 [==============================] - 0s 33ms/step - loss: 6.5401e-04 - mae: 0.0182 - val_loss: 0.0020 - val_mae: 0.0353
# Epoch 84/400
# 1/1 [==============================] - 0s 34ms/step - loss: 6.8454e-04 - mae: 0.0185 - val_loss: 0.0022 - val_mae: 0.0374
# Epoch 85/400
# 1/1 [==============================] - 0s 33ms/step - loss: 6.4905e-04 - mae: 0.0179 - val_loss: 0.0026 - val_mae: 0.0423
# Epoch 86/400
# 1/1 [==============================] - 0s 32ms/step - loss: 6.6589e-04 - mae: 0.0185 - val_loss: 0.0025 - val_mae: 0.0409
# Epoch 87/400
# 1/1 [==============================] - 0s 32ms/step - loss: 6.4528e-04 - mae: 0.0180 - val_loss: 0.0021 - val_mae: 0.0363
# Epoch 88/400
# 1/1 [==============================] - 0s 31ms/step - loss: 6.5097e-04 - mae: 0.0178 - val_loss: 0.0021 - val_mae: 0.0369
# Epoch 89/400
# 1/1 [==============================] - 0s 33ms/step - loss: 6.4018e-04 - mae: 0.0176 - val_loss: 0.0025 - val_mae: 0.0412
# Epoch 90/400
# 1/1 [==============================] - 0s 37ms/step - loss: 6.3963e-04 - mae: 0.0179 - val_loss: 0.0025 - val_mae: 0.0411
# Epoch 91/400
# 1/1 [==============================] - 0s 34ms/step - loss: 6.3526e-04 - mae: 0.0178 - val_loss: 0.0021 - val_mae: 0.0371
# Epoch 92/400
# 1/1 [==============================] - 0s 33ms/step - loss: 6.3053e-04 - mae: 0.0174 - val_loss: 0.0021 - val_mae: 0.0369
# Epoch 93/400
# 1/1 [==============================] - 0s 32ms/step - loss: 6.2967e-04 - mae: 0.0174 - val_loss: 0.0024 - val_mae: 0.0405
# Epoch 94/400
# 1/1 [==============================] - 0s 34ms/step - loss: 6.2355e-04 - mae: 0.0176 - val_loss: 0.0025 - val_mae: 0.0408
# Epoch 95/400
# 1/1 [==============================] - 0s 34ms/step - loss: 6.2399e-04 - mae: 0.0176 - val_loss: 0.0022 - val_mae: 0.0375
# Epoch 96/400
# 1/1 [==============================] - 0s 31ms/step - loss: 6.1737e-04 - mae: 0.0172 - val_loss: 0.0021 - val_mae: 0.0370
# Epoch 97/400
# 1/1 [==============================] - 0s 32ms/step - loss: 6.1815e-04 - mae: 0.0173 - val_loss: 0.0024 - val_mae: 0.0399
# Epoch 98/400
# 1/1 [==============================] - 0s 33ms/step - loss: 6.1222e-04 - mae: 0.0174 - val_loss: 0.0024 - val_mae: 0.0402
# Epoch 99/400
# 1/1 [==============================] - 0s 37ms/step - loss: 6.1253e-04 - mae: 0.0175 - val_loss: 0.0022 - val_mae: 0.0375
# Epoch 100/400
# 1/1 [==============================] - 0s 33ms/step - loss: 6.0746e-04 - mae: 0.0172 - val_loss: 0.0021 - val_mae: 0.0372
# Epoch 101/400
# 1/1 [==============================] - 0s 34ms/step - loss: 6.0712e-04 - mae: 0.0172 - val_loss: 0.0023 - val_mae: 0.0396
# Epoch 102/400
# 1/1 [==============================] - 0s 31ms/step - loss: 6.0329e-04 - mae: 0.0173 - val_loss: 0.0023 - val_mae: 0.0397
# Epoch 103/400
# 1/1 [==============================] - 0s 33ms/step - loss: 6.0204e-04 - mae: 0.0173 - val_loss: 0.0021 - val_mae: 0.0373
# Epoch 104/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.9937e-04 - mae: 0.0171 - val_loss: 0.0021 - val_mae: 0.0374
# Epoch 105/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.9730e-04 - mae: 0.0171 - val_loss: 0.0023 - val_mae: 0.0394
# Epoch 106/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.9585e-04 - mae: 0.0173 - val_loss: 0.0023 - val_mae: 0.0391
# Epoch 107/400
# 1/1 [==============================] - 0s 79ms/step - loss: 5.9299e-04 - mae: 0.0172 - val_loss: 0.0021 - val_mae: 0.0372
# Epoch 108/400
# 1/1 [==============================] - 0s 33ms/step - loss: 5.9258e-04 - mae: 0.0170 - val_loss: 0.0022 - val_mae: 0.0376
# Epoch 109/400
# 1/1 [==============================] - 0s 30ms/step - loss: 5.8905e-04 - mae: 0.0170 - val_loss: 0.0023 - val_mae: 0.0392
# Epoch 110/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.8936e-04 - mae: 0.0172 - val_loss: 0.0022 - val_mae: 0.0385
# Epoch 111/400
# 1/1 [==============================] - 0s 38ms/step - loss: 5.8545e-04 - mae: 0.0170 - val_loss: 0.0021 - val_mae: 0.0371
# Epoch 112/400
# 1/1 [==============================] - 0s 34ms/step - loss: 5.8615e-04 - mae: 0.0169 - val_loss: 0.0022 - val_mae: 0.0380
# Epoch 113/400
# 1/1 [==============================] - 0s 34ms/step - loss: 5.8212e-04 - mae: 0.0170 - val_loss: 0.0023 - val_mae: 0.0390
# Epoch 114/400
# 1/1 [==============================] - 0s 35ms/step - loss: 5.8274e-04 - mae: 0.0171 - val_loss: 0.0022 - val_mae: 0.0379
# Epoch 115/400
# 1/1 [==============================] - 0s 36ms/step - loss: 5.7912e-04 - mae: 0.0169 - val_loss: 0.0021 - val_mae: 0.0372
# Epoch 116/400
# 1/1 [==============================] - 0s 39ms/step - loss: 5.7930e-04 - mae: 0.0168 - val_loss: 0.0022 - val_mae: 0.0383
# Epoch 117/400
# 1/1 [==============================] - 0s 40ms/step - loss: 5.7647e-04 - mae: 0.0169 - val_loss: 0.0022 - val_mae: 0.0387
# Epoch 118/400
# 1/1 [==============================] - 0s 34ms/step - loss: 5.7601e-04 - mae: 0.0169 - val_loss: 0.0021 - val_mae: 0.0375
# Epoch 119/400
# 1/1 [==============================] - 0s 38ms/step - loss: 5.7412e-04 - mae: 0.0168 - val_loss: 0.0021 - val_mae: 0.0375
# Epoch 120/400
# 1/1 [==============================] - 0s 34ms/step - loss: 5.7291e-04 - mae: 0.0167 - val_loss: 0.0022 - val_mae: 0.0385
# Epoch 121/400
# 1/1 [==============================] - 0s 34ms/step - loss: 5.7182e-04 - mae: 0.0168 - val_loss: 0.0022 - val_mae: 0.0382
# Epoch 122/400
# 1/1 [==============================] - 0s 33ms/step - loss: 5.7005e-04 - mae: 0.0167 - val_loss: 0.0021 - val_mae: 0.0374
# Epoch 123/400
# 1/1 [==============================] - 0s 33ms/step - loss: 5.6948e-04 - mae: 0.0167 - val_loss: 0.0022 - val_mae: 0.0379
# Epoch 124/400
# 1/1 [==============================] - 0s 33ms/step - loss: 5.6748e-04 - mae: 0.0167 - val_loss: 0.0022 - val_mae: 0.0385
# Epoch 125/400
# 1/1 [==============================] - 0s 30ms/step - loss: 5.6702e-04 - mae: 0.0167 - val_loss: 0.0022 - val_mae: 0.0378
# Epoch 126/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.6519e-04 - mae: 0.0166 - val_loss: 0.0021 - val_mae: 0.0374
# Epoch 127/400
# 1/1 [==============================] - 0s 30ms/step - loss: 5.6448e-04 - mae: 0.0166 - val_loss: 0.0022 - val_mae: 0.0382
# Epoch 128/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.6309e-04 - mae: 0.0166 - val_loss: 0.0022 - val_mae: 0.0381
# Epoch 129/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.6198e-04 - mae: 0.0166 - val_loss: 0.0021 - val_mae: 0.0375
# Epoch 130/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.6104e-04 - mae: 0.0165 - val_loss: 0.0022 - val_mae: 0.0377
# Epoch 131/400
# 1/1 [==============================] - 0s 33ms/step - loss: 5.5965e-04 - mae: 0.0165 - val_loss: 0.0022 - val_mae: 0.0382
# Epoch 132/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.5894e-04 - mae: 0.0166 - val_loss: 0.0021 - val_mae: 0.0377
# Epoch 133/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.5757e-04 - mae: 0.0165 - val_loss: 0.0021 - val_mae: 0.0374
# Epoch 134/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.5678e-04 - mae: 0.0165 - val_loss: 0.0022 - val_mae: 0.0380
# Epoch 135/400
# 1/1 [==============================] - 0s 33ms/step - loss: 5.5566e-04 - mae: 0.0165 - val_loss: 0.0022 - val_mae: 0.0379
# Epoch 136/400
# 1/1 [==============================] - 0s 35ms/step - loss: 5.5465e-04 - mae: 0.0165 - val_loss: 0.0021 - val_mae: 0.0374
# Epoch 137/400
# 1/1 [==============================] - 0s 33ms/step - loss: 5.5379e-04 - mae: 0.0164 - val_loss: 0.0021 - val_mae: 0.0377
# Epoch 138/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.5264e-04 - mae: 0.0164 - val_loss: 0.0022 - val_mae: 0.0380
# Epoch 139/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.5187e-04 - mae: 0.0164 - val_loss: 0.0021 - val_mae: 0.0376
# Epoch 140/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.5081e-04 - mae: 0.0164 - val_loss: 0.0021 - val_mae: 0.0375
# Epoch 141/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.4994e-04 - mae: 0.0164 - val_loss: 0.0022 - val_mae: 0.0379
# Epoch 142/400
# 1/1 [==============================] - 0s 33ms/step - loss: 5.4907e-04 - mae: 0.0164 - val_loss: 0.0021 - val_mae: 0.0377
# Epoch 143/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.4810e-04 - mae: 0.0163 - val_loss: 0.0021 - val_mae: 0.0374
# Epoch 144/400
# 1/1 [==============================] - 0s 29ms/step - loss: 5.4733e-04 - mae: 0.0163 - val_loss: 0.0021 - val_mae: 0.0377
# Epoch 145/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.4637e-04 - mae: 0.0163 - val_loss: 0.0022 - val_mae: 0.0378
# Epoch 146/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.4556e-04 - mae: 0.0163 - val_loss: 0.0021 - val_mae: 0.0375
# Epoch 147/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.4473e-04 - mae: 0.0163 - val_loss: 0.0021 - val_mae: 0.0376
# Epoch 148/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.4385e-04 - mae: 0.0163 - val_loss: 0.0021 - val_mae: 0.0378
# Epoch 149/400
# 1/1 [==============================] - 0s 34ms/step - loss: 5.4310e-04 - mae: 0.0163 - val_loss: 0.0021 - val_mae: 0.0375
# Epoch 150/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.4224e-04 - mae: 0.0162 - val_loss: 0.0021 - val_mae: 0.0375
# Epoch 151/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.4146e-04 - mae: 0.0162 - val_loss: 0.0021 - val_mae: 0.0377
# Epoch 152/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.4070e-04 - mae: 0.0162 - val_loss: 0.0021 - val_mae: 0.0376
# Epoch 153/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.3988e-04 - mae: 0.0162 - val_loss: 0.0021 - val_mae: 0.0374
# Epoch 154/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.3914e-04 - mae: 0.0162 - val_loss: 0.0021 - val_mae: 0.0376
# Epoch 155/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.3836e-04 - mae: 0.0162 - val_loss: 0.0021 - val_mae: 0.0376
# Epoch 156/400
# 1/1 [==============================] - 0s 30ms/step - loss: 5.3758e-04 - mae: 0.0161 - val_loss: 0.0021 - val_mae: 0.0374
# Epoch 157/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.3686e-04 - mae: 0.0161 - val_loss: 0.0021 - val_mae: 0.0375
# Epoch 158/400
# 1/1 [==============================] - 0s 33ms/step - loss: 5.3609e-04 - mae: 0.0161 - val_loss: 0.0021 - val_mae: 0.0376
# Epoch 159/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.3535e-04 - mae: 0.0161 - val_loss: 0.0021 - val_mae: 0.0374
# Epoch 160/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.3463e-04 - mae: 0.0161 - val_loss: 0.0021 - val_mae: 0.0375
# Epoch 161/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.3388e-04 - mae: 0.0161 - val_loss: 0.0021 - val_mae: 0.0375
# Epoch 162/400
# 1/1 [==============================] - 0s 30ms/step - loss: 5.3318e-04 - mae: 0.0161 - val_loss: 0.0021 - val_mae: 0.0374
# Epoch 163/400
# 1/1 [==============================] - 0s 33ms/step - loss: 5.3247e-04 - mae: 0.0161 - val_loss: 0.0021 - val_mae: 0.0374
# Epoch 164/400
# 1/1 [==============================] - 0s 33ms/step - loss: 5.3175e-04 - mae: 0.0161 - val_loss: 0.0021 - val_mae: 0.0375
# Epoch 165/400
# 1/1 [==============================] - 0s 33ms/step - loss: 5.3106e-04 - mae: 0.0160 - val_loss: 0.0021 - val_mae: 0.0374
# Epoch 166/400
# 1/1 [==============================] - 0s 33ms/step - loss: 5.3035e-04 - mae: 0.0160 - val_loss: 0.0021 - val_mae: 0.0374
# Epoch 167/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.2965e-04 - mae: 0.0160 - val_loss: 0.0021 - val_mae: 0.0374
# Epoch 168/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.2897e-04 - mae: 0.0160 - val_loss: 0.0021 - val_mae: 0.0373
# Epoch 169/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.2828e-04 - mae: 0.0160 - val_loss: 0.0021 - val_mae: 0.0373
# Epoch 170/400
# 1/1 [==============================] - 0s 33ms/step - loss: 5.2760e-04 - mae: 0.0160 - val_loss: 0.0021 - val_mae: 0.0374
# Epoch 171/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.2694e-04 - mae: 0.0160 - val_loss: 0.0021 - val_mae: 0.0373
# Epoch 172/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.2626e-04 - mae: 0.0159 - val_loss: 0.0021 - val_mae: 0.0373
# Epoch 173/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.2560e-04 - mae: 0.0159 - val_loss: 0.0021 - val_mae: 0.0374
# Epoch 174/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.2494e-04 - mae: 0.0159 - val_loss: 0.0021 - val_mae: 0.0373
# Epoch 175/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.2428e-04 - mae: 0.0159 - val_loss: 0.0021 - val_mae: 0.0373
# Epoch 176/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.2363e-04 - mae: 0.0159 - val_loss: 0.0021 - val_mae: 0.0373
# Epoch 177/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.2299e-04 - mae: 0.0159 - val_loss: 0.0021 - val_mae: 0.0373
# Epoch 178/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.2235e-04 - mae: 0.0159 - val_loss: 0.0021 - val_mae: 0.0373
# Epoch 179/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.2171e-04 - mae: 0.0159 - val_loss: 0.0021 - val_mae: 0.0373
# Epoch 180/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.2109e-04 - mae: 0.0159 - val_loss: 0.0021 - val_mae: 0.0372
# Epoch 181/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.2046e-04 - mae: 0.0158 - val_loss: 0.0021 - val_mae: 0.0372
# Epoch 182/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.1985e-04 - mae: 0.0158 - val_loss: 0.0021 - val_mae: 0.0373
# Epoch 183/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.1924e-04 - mae: 0.0158 - val_loss: 0.0021 - val_mae: 0.0372
# Epoch 184/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.1864e-04 - mae: 0.0158 - val_loss: 0.0021 - val_mae: 0.0372
# Epoch 185/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.1805e-04 - mae: 0.0158 - val_loss: 0.0021 - val_mae: 0.0372
# Epoch 186/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.1746e-04 - mae: 0.0158 - val_loss: 0.0021 - val_mae: 0.0372
# Epoch 187/400
# 1/1 [==============================] - 0s 33ms/step - loss: 5.1687e-04 - mae: 0.0158 - val_loss: 0.0021 - val_mae: 0.0372
# Epoch 188/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.1629e-04 - mae: 0.0158 - val_loss: 0.0021 - val_mae: 0.0372
# Epoch 189/400
# 1/1 [==============================] - 0s 30ms/step - loss: 5.1572e-04 - mae: 0.0158 - val_loss: 0.0021 - val_mae: 0.0371
# Epoch 190/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.1515e-04 - mae: 0.0158 - val_loss: 0.0021 - val_mae: 0.0372
# Epoch 191/400
# 1/1 [==============================] - 0s 33ms/step - loss: 5.1458e-04 - mae: 0.0158 - val_loss: 0.0021 - val_mae: 0.0371
# Epoch 192/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.1402e-04 - mae: 0.0157 - val_loss: 0.0021 - val_mae: 0.0371
# Epoch 193/400
# 1/1 [==============================] - 0s 33ms/step - loss: 5.1346e-04 - mae: 0.0157 - val_loss: 0.0021 - val_mae: 0.0371
# Epoch 194/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.1291e-04 - mae: 0.0157 - val_loss: 0.0021 - val_mae: 0.0371
# Epoch 195/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.1235e-04 - mae: 0.0157 - val_loss: 0.0021 - val_mae: 0.0371
# Epoch 196/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.1180e-04 - mae: 0.0157 - val_loss: 0.0021 - val_mae: 0.0371
# Epoch 197/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.1126e-04 - mae: 0.0157 - val_loss: 0.0021 - val_mae: 0.0371
# Epoch 198/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.1071e-04 - mae: 0.0157 - val_loss: 0.0021 - val_mae: 0.0371
# Epoch 199/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.1017e-04 - mae: 0.0157 - val_loss: 0.0021 - val_mae: 0.0371
# Epoch 200/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.0964e-04 - mae: 0.0157 - val_loss: 0.0021 - val_mae: 0.0371
# Epoch 201/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.0912e-04 - mae: 0.0156 - val_loss: 0.0021 - val_mae: 0.0371
# Epoch 202/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.0860e-04 - mae: 0.0156 - val_loss: 0.0021 - val_mae: 0.0371
# Epoch 203/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.0808e-04 - mae: 0.0156 - val_loss: 0.0021 - val_mae: 0.0371
# Epoch 204/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.0757e-04 - mae: 0.0156 - val_loss: 0.0021 - val_mae: 0.0371
# Epoch 205/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.0706e-04 - mae: 0.0156 - val_loss: 0.0021 - val_mae: 0.0370
# Epoch 206/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.0656e-04 - mae: 0.0156 - val_loss: 0.0021 - val_mae: 0.0370
# Epoch 207/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.0606e-04 - mae: 0.0156 - val_loss: 0.0021 - val_mae: 0.0370
# Epoch 208/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.0557e-04 - mae: 0.0156 - val_loss: 0.0021 - val_mae: 0.0370
# Epoch 209/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.0508e-04 - mae: 0.0156 - val_loss: 0.0021 - val_mae: 0.0370
# Epoch 210/400
# 1/1 [==============================] - 0s 33ms/step - loss: 5.0460e-04 - mae: 0.0156 - val_loss: 0.0021 - val_mae: 0.0370
# Epoch 211/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.0412e-04 - mae: 0.0156 - val_loss: 0.0021 - val_mae: 0.0370
# Epoch 212/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.0364e-04 - mae: 0.0156 - val_loss: 0.0021 - val_mae: 0.0370
# Epoch 213/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.0317e-04 - mae: 0.0155 - val_loss: 0.0021 - val_mae: 0.0370
# Epoch 214/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.0271e-04 - mae: 0.0155 - val_loss: 0.0021 - val_mae: 0.0370
# Epoch 215/400
# 1/1 [==============================] - 0s 30ms/step - loss: 5.0225e-04 - mae: 0.0155 - val_loss: 0.0021 - val_mae: 0.0370
# Epoch 216/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.0179e-04 - mae: 0.0155 - val_loss: 0.0021 - val_mae: 0.0370
# Epoch 217/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.0133e-04 - mae: 0.0155 - val_loss: 0.0021 - val_mae: 0.0369
# Epoch 218/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.0088e-04 - mae: 0.0155 - val_loss: 0.0021 - val_mae: 0.0369
# Epoch 219/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.0043e-04 - mae: 0.0155 - val_loss: 0.0021 - val_mae: 0.0369
# Epoch 220/400
# 1/1 [==============================] - 0s 32ms/step - loss: 4.9999e-04 - mae: 0.0155 - val_loss: 0.0021 - val_mae: 0.0369
# Epoch 221/400
# 1/1 [==============================] - 0s 33ms/step - loss: 4.9956e-04 - mae: 0.0155 - val_loss: 0.0021 - val_mae: 0.0369
# Epoch 222/400
# 1/1 [==============================] - 0s 30ms/step - loss: 4.9912e-04 - mae: 0.0155 - val_loss: 0.0021 - val_mae: 0.0369
# Epoch 223/400
# 1/1 [==============================] - 0s 32ms/step - loss: 4.9869e-04 - mae: 0.0155 - val_loss: 0.0021 - val_mae: 0.0369
# Epoch 224/400
# 1/1 [==============================] - 0s 30ms/step - loss: 4.9827e-04 - mae: 0.0155 - val_loss: 0.0021 - val_mae: 0.0369
# Epoch 225/400
# 1/1 [==============================] - 0s 32ms/step - loss: 4.9785e-04 - mae: 0.0155 - val_loss: 0.0021 - val_mae: 0.0369
# Epoch 226/400
# 1/1 [==============================] - 0s 34ms/step - loss: 4.9743e-04 - mae: 0.0155 - val_loss: 0.0021 - val_mae: 0.0369
# Epoch 227/400
# 1/1 [==============================] - 0s 32ms/step - loss: 4.9701e-04 - mae: 0.0154 - val_loss: 0.0021 - val_mae: 0.0369
# Epoch 228/400
# 1/1 [==============================] - 0s 31ms/step - loss: 4.9659e-04 - mae: 0.0154 - val_loss: 0.0021 - val_mae: 0.0369
# Epoch 229/400
# 1/1 [==============================] - 0s 31ms/step - loss: 4.9619e-04 - mae: 0.0154 - val_loss: 0.0020 - val_mae: 0.0368
# Epoch 230/400
# 1/1 [==============================] - 0s 33ms/step - loss: 4.9579e-04 - mae: 0.0154 - val_loss: 0.0021 - val_mae: 0.0368
# Epoch 231/400
# 1/1 [==============================] - 0s 31ms/step - loss: 4.9539e-04 - mae: 0.0154 - val_loss: 0.0020 - val_mae: 0.0368
# Epoch 232/400
# 1/1 [==============================] - 0s 31ms/step - loss: 4.9499e-04 - mae: 0.0154 - val_loss: 0.0020 - val_mae: 0.0368
# Epoch 233/400
# 1/1 [==============================] - 0s 32ms/step - loss: 4.9459e-04 - mae: 0.0154 - val_loss: 0.0020 - val_mae: 0.0368
# Epoch 234/400
# 1/1 [==============================] - 0s 32ms/step - loss: 4.9420e-04 - mae: 0.0154 - val_loss: 0.0020 - val_mae: 0.0368
# Epoch 235/400
# 1/1 [==============================] - 0s 32ms/step - loss: 4.9379e-04 - mae: 0.0154 - val_loss: 0.0020 - val_mae: 0.0368
# Epoch 236/400
# 1/1 [==============================] - 0s 32ms/step - loss: 4.9339e-04 - mae: 0.0154 - val_loss: 0.0020 - val_mae: 0.0368
# Epoch 237/400
# 1/1 [==============================] - 0s 32ms/step - loss: 4.9297e-04 - mae: 0.0154 - val_loss: 0.0020 - val_mae: 0.0368
# Epoch 238/400
# 1/1 [==============================] - 0s 31ms/step - loss: 4.9253e-04 - mae: 0.0154 - val_loss: 0.0020 - val_mae: 0.0368
# Epoch 239/400
# 1/1 [==============================] - 0s 32ms/step - loss: 4.9209e-04 - mae: 0.0154 - val_loss: 0.0020 - val_mae: 0.0368
# Epoch 240/400
# 1/1 [==============================] - 0s 33ms/step - loss: 4.9159e-04 - mae: 0.0154 - val_loss: 0.0020 - val_mae: 0.0368
# Epoch 241/400
# 1/1 [==============================] - 0s 32ms/step - loss: 4.9100e-04 - mae: 0.0154 - val_loss: 0.0020 - val_mae: 0.0367
# Epoch 242/400
# 1/1 [==============================] - 0s 33ms/step - loss: 4.9031e-04 - mae: 0.0153 - val_loss: 0.0020 - val_mae: 0.0367
# Epoch 243/400
# 1/1 [==============================] - 0s 32ms/step - loss: 4.8941e-04 - mae: 0.0153 - val_loss: 0.0020 - val_mae: 0.0367
# Epoch 244/400
# 1/1 [==============================] - 0s 32ms/step - loss: 4.8858e-04 - mae: 0.0153 - val_loss: 0.0020 - val_mae: 0.0367
# Epoch 245/400
# 1/1 [==============================] - 0s 32ms/step - loss: 4.8802e-04 - mae: 0.0153 - val_loss: 0.0020 - val_mae: 0.0367
# Epoch 246/400
# 1/1 [==============================] - 0s 31ms/step - loss: 4.8766e-04 - mae: 0.0153 - val_loss: 0.0020 - val_mae: 0.0367
# Epoch 247/400
# 1/1 [==============================] - 0s 31ms/step - loss: 4.8722e-04 - mae: 0.0153 - val_loss: 0.0020 - val_mae: 0.0367
# Epoch 248/400
# 1/1 [==============================] - 0s 33ms/step - loss: 4.8661e-04 - mae: 0.0153 - val_loss: 0.0020 - val_mae: 0.0367
# Epoch 249/400
# 1/1 [==============================] - 0s 31ms/step - loss: 4.8577e-04 - mae: 0.0153 - val_loss: 0.0020 - val_mae: 0.0366
# Epoch 250/400
# 1/1 [==============================] - 0s 32ms/step - loss: 4.8467e-04 - mae: 0.0153 - val_loss: 0.0020 - val_mae: 0.0366
# Epoch 251/400
# 1/1 [==============================] - 0s 32ms/step - loss: 4.8332e-04 - mae: 0.0152 - val_loss: 0.0020 - val_mae: 0.0366
# Epoch 252/400
# 1/1 [==============================] - 0s 32ms/step - loss: 4.8197e-04 - mae: 0.0152 - val_loss: 0.0020 - val_mae: 0.0366
# Epoch 253/400
# 1/1 [==============================] - 0s 31ms/step - loss: 4.8080e-04 - mae: 0.0152 - val_loss: 0.0020 - val_mae: 0.0366
# Epoch 254/400
# 1/1 [==============================] - 0s 32ms/step - loss: 4.7972e-04 - mae: 0.0152 - val_loss: 0.0020 - val_mae: 0.0366
# Epoch 255/400
# 1/1 [==============================] - 0s 31ms/step - loss: 4.7812e-04 - mae: 0.0151 - val_loss: 0.0020 - val_mae: 0.0365
# Epoch 256/400
# 1/1 [==============================] - 0s 31ms/step - loss: 4.7614e-04 - mae: 0.0151 - val_loss: 0.0020 - val_mae: 0.0365
# Epoch 257/400
# 1/1 [==============================] - 0s 32ms/step - loss: 4.7428e-04 - mae: 0.0151 - val_loss: 0.0020 - val_mae: 0.0364
# Epoch 258/400
# 1/1 [==============================] - 0s 32ms/step - loss: 4.7242e-04 - mae: 0.0151 - val_loss: 0.0020 - val_mae: 0.0363
# Epoch 259/400
# 1/1 [==============================] - 0s 31ms/step - loss: 4.7027e-04 - mae: 0.0151 - val_loss: 0.0020 - val_mae: 0.0363
# Epoch 260/400
# 1/1 [==============================] - 0s 31ms/step - loss: 4.6764e-04 - mae: 0.0150 - val_loss: 0.0020 - val_mae: 0.0363
# Epoch 261/400
# 1/1 [==============================] - 0s 32ms/step - loss: 4.6486e-04 - mae: 0.0150 - val_loss: 0.0020 - val_mae: 0.0362
# Epoch 262/400
# 1/1 [==============================] - 0s 31ms/step - loss: 4.6196e-04 - mae: 0.0149 - val_loss: 0.0020 - val_mae: 0.0362
# Epoch 263/400
# 1/1 [==============================] - 0s 32ms/step - loss: 4.5886e-04 - mae: 0.0149 - val_loss: 0.0020 - val_mae: 0.0361
# Epoch 264/400
# 1/1 [==============================] - 0s 31ms/step - loss: 4.5532e-04 - mae: 0.0148 - val_loss: 0.0020 - val_mae: 0.0361
# Epoch 265/400
# 1/1 [==============================] - 0s 31ms/step - loss: 4.5145e-04 - mae: 0.0147 - val_loss: 0.0019 - val_mae: 0.0358
# Epoch 266/400
# 1/1 [==============================] - 0s 31ms/step - loss: 4.4740e-04 - mae: 0.0147 - val_loss: 0.0020 - val_mae: 0.0360
# Epoch 267/400
# 1/1 [==============================] - 0s 32ms/step - loss: 4.4322e-04 - mae: 0.0147 - val_loss: 0.0019 - val_mae: 0.0355
# Epoch 268/400
# 1/1 [==============================] - 0s 31ms/step - loss: 4.3879e-04 - mae: 0.0145 - val_loss: 0.0020 - val_mae: 0.0362
# Epoch 269/400
# 1/1 [==============================] - 0s 31ms/step - loss: 4.3420e-04 - mae: 0.0145 - val_loss: 0.0019 - val_mae: 0.0350
# Epoch 270/400
# 1/1 [==============================] - 0s 34ms/step - loss: 4.2993e-04 - mae: 0.0143 - val_loss: 0.0020 - val_mae: 0.0368
# Epoch 271/400
# 1/1 [==============================] - 0s 32ms/step - loss: 4.2684e-04 - mae: 0.0145 - val_loss: 0.0018 - val_mae: 0.0337
# Epoch 272/400
# 1/1 [==============================] - 0s 32ms/step - loss: 4.2702e-04 - mae: 0.0143 - val_loss: 0.0022 - val_mae: 0.0388
# Epoch 273/400
# 1/1 [==============================] - 0s 32ms/step - loss: 4.3618e-04 - mae: 0.0150 - val_loss: 0.0016 - val_mae: 0.0310
# Epoch 274/400
# 1/1 [==============================] - 0s 31ms/step - loss: 4.6296e-04 - mae: 0.0150 - val_loss: 0.0027 - val_mae: 0.0436
# Epoch 275/400
# 1/1 [==============================] - 0s 32ms/step - loss: 5.2657e-04 - mae: 0.0175 - val_loss: 0.0013 - val_mae: 0.0279
# Epoch 276/400
# 1/1 [==============================] - 0s 31ms/step - loss: 6.1231e-04 - mae: 0.0184 - val_loss: 0.0034 - val_mae: 0.0502
# Epoch 277/400
# 1/1 [==============================] - 0s 32ms/step - loss: 7.5963e-04 - mae: 0.0220 - val_loss: 0.0012 - val_mae: 0.0263
# Epoch 278/400
# 1/1 [==============================] - 0s 31ms/step - loss: 8.0566e-04 - mae: 0.0223 - val_loss: 0.0037 - val_mae: 0.0526
# Epoch 279/400
# 1/1 [==============================] - 0s 31ms/step - loss: 8.6413e-04 - mae: 0.0238 - val_loss: 0.0013 - val_mae: 0.0269
# Epoch 280/400
# 1/1 [==============================] - 0s 32ms/step - loss: 6.8988e-04 - mae: 0.0202 - val_loss: 0.0027 - val_mae: 0.0443
# Epoch 281/400
# 1/1 [==============================] - 0s 31ms/step - loss: 5.2818e-04 - mae: 0.0177 - val_loss: 0.0017 - val_mae: 0.0329

# %%
modelen_mm.save_weights('model_weights_mmlater.h5', overwrite=True)

# %%
modelen_mm.load_weights('model_weights_mmlater.h5')

# %%
# Check how loss & mae went down
epoch_loss = history_mm.history['loss']
epoch_val_loss = history_mm.history['val_loss']

plt.figure(figsize=(20,6),dpi=200)
plt.plot(range(0,len(epoch_loss)), epoch_loss, 'b-', linewidth=2, label='Train Loss')
plt.plot(range(0,len(epoch_val_loss)), epoch_val_loss, 'r-', linewidth=2, label='Val Loss')
plt.title('Evolution of loss on train & validation datasets over epochs')
plt.legend(loc='best')


plt.show()

# %%
start = '2018-06-01'
end = '2019-06-01'
GSPC_test = pd.DataFrame(data.DataReader("^GSPC","yahoo",start,end)['Adj Close'])#Choose the data
GSPC_test
# Out:
#               Adj Close
# Date
# 2018-06-01  2734.620117
# 2018-06-04  2746.870117
# 2018-06-05  2748.800049
# 2018-06-06  2772.350098
# 2018-06-07  2770.370117
# ...                 ...
# 2019-05-24  2826.060059
# 2019-05-28  2802.389893
# 2019-05-29  2783.020020
# 2019-05-30  2788.860107
# 2019-05-31  2752.060059
#
# [251 rows x 1 columns]

# %%
mm_t = MinMaxScaler()
noise_mm_T=mm_t.fit_transform(GSPC_test)
Y_test_mm_cnn = modelen_mm.predict(noise_mm_T.T)
Y_test_mm_cnn=Y_test_mm_cnn.reshape((len(GSPC_test),1))
pure_mm_cnn = mm_t.inverse_transform(Y_test_mm_cnn)
noise_mm_T=pd.DataFrame(noise_mm_T,columns=['Adj Close'],index=GSPC_test.index)
Y_test_mm_cnn=pd.DataFrame(Y_test_mm_cnn,columns=['Adj Close'],index=GSPC_test.index)
pure_mm_cnn=pd.DataFrame(pure_mm_cnn,columns=['Adj Close'],index=GSPC_test.index)
plt.figure(figsize=(15,4),dpi=200)
plt.plot(pure_mm_cnn)
plt.plot(GSPC_test,'r')
plt.title('Adj close price')
plt.legend(['denoised', 'original'], loc='upper left')
# Out:
# 1/1 [==============================] - 0s 87ms/step

# %%
original=GSPC_test
recon=pure_mm_cnn

# %%
def features(dataset):
    ret_dataset=pd.DataFrame(index=dataset.index)
    for i in range(2,52,1):
        window = i
        # Volatility
        ret_dataset[str('SMA'+str(i))] = talib.SMA(dataset['Adj Close'],timeperiod=window).shift(1)
        ret_dataset[str('EMA'+str(i))] = talib.EMA(dataset['Adj Close'],timeperiod=window).shift(1)
        ret_dataset[str('STDDEV'+str(i))] = talib.STDDEV(dataset['Adj Close'],timeperiod=window).shift(1)
        ret_dataset[str('Lag'+str(i))] = dataset['Adj Close'].shift(i)
    return ret_dataset

# %%
from sklearn.model_selection import TimeSeriesSplit
import xgboost as xgb
import talib
splits=10

# %%
recon_fea=features(recon)
recon_fea=recon_fea.iloc[51:]
original_m=original.iloc[51::]
recon_m=recon.iloc[51::]
tscv = TimeSeriesSplit(n_splits=splits)
msetestav=0

for train_index, test_index in tscv.split(recon_fea):
    model = xgb.XGBRegressor()
    model.fit(recon_fea.iloc[train_index,:],original_m.iloc[train_index,:])
    test_predict=model.predict(recon_fea.iloc[test_index,:])
    msetest=mean_squared_error(original_m.iloc[test_index,:],test_predict)
    i=1+int(len(train_index)/int(len(recon_fea)/splits))
    plt.figure(figsize=(10,15))
    plt.subplot(1 +splits,1,i)
    past=np.asarray(original_m.iloc[train_index,:]).reshape(len(original_m.iloc[train_index,:]))
    whole=np.concatenate((past, test_predict))
    true=np.asarray(original_m.iloc[test_index,:]).reshape(len(original_m.iloc[test_index,:]))
    whole_t=np.concatenate((past, true))
    plt.plot(whole,"r",label='Predicted')
    plt.plot(whole_t,"b",label='Original')
    plt.ylabel('TimeSeriesSplit'+str(i))
    print(msetest)
    msetestav+=msetest
msetestav=msetestav/splits
print('The last MSE:',msetest)
print('The average MSE:',msetestav)
# Out:
# 813.9203774432341
# 20994.188842789994
# 4536.93085188667
# 17220.970705171425
# 14453.909375329813
# 1279.8522132171524
# 1255.1172306769424
# 2511.6436102357175
# 500.7531332936552
# 1605.2115623950958
# The last MSE: 1605.2115623950958
# The average MSE: 6517.24979024397

# %%
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV 
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingRandomSearchCV
from sklearn.model_selection import HalvingGridSearchCV
parameters = {  'max_depth': [1, 2, 3, 5, 10],
    'learning_rate': [ 0.02, 0.05, 0.1, 0.15],
  'n_estimators': [ 200, 300, 500, 700]}  # Specify the range of hyperparameters in the model to reduce time spent

# %%
# In the following we pass the data into the grid search model and output the hyperparameter optimal values.
reg = xgb.XGBRegressor(eval_metric=mean_squared_error)  # Building the model
grid_search = HalvingGridSearchCV(reg, parameters, scoring='neg_mean_squared_error',verbose=1,cv=None) 
grid_search.fit(recon_fea.iloc[train_index,:],original_m.iloc[train_index,:])  # Input data
print("Optimal values for hyperparameters:",grid_search.best_params_)
print("Best model score:",grid_search.best_score_)
# Out:
# n_iterations: 3
# n_required_iterations: 4
# n_possible_iterations: 3
# min_resources_: 10
# max_resources_: 182
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 80
# n_resources: 10
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# ----------
# iter: 1
# n_candidates: 27
# n_resources: 30
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# ----------
# iter: 2
# n_candidates: 9
# n_resources: 90
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# Optimal values for hyperparameters: {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 500}
# Best model score: -3561.044893987818

# %%
model = xgb.XGBRegressor(
                        n_estimators=500,
                        max_depth=10,
                        learning_rate=0.1,)
model.fit (recon_fea.iloc[train_index,:],original_m.iloc[train_index,:])
test_predict=model.predict(recon_fea.iloc[test_index,:])
msetest=mean_squared_error(recon_m.iloc[test_index,:],test_predict)
msetest
# Out:
# 995.4036443640572

# %%
parameters = {  'max_depth':[1, 2, 3, 5, 10],
    'learning_rate': [ 0.02, 0.05, 0.1, 0.15],
    'n_estimators': [ 100,200, 300, 500, 700],
    'min_child_weight': [0, 2, 5, 10, 20],
    #'max_delta_step': [0, 0.2, 0.6, 1, 2],
    'subsample': [0.6, 0.7, 0.8, 0.85, 0.95],
    'colsample_bytree': [0.5, 0.6, 0.7, 0.8, 0.9],
    'reg_alpha': [0, 0.25, 0.5, 0.75, 1],
    'reg_lambda': [0.2, 0.4, 0.6, 0.8, 1],
    'scale_pos_weight': [0.2, 0.4, 0.6, 0.8, 1],
    'gamma':[0,0.01,0.05,0.1,0.2,0.4,0.6]}  # Specify the range of hyperparameters in the model to reduce time spent

# %%
regran = xgb.XGBRegressor(eval_metric=mean_squared_error)  
Rgrid_search = HalvingRandomSearchCV(regran, parameters, scoring='neg_mean_squared_error', verbose=1,cv=None) 
Rgrid_search.fit(recon_fea.iloc[train_index,:],original_m.iloc[train_index,:]) 
print("Optimal values for hyperparameters:",Rgrid_search.best_params_)
print("Best model score:",Rgrid_search.best_score_)
# Out:
# n_iterations: 3
# n_required_iterations: 3
# n_possible_iterations: 3
# min_resources_: 10
# max_resources_: 182
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 18
# n_resources: 10
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# ----------
# iter: 1
# n_candidates: 6
# n_resources: 30
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# ----------
# iter: 2
# n_candidates: 2
# n_resources: 90
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# Optimal values for hyperparameters: {'subsample': 0.85, 'scale_pos_weight': 0.4, 'reg_lambda': 0.8, 'reg_alpha': 0.25, 'n_estimators': 700, 'min_child_weight': 0, 'max_depth': 10, 'learning_rate': 0.15, 'gamma': 0.1, 'colsample_bytree': 0.6}
# Best model score: -2778.3144430715665

# %%
model = xgb.XGBRegressor(subsample=0.85,
                        scale_pos_weight=0.4,
                        reg_lambda=0.8,
                        reg_alpha=0.25,
                        n_estimators=700,
                        min_child_weight=0,
                        max_depth=10,
                        learning_rate=0.15,
                        gamma=0.1,
                        colsample_bytree=0.6)
model.fit (recon_fea.iloc[train_index,:],original_m.iloc[train_index,:])
test_predict=model.predict(recon_fea.iloc[test_index,:])
msetest=mean_squared_error(recon_m.iloc[test_index,:],test_predict)
msetest
# Out:
# 780.6996577729249

# %%
from bayes_opt import BayesianOptimization
def rf_do(max_depth, learning_rate, n_estimators, min_child_weight, subsample, colsample_bytree,reg_alpha,reg_lambda,scale_pos_weight,gamma):
    val = xgb.XGBRegressor(max_depth = round(max_depth),
                           learning_rate = float(learning_rate),
                           n_estimators = round(n_estimators),
                           min_child_weight = round(min_child_weight),
                           #max_delta_step = float(max_delta_step),
                           subsample = float(subsample),
                           colsample_bytree = float(colsample_bytree),
                           reg_alpha = float(reg_alpha),
                           reg_lambda = float(reg_lambda),
                           scale_pos_weight = float(scale_pos_weight),
                           gamma = float(gamma),
                           eval_metric=mean_squared_error)
    msetest=0
    val.fit(recon_fea.iloc[train_index,:],original_m.iloc[train_index,:])
    test_predict=val.predict(recon_fea.iloc[test_index,:])
    msetest=-1*mean_squared_error(recon_m.iloc[test_index,:],test_predict)
    return msetest

# %%
rf_bo = BayesianOptimization(
        rf_do,
                {'max_depth':(1,20),
                'learning_rate': (0.01,0.3),
                'n_estimators': (100,1000),
                'min_child_weight': (0,2),
                #'max_delta_step': (0.01,1),
                'subsample':(0.5,1),
                'colsample_bytree': (0.5,1),
                'reg_alpha': (0.01,1),
                'reg_lambda': (0.2,1),
                'scale_pos_weight': (0.2,1),
                'gamma':(0,1)}
    )
rf_bo.maximize()#init_points=20, n_iter=10
rf_bo_p=rf_bo.max
rf_bo_p['params']['max_depth'] = round(rf_bo_p['params']['max_depth'])
rf_bo_p['params']['n_estimators'] = round(rf_bo_p['params']['n_estimators'])
rf_bo_p['params']['min_child_weight'] = round(rf_bo_p['params']['min_child_weight'])
rf_bo_p
# Out:
# |   iter    |  target   | colsam... |   gamma   | learni... | max_depth | min_ch... | n_esti... | reg_alpha | reg_la... | scale_... | subsample |
# -------------------------------------------------------------------------------------------------------------------------------------------------
# |  1        | -441.0    |  0.6203   |  0.5704   |  0.03025  |  14.65    |  0.08645  |  318.6    |  0.7491   |  0.3223   |  0.287    |  0.7322   |
# |  2        | -374.3    |  0.6896   |  0.5881   |  0.1938   |  16.42    |  0.9323   |  466.6    |  0.3568   |  0.6966   |  0.844    |  0.9698   |
# |  3        | -779.6    |  0.9149   |  0.8348   |  0.03916  |  5.852    |  0.2241   |  182.2    |  0.2168   |  0.9875   |  0.7148   |  0.9763   |
# |  4        | -324.2    |  0.8033   |  0.5671   |  0.0953   |  19.71    |  0.6189   |  854.0    |  0.02559  |  0.4716   |  0.5818   |  0.5792   |
# |  5        | -488.8    |  0.8727   |  0.7573   |  0.07298  |  12.66    |  0.119    |  755.2    |  0.7381   |  0.2775   |  0.7854   |  0.7436   |
# |  6        | -251.9    |  0.908    |  0.5342   |  0.06305  |  19.43    |  1.306    |  854.4    |  0.9309   |  0.326    |  0.8536   |  0.6453   |
# |  7        | -681.9    |  0.9804   |  0.7708   |  0.1021   |  15.88    |  1.53     |  857.3    |  0.9361   |  0.3855   |  0.6552   |  0.5064   |
# |  8        | -742.4    |  0.8081   |  0.2727   |  0.2482   |  18.45    |  0.7421   |  852.4    |  0.9985   |  0.908    |  0.6412   |  0.8191   |
# |  9        | -670.6    |  0.7729   |  0.6729   |  0.2801   |  19.99    |  0.08129  |  854.1    |  0.5037   |  0.6013   |  0.893    |  0.7788   |
# |  10       | -971.3    |  0.5575   |  0.7433   |  0.01071  |  7.212    |  1.583    |  510.6    |  0.1254   |  0.5832   |  0.694    |  0.8155   |
# |  11       | -457.0    |  0.5893   |  0.8153   |  0.08102  |  16.24    |  1.368    |  808.3    |  0.1513   |  0.7351   |  0.2036   |  0.6915   |
# |  12       | -266.5    |  0.7127   |  0.7281   |  0.1457   |  9.816    |  1.013    |  620.4    |  0.2198   |  0.5103   |  0.4512   |  0.5756   |
# |  13       | -1.379e+0 |  0.9142   |  0.4176   |  0.2442   |  13.05    |  1.324    |  408.1    |  0.2075   |  0.5448   |  0.3711   |  0.8459   |
# |  14       | -1.108e+0 |  0.8273   |  0.3704   |  0.02026  |  9.008    |  1.168    |  620.3    |  0.3046   |  0.7782   |  0.2431   |  0.9982   |
# |  15       | -999.0    |  0.9962   |  0.6781   |  0.198    |  19.42    |  0.09129  |  154.0    |  0.9182   |  0.2453   |  0.3533   |  0.608    |
# |  16       | -698.7    |  0.6545   |  0.5773   |  0.1526   |  12.57    |  0.09849  |  755.2    |  0.1549   |  0.3322   |  0.6955   |  0.902    |
# |  17       | -681.6    |  0.9464   |  0.1735   |  0.167    |  5.278    |  1.716    |  340.9    |  0.2418   |  0.6419   |  0.3505   |  0.8783   |
# |  18       | -1.183e+0 |  0.9103   |  0.7253   |  0.2088   |  13.01    |  0.5284   |  575.7    |  0.8899   |  0.4087   |  0.3607   |  0.5024   |
# |  19       | -979.1    |  0.5603   |  0.2947   |  0.04982  |  17.45    |  0.4664   |  736.4    |  0.6871   |  0.9649   |  0.556    |  0.7335   |
# |  20       | -464.4    |  0.9391   |  0.1373   |  0.07833  |  19.27    |  0.9109   |  854.1    |  0.7179   |  0.3725   |  0.8114   |  0.8306   |
# |  21       | -765.3    |  0.5522   |  0.2311   |  0.25     |  15.95    |  0.6273   |  466.8    |  0.7099   |  0.5949   |  0.3227   |  0.9286   |
# |  22       | -608.4    |  0.5156   |  0.6737   |  0.11     |  3.883    |  1.895    |  244.6    |  0.3839   |  0.6436   |  0.5801   |  0.7321   |
# |  23       | -1.034e+0 |  0.8504   |  0.3419   |  0.1443   |  9.661    |  0.6      |  620.2    |  0.1387   |  0.7379   |  0.3741   |  0.791    |
# |  24       | -427.0    |  0.5154   |  0.8044   |  0.2166   |  3.776    |  0.4437   |  812.4    |  0.3484   |  0.6719   |  0.647    |  0.9143   |
# |  25       | -469.3    |  0.6874   |  0.3937   |  0.05794  |  4.463    |  0.7013   |  768.9    |  0.3421   |  0.9027   |  0.6291   |  0.8128   |
# |  26       | -1.569e+0 |  0.9272   |  0.9437   |  0.2104   |  9.974    |  0.8449   |  319.2    |  0.3124   |  0.4037   |  0.4405   |  0.7856   |
# |  27       | -302.3    |  0.8222   |  0.2476   |  0.132    |  11.74    |  1.128    |  916.9    |  0.3595   |  0.5266   |  0.8437   |  0.5218   |
# |  28       | -482.3    |  0.973    |  0.03843  |  0.1486   |  15.45    |  0.5435   |  809.0    |  0.4618   |  0.5402   |  0.3741   |  0.6388   |
# |  29       | -576.5    |  0.6054   |  0.9441   |  0.1538   |  1.14     |  0.2048   |  215.5    |  0.4375   |  0.8403   |  0.3822   |  0.5499   |
# |  30       | -646.1    |  0.9632   |  0.9576   |  0.2748   |  5.858    |  0.2341   |  710.8    |  0.5019   |  0.5431   |  0.8983   |  0.81     |
# =================================================================================================================================================
# {'target': -251.93014526367188,
#  'params': {'colsample_bytree': 0.9080352920136778,
#   'gamma': 0.5341775846826899,
#   'learning_rate': 0.06304789710002581,
#   'max_depth': 19,
#   'min_child_weight': 1,
#   'n_estimators': 854,
#   'reg_alpha': 0.9308907782989828,
#   'reg_lambda': 0.3259806094858059,
#   'scale_pos_weight': 0.8536102714125846,
#   'subsample': 0.645306142522285}}

# %%
original_fea=features(original)
original_fea=original_fea.iloc[51:]
original_m=original.iloc[51::]
tscv = TimeSeriesSplit(n_splits=splits)
msetestav=0
for train_index, test_index in tscv.split(original_fea):
    model = xgb.XGBRegressor()
    model.fit (original_fea.iloc[train_index,:],original_m.iloc[train_index,:])
    test_predict=model.predict(original_fea.iloc[test_index,:])
    msetest=mean_squared_error(original_m.iloc[test_index,:],test_predict)
    i=1+int(len(train_index)/int(len(recon_fea)/splits))
    plt.figure(figsize=(10,15))
    plt.subplot(1 +splits,1,i)
    past=np.asarray(original_m.iloc[train_index,:]).reshape(len(original_m.iloc[train_index,:]))
    whole=np.concatenate((past, test_predict))
    true=np.asarray(original_m.iloc[test_index,:]).reshape(len(original_m.iloc[test_index,:]))
    whole_t=np.concatenate((past, true))
    plt.plot(whole,"r",label='Predicted')
    plt.plot(whole_t,"b",label='Original')
    plt.ylabel('TimeSeriesSplit'+str(i))
    msetestav+=msetest
msetestav=msetestav/splits
print('The last MSE:',msetest)
print('The average MSE:',msetestav)
# Out:
# The last MSE: 1896.106842233075
# The average MSE: 6788.943680778806

# %%
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV 
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingRandomSearchCV
from sklearn.model_selection import HalvingGridSearchCV
parameters = {  'max_depth': [1, 2, 3, 5, 10],
    'learning_rate': [ 0.02, 0.05, 0.1, 0.15],
  'n_estimators': [ 200, 300, 500, 700]}  # Specify the range of hyperparameters in the model to reduce time spent

# %%
# In the following we pass the data into the grid search model and output the hyperparameter optimal values.
reg = xgb.XGBRegressor(eval_metric=mean_squared_error)  # Building the model
grid_search = HalvingGridSearchCV(reg, parameters, scoring='neg_mean_squared_error',verbose=1,cv=None) 
grid_search.fit(original_fea.iloc[train_index,:],original_m.iloc[train_index,:])  # Input data
print("Optimal values for hyperparameters:",grid_search.best_params_)
print("Best model score:",grid_search.best_score_)
# Out:
# n_iterations: 3
# n_required_iterations: 4
# n_possible_iterations: 3
# min_resources_: 10
# max_resources_: 182
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 80
# n_resources: 10
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# ----------
# iter: 1
# n_candidates: 27
# n_resources: 30
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# ----------
# iter: 2
# n_candidates: 9
# n_resources: 90
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# Optimal values for hyperparameters: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200}
# Best model score: -5269.129959548923

# %%
model = xgb.XGBRegressor(
                        n_estimators=700,
                        max_depth=10,
                        learning_rate=0.02,)
model.fit (original_fea.iloc[train_index,:],original_m.iloc[train_index,:])
test_predict=model.predict(original_fea.iloc[test_index,:])
msetest=mean_squared_error(original_m.iloc[test_index,:],test_predict)
msetest
# Out:
# 2094.160648379061

# %%
parameters = {  'max_depth':[1, 2, 3, 5, 10],
    'learning_rate': [ 0.02, 0.05, 0.1, 0.15],
    'n_estimators': [ 100,200, 300, 500, 700],
    'min_child_weight': [0, 2, 5, 10, 20],
    'subsample': [0.6, 0.7, 0.8, 0.85, 0.95],
    'colsample_bytree': [0.5, 0.6, 0.7, 0.8, 0.9],
    'reg_alpha': [0, 0.25, 0.5, 0.75, 1],
    'reg_lambda': [0.2, 0.4, 0.6, 0.8, 1],
    'scale_pos_weight': [0.2, 0.4, 0.6, 0.8, 1],
    'gamma':[0,0.01,0.05,0.1,0.2,0.4,0.6]}  # Specify the range of hyperparameters in the model to reduce time spent

# %%
regran = xgb.XGBRegressor(eval_metric=mean_squared_error)  
Rgrid_search = HalvingRandomSearchCV(regran, parameters, scoring='neg_mean_squared_error', verbose=1,cv=None) 
Rgrid_search.fit(original_fea.iloc[train_index,:],original_m.iloc[train_index,:]) 
print("Optimal values for hyperparameters:",Rgrid_search.best_params_)
print("Best model score:",Rgrid_search.best_score_)
# Out:
# n_iterations: 3
# n_required_iterations: 3
# n_possible_iterations: 3
# min_resources_: 10
# max_resources_: 182
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 18
# n_resources: 10
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# ----------
# iter: 1
# n_candidates: 6
# n_resources: 30
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# ----------
# iter: 2
# n_candidates: 2
# n_resources: 90
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# Optimal values for hyperparameters: {'subsample': 0.6, 'scale_pos_weight': 0.2, 'reg_lambda': 0.6, 'reg_alpha': 0.75, 'n_estimators': 100, 'min_child_weight': 0, 'max_depth': 2, 'learning_rate': 0.1, 'gamma': 0.1, 'colsample_bytree': 0.7}
# Best model score: -4579.445191228546

# %%
model = xgb.XGBRegressor(subsample=0.6,
                        scale_pos_weight=1,
                        reg_lambda=0.8,
                        reg_alpha=1,
                        n_estimators=500,
                        min_child_weight=0,
                        max_depth=10,
                        learning_rate=0.05,
                        gamma=0,
                        colsample_bytree=0.5)
model.fit (original_fea.iloc[train_index,:],original_m.iloc[train_index,:])
test_predict=model.predict(original_fea.iloc[test_index,:])
msetest=mean_squared_error(original_m.iloc[test_index,:],test_predict)
msetest
# Out:
# 1422.358187529776

# %%
def rf_oo(max_depth, learning_rate, n_estimators, min_child_weight, subsample, colsample_bytree,reg_alpha,reg_lambda,scale_pos_weight,gamma):
    val = xgb.XGBRegressor(max_depth = round(max_depth),
                           learning_rate = float(learning_rate),
                           n_estimators = round(n_estimators),
                           min_child_weight = round(min_child_weight),
                           subsample = float(subsample),
                           colsample_bytree = float(colsample_bytree),
                           reg_alpha = float(reg_alpha),
                           reg_lambda = float(reg_lambda),
                           scale_pos_weight = float(scale_pos_weight),
                           gamma = float(gamma),
                           eval_metric=mean_squared_error)
    msetest=0
    val.fit(original_fea.iloc[train_index,:],original_m.iloc[train_index,:])
    test_predict=val.predict(original_fea.iloc[test_index,:])
    msetest=-1*mean_squared_error(original_m.iloc[test_index,:],test_predict)
    return msetest

# %%
rf_bo = BayesianOptimization(
        rf_oo,
                {'max_depth':(1,20),
                'learning_rate': (0.01,0.3),
                'n_estimators': (100,1000),
                'min_child_weight': (0,2),
                'subsample':(0.5,1),
                'colsample_bytree': (0.5,1),
                'reg_alpha': (0.01,1),
                'reg_lambda': (0.2,1),
                'scale_pos_weight': (0.2,1),
                'gamma':(0,1)}
    )
rf_bo.maximize()#init_points=20, n_iter=10
rf_bo_p=rf_bo.max
rf_bo_p['params']['max_depth'] = round(rf_bo_p['params']['max_depth'])
rf_bo_p['params']['n_estimators'] = round(rf_bo_p['params']['n_estimators'])
rf_bo_p['params']['min_child_weight'] = round(rf_bo_p['params']['min_child_weight'])
rf_bo_p
# Out:
# |   iter    |  target   | colsam... |   gamma   | learni... | max_depth | min_ch... | n_esti... | reg_alpha | reg_la... | scale_... | subsample |
# -------------------------------------------------------------------------------------------------------------------------------------------------
# |  1        | -1.307e+0 |  0.9389   |  0.9167   |  0.222    |  9.222    |  1.805    |  656.5    |  0.3327   |  0.7897   |  0.636    |  0.9047   |
# |  2        | -1.459e+0 |  0.5186   |  0.6218   |  0.2028   |  16.55    |  0.8087   |  561.5    |  0.2162   |  0.3867   |  0.5476   |  0.9483   |
# |  3        | -2.021e+0 |  0.9423   |  0.9186   |  0.1679   |  10.64    |  1.781    |  802.4    |  0.5805   |  0.3137   |  0.4861   |  0.5978   |
# |  4        | -1.821e+0 |  0.8926   |  0.8316   |  0.2646   |  4.732    |  0.2646   |  420.8    |  0.6113   |  0.9823   |  0.2979   |  0.6486   |
# |  5        | -1.476e+0 |  0.5876   |  0.1227   |  0.1232   |  17.55    |  0.9285   |  359.3    |  0.8218   |  0.4559   |  0.9478   |  0.7397   |
# |  6        | -983.1    |  0.9487   |  0.6807   |  0.2929   |  8.11     |  0.7767   |  656.4    |  0.8579   |  0.2839   |  0.829    |  0.7881   |
# |  7        | -839.5    |  0.8333   |  0.4791   |  0.08839  |  6.945    |  0.8601   |  655.5    |  0.04275  |  0.9887   |  0.341    |  0.9587   |
# |  8        | -2.033e+0 |  1.0      |  0.0      |  0.3      |  4.325    |  0.0      |  656.4    |  1.0      |  0.2      |  1.0      |  0.5      |
# |  9        | -2.15e+03 |  0.5279   |  0.4998   |  0.2351   |  7.393    |  0.01735  |  655.0    |  0.3349   |  0.9976   |  0.5594   |  0.6307   |
# |  10       | -2.031e+0 |  0.5926   |  0.09375  |  0.173    |  5.603    |  1.116    |  337.3    |  0.8632   |  0.2914   |  0.9351   |  0.5374   |
# |  11       | -1.333e+0 |  0.6263   |  0.1053   |  0.1387   |  16.78    |  0.7562   |  561.7    |  0.2219   |  0.9978   |  0.7362   |  0.6299   |
# |  12       | -734.3    |  0.5042   |  0.9283   |  0.07202  |  8.177    |  1.004    |  656.8    |  0.7059   |  0.9166   |  0.9987   |  0.8603   |
# |  13       | -1.364e+0 |  0.679    |  0.819    |  0.07934  |  7.519    |  1.001    |  657.0    |  0.423    |  0.3086   |  0.7877   |  0.5618   |
# |  14       | -1.092e+0 |  0.803    |  0.3911   |  0.1729   |  6.824    |  1.332    |  656.2    |  0.625    |  0.5362   |  0.2523   |  0.6044   |
# |  15       | -1.563e+0 |  0.7341   |  0.7217   |  0.09359  |  7.834    |  1.173    |  656.2    |  0.5644   |  1.0      |  0.71     |  1.0      |
# |  16       | -1.231e+0 |  0.893    |  0.8468   |  0.01252  |  17.84    |  0.5557   |  748.1    |  0.7727   |  0.2127   |  0.5736   |  0.6714   |
# |  17       | -1.013e+0 |  0.8175   |  0.6241   |  0.1282   |  14.94    |  0.9969   |  709.2    |  0.788    |  0.8684   |  0.6443   |  0.9025   |
# |  18       | -2.343e+0 |  0.9613   |  0.6012   |  0.05809  |  10.94    |  0.3385   |  702.0    |  0.9761   |  0.8658   |  0.4451   |  0.5133   |
# |  19       | -1.763e+0 |  0.9985   |  0.7339   |  0.2978   |  6.672    |  1.802    |  655.9    |  0.4275   |  0.9107   |  0.5822   |  0.6704   |
# |  20       | -770.2    |  0.6286   |  0.8344   |  0.1061   |  8.3      |  0.5778   |  656.8    |  0.6789   |  0.5408   |  0.3697   |  0.9888   |
# |  21       | -1.327e+0 |  0.7202   |  0.2801   |  0.06061  |  1.956    |  0.7961   |  785.4    |  0.4512   |  0.8514   |  0.3526   |  0.6824   |
# |  22       | -2.081e+0 |  0.9101   |  0.9619   |  0.09792  |  18.48    |  1.012    |  109.2    |  0.4026   |  0.8645   |  0.9409   |  0.7708   |
# |  23       | -2.002e+0 |  0.9667   |  0.4375   |  0.06087  |  9.765    |  1.681    |  106.6    |  0.6209   |  0.2191   |  0.7734   |  0.5525   |
# |  24       | -1.223e+0 |  0.6548   |  0.5393   |  0.07788  |  7.938    |  1.576    |  146.1    |  0.6964   |  0.3794   |  0.7545   |  0.9124   |
# |  25       | -1.066e+0 |  0.7466   |  0.7454   |  0.2495   |  9.749    |  0.5242   |  676.0    |  0.7268   |  0.7537   |  0.3399   |  0.7631   |
# |  26       | -1.121e+0 |  0.8585   |  0.8772   |  0.1325   |  8.427    |  0.5397   |  657.3    |  0.9011   |  0.3392   |  0.9455   |  0.9988   |
# |  27       | -1.688e+0 |  0.6302   |  0.7576   |  0.2323   |  1.06     |  1.767    |  626.4    |  0.8185   |  0.7764   |  0.3673   |  0.6727   |
# |  28       | -1.786e+0 |  0.9997   |  0.5321   |  0.1966   |  12.0     |  1.222    |  510.4    |  0.09324  |  0.6422   |  0.2303   |  0.7699   |
# |  29       | -807.3    |  0.5087   |  0.3582   |  0.2416   |  14.73    |  1.003    |  709.7    |  0.6435   |  0.7115   |  0.4926   |  0.6135   |
# |  30       | -1.51e+03 |  0.5398   |  0.8058   |  0.2931   |  14.78    |  1.62     |  709.8    |  0.7545   |  0.5686   |  0.7431   |  0.941    |
# =================================================================================================================================================
# {'target': -734.2657844656044,
#  'params': {'colsample_bytree': 0.5041942791325689,
#   'gamma': 0.9283181456648406,
#   'learning_rate': 0.07201947714853366,
#   'max_depth': 8,
#   'min_child_weight': 1,
#   'n_estimators': 657,
#   'reg_alpha': 0.7059443459309296,
#   'reg_lambda': 0.9166433175276387,
#   'scale_pos_weight': 0.9987457850419419,
#   'subsample': 0.860341189151195}}

# %% [markdown]
# # EMDCNN

# %%
# Log Returns
GSPC_test_n=GSPC_test.copy()
GSPC_test_n['log_ret'] = np.log(GSPC_test.iloc[:,0]).diff()
pure_mm_cnn['log_ret'] = np.log(pure_mm_cnn.iloc[:,0]).diff()


plt.figure(figsize=(20,4),dpi=200)
plt.subplot(1,2,1)
plt.plot(GSPC_test_n['log_ret'], 'r-', linewidth=2, label='Original log return')
plt.ylim(-0.1,0.1)
plt.title('log return of original data')
plt.legend(loc='best')

plt.subplot(1,2,2)
plt.plot(pure_mm_cnn['log_ret'] , 'b-', linewidth=2, label='Denoised log return')
plt.ylim(-0.1,0.1)
plt.title('log return of denoised data(CNN)')
plt.legend(loc='best')


plt.show()

# %%
def svmf1_ori(dataset,dataset2,long_predict=10,percentage=0.8):
    f11=np.empty(0)
    f12=np.empty(0)
    max_t=0
    if dataset['log_ret'].max()>dataset2['log_ret'].max():
        max_t=dataset2['log_ret'].max()
    else:
        max_t=dataset['log_ret'].max()
    for n in np.arange(0.0, (percentage*max_t), (percentage*max_t)/100):#get multiple threshold
        threshold = n
        # for dataset
        daily_label=np.empty(0)#make the data labelled
        for i in range(0,len(dataset)):
            if dataset.iloc[i,1]<-threshold:
                n=-1
                daily_label=np.append(daily_label,n)
            elif abs(dataset.iloc[i,1])<=threshold:
                n=0
                daily_label=np.append(daily_label,n)
            else:
                n=1
                daily_label=np.append(daily_label,n)
        X=pd.DataFrame()
        Y=pd.DataFrame()
        for i in range(1,len(dataset)-long_predict):
            X=pd.concat([X, pd.DataFrame(dataset.iloc[:,1].values[i:i+long_predict]).T],ignore_index=True)#n values of log return to predict trends
            Y=pd.concat([Y, pd.DataFrame(daily_label[i+long_predict:i+long_predict+1]).T],ignore_index=True)#labels of trends
        X=np.array(X)
        Y=np.array(Y[0])
        X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2,random_state=1,shuffle=False)
        svc_rbf = SVC(kernel='rbf',decision_function_shape='ovo')
        model = svc_rbf.fit(X_train,Y_train)
        Y_pred = model.predict(X_test)
        f1 = f1_score(Y_test,Y_pred,average='weighted')
        f11=np.append(f11,f1)
        
        # for dataset2
    for n in np.arange(0.0, (percentage*max_t), (percentage*max_t)/100):#get multiple threshold
        threshold = n
        daily_label2=np.empty(0)#make the data labelled
        for i in range(0,len(dataset2)):
            if dataset.iloc[i,1]<-threshold:
                n=-1
                daily_label2=np.append(daily_label2,n)
            elif abs(dataset.iloc[i,1])<=threshold:
                n=0
                daily_label2=np.append(daily_label2,n)
            else:
                n=1
                daily_label2=np.append(daily_label2,n)
        X=pd.DataFrame()
        Y=pd.DataFrame()
        for i in range(1,len(dataset2)-long_predict):
            X=pd.concat([X, pd.DataFrame(dataset2.iloc[:,1].values[i:i+long_predict]).T],ignore_index=True)#n values of log return to predict trends
            Y=pd.concat([Y, pd.DataFrame(daily_label2[i+long_predict:i+long_predict+1]).T],ignore_index=True)#labels of trends
        X=np.array(X)
        Y=np.array(Y[0])
        X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2,random_state=1,shuffle=False)
        svc_rbf = SVC(kernel='rbf',decision_function_shape='ovo')
        model = svc_rbf.fit(X_train,Y_train)
        Y_pred = model.predict(X_test)
        f1 = f1_score(Y_test,Y_pred,average='weighted')
        f12=np.append(f12,f1)
    return f11,f12

# %%
original_svm_ori,denoised_svm_ori=svmf1_ori(GSPC_test_n,pure_mm_cnn,long_predict=1,percentage=1)

# %%
plt.figure(figsize=(10,3),dpi=100)
percentage=1
max_t=0
if GSPC_test_n['log_ret'].max()>pure_mm_cnn['log_ret'].max():
    max_t=pure_mm_cnn['log_ret'].max()
else:
    max_t=GSPC_test_n['log_ret'].max()
plt.plot(np.arange(0.0,(percentage*max_t), (percentage*max_t)/100),original_svm_ori,label='orignal_svm', color='red', linewidth=1.0)
plt.plot(np.arange(0.0,(percentage*max_t), (percentage*max_t)/100),denoised_svm_ori,label='denoised_svm', color='blue', linewidth=1.0, linestyle='--')

plt.xticks(np.arange(0.0,(percentage*max_t), (percentage*max_t)/6))
plt.xlabel('threshold')
plt.ylabel('f1_value')
plt.legend()

# %% [markdown]
# ## Strategies

# %% [markdown]
# ## Bollinger band

# %%
def bbands(close_prices, window, no_of_stdev):#bollinger  bands, using today's closing price

    rolling_mean = close_prices.rolling(window,min_periods=1).mean()#.shift(1)
    rolling_std = close_prices.rolling(window,min_periods=1).std()#.shift(1)
    

    upper_band = rolling_mean + (rolling_std * no_of_stdev)
    lower_band = rolling_mean - (rolling_std * no_of_stdev)

    return rolling_mean, upper_band, lower_band

# %%
def buy_signal_function(dataset):
    buy_signal=pd.DataFrame(columns=['Price'],index=dataset.index)
    buy_signal['Price']=dataset['Adj Close']
    buy_signal['mean'],buy_signal['upper'],buy_signal['lower']=bbands(dataset['Adj Close'],20,2)
    buy_signal['side'] = np.nan 
    buy_signal['signal'] = np.nan 
    for i in range(0,len(dataset)):
        if (buy_signal.iloc[i,0]<buy_signal.iloc[i,3]):
            buy_signal.iloc[i,4]=1
            if (buy_signal.iloc[i-1,0]>=buy_signal.iloc[i-1,3]):
                buy_signal.iloc[i,5]=1
        elif (buy_signal.iloc[i,0]>buy_signal.iloc[i,2]):
            buy_signal.iloc[i,4]=-1
            if (buy_signal.iloc[i-1,0]<=buy_signal.iloc[i-1,2]):
                buy_signal.iloc[i,5]=-1
    return buy_signal

# %%
GSPC_test_signal=buy_signal_function(GSPC_test_n)


pure_mm_cnn_signal=buy_signal_function(pure_mm_cnn)

# %%
print('GSPC_test_signal:\n',GSPC_test_signal.signal.value_counts(),'\n')
print('pure_mm_cnn_signal:\n',pure_mm_cnn_signal.signal.value_counts(),'\n')
# Out:
# GSPC_test_signal:
#   1.0    8
# -1.0    4
# Name: signal, dtype: int64
#
# pure_mm_cnn_signal:
#   1.0    4
# -1.0    3
# Name: signal, dtype: int64

# %%
print(GSPC_test[GSPC_test_signal.signal == 1.0])
print(GSPC_test[pure_mm_cnn_signal.signal == 1.0])
# Out:
#               Adj Close
# Date
# 2018-06-25  2717.070068
# 2018-06-27  2699.629883
# 2018-10-10  2785.679932
# 2018-10-24  2656.100098
# 2018-12-17  2545.939941
# 2018-12-19  2506.959961
# 2019-05-13  2811.870117
# 2019-05-31  2752.060059
#               Adj Close
# Date
# 2018-10-08  2884.429932
# 2018-10-24  2656.100098
# 2018-12-17  2545.939941
# 2019-05-09  2870.719971

# %%
print(GSPC_test[GSPC_test_signal.signal == -1.0])
print(GSPC_test[pure_mm_cnn_signal.signal == -1.0])
# Out:
#               Adj Close
# Date
# 2018-08-27  2896.739990
# 2018-09-20  2930.750000
# 2019-03-18  2832.939941
# 2019-03-21  2854.879883
#               Adj Close
# Date
# 2018-08-07  2858.449951
# 2018-08-27  2896.739990
# 2019-03-15  2822.479980

# %%
plt.figure(figsize=(15,9),dpi=150)
plt.subplot(2,1,1)
plt.title('GSPC_test')
plt.plot(GSPC_test_signal['Price'], color='r', lw=1,label='Close')
plt.plot(GSPC_test_signal[['mean','upper','lower']], lw=1,label=['mean','upper','lower'])
plt.plot(GSPC_test_signal.loc[GSPC_test_signal.signal == 1.0].index, 
         GSPC_test_signal.Price[GSPC_test_signal.signal == 1.0],
         '^', markersize=5, color='m',label='long')
plt.plot(GSPC_test_signal.loc[GSPC_test_signal.signal == -1.0].index, 
         GSPC_test_signal.Price[GSPC_test_signal.signal == -1.0],
         'v', markersize=5, color='k',label='short')
plt.legend()         


plt.subplot(2,1,2)
plt.title('pure_mm_cnn_signal')
plt.plot(pure_mm_cnn_signal['Price'], color='r', lw=1,label='Close')
plt.plot(pure_mm_cnn_signal[['mean','upper','lower']], lw=1,label=['mean','upper','lower'])
plt.plot(pure_mm_cnn_signal.loc[pure_mm_cnn_signal.signal == 1.0].index, 
         pure_mm_cnn_signal.Price[pure_mm_cnn_signal.signal == 1.0],
         '^', markersize=5, color='m',label='long')
plt.plot(pure_mm_cnn_signal.loc[pure_mm_cnn_signal.signal == -1.0].index, 
         pure_mm_cnn_signal.Price[pure_mm_cnn_signal.signal == -1.0],
         'v', markersize=5, color='k',label='short')
plt.legend()

# %% [markdown]
# ## MACD

# %%
def MACD(dataset,short_window = 12,long_window = 26, signal_window=9):
    # Initiate short and long windows

    # Initialise the `signals` dataframe and add the `signal` column
    signals = pd.DataFrame(index=dataset.index)
    signals['signal'] = 0.0

    # Calculate short term moving averages
    signals['short_mavg'] = dataset['Adj Close'].ewm(span=short_window, min_periods=1).mean()

    # Calculate long term moving averages
    signals['long_mavg'] = dataset['Adj Close'].ewm(span=long_window, min_periods=1).mean()
    
    # Calculate DIF 
    signals['DIF'] = signals['short_mavg']-signals['long_mavg']
    
     # Calculate DIF moving averages
    signals['DEA'] = signals['DIF'].ewm(span=signal_window, min_periods=1).mean()

    # Generate signal
    signals['signal'] = np.where(signals['DIF']> signals['DEA'], 1.0, 0.0)   

    # Generate trading orders
    signals['positions'] = signals['signal'].diff()
    return signals

# %%
GSPC_test_macd=MACD(GSPC_test_n,short_window = 14,long_window = 22)
pure_mm_cnn_macd=MACD(pure_mm_cnn,short_window = 14,long_window = 22)
#pure_mm_lstm_macd=MACD(pure_mm_lstm,short_window = 14,long_window = 22)

plt.figure(figsize=(15,9),dpi=150)
plt.subplot(2,1,1)
plt.title('GSPC_test')
plt.plot(GSPC_test_n['Adj Close'], color='r', lw=1,label='Close')
plt.plot(GSPC_test_macd[['short_mavg', 'long_mavg']], lw=2,label=['short_mavg', 'long_mavg'])
plt.plot(GSPC_test_macd.loc[GSPC_test_macd.positions == 1.0].index, 
         GSPC_test_macd.short_mavg[GSPC_test_macd.positions == 1.0],
         '^', markersize=5, color='m',label='long')
plt.plot(GSPC_test_macd.loc[GSPC_test_macd.positions == -1.0].index, 
         GSPC_test_macd.short_mavg[GSPC_test_macd.positions == -1.0],
         'v', markersize=5, color='k',label='short')
plt.legend()         


plt.subplot(2,1,2)
plt.title('pure_mm_cnn')
plt.plot(pure_mm_cnn['Adj Close'], color='r', lw=1,label='Close')
plt.plot(pure_mm_cnn_macd[['short_mavg', 'long_mavg']], lw=2,label=['short_mavg', 'long_mavg'])
plt.plot(pure_mm_cnn_macd.loc[pure_mm_cnn_macd.positions == 1.0].index, 
         pure_mm_cnn_macd.short_mavg[pure_mm_cnn_macd.positions == 1.0],
         '^', markersize=5, color='m',label='long')
plt.plot(pure_mm_cnn_macd.loc[pure_mm_cnn_macd.positions == -1.0].index, 
         pure_mm_cnn_macd.short_mavg[pure_mm_cnn_macd.positions == -1.0],
         'v', markersize=5, color='k',label='short')
plt.legend()

# %%
print('GSPC_test_macd:\n',GSPC_test_macd.positions.value_counts(),'\n')
print('pure_mm_cnn_macd:\n',pure_mm_cnn_macd.positions.value_counts(),'\n')
# Out:
# GSPC_test_macd:
#   0.0    226
#  1.0     12
# -1.0     12
# Name: positions, dtype: int64
#
# pure_mm_cnn_macd:
#   0.0    234
#  1.0      8
# -1.0      8
# Name: positions, dtype: int64

# %%
print(GSPC_test[GSPC_test_macd['positions']==1])
print(GSPC_test[pure_mm_cnn_macd['positions']==1])
# Out:
#               Adj Close
# Date
# 2018-06-04  2746.870117
# 2018-07-06  2759.820068
# 2018-08-03  2840.350098
# 2018-08-22  2861.820068
# 2018-08-24  2874.689941
# 2018-09-20  2930.750000
# 2018-11-02  2723.060059
# 2018-11-28  2743.790039
# 2019-01-02  2510.030029
# 2019-03-19  2832.570068
# 2019-04-02  2867.239990
# 2019-04-23  2933.679932
#               Adj Close
# Date
# 2018-06-04  2746.870117
# 2018-07-06  2759.820068
# 2018-08-03  2840.350098
# 2018-08-24  2874.689941
# 2018-11-02  2723.060059
# 2018-11-28  2743.790039
# 2019-01-03  2447.889893
# 2019-04-03  2873.399902

# %%
print(GSPC_test[GSPC_test_macd['positions']==-1])
print(GSPC_test[pure_mm_cnn_macd['positions']==-1])
# Out:
#               Adj Close
# Date
# 2018-06-19  2762.590088
# 2018-08-01  2813.360107
# 2018-08-13  2821.929932
# 2018-08-23  2856.979980
# 2018-09-06  2878.050049
# 2018-09-26  2905.969971
# 2018-11-20  2641.889893
# 2018-12-10  2637.719971
# 2019-02-28  2784.489990
# 2019-03-22  2800.709961
# 2019-04-18  2905.030029
# 2019-05-01  2923.729980
#               Adj Close
# Date
# 2018-06-18  2773.750000
# 2018-08-01  2813.360107
# 2018-08-10  2833.280029
# 2018-09-05  2888.600098
# 2018-11-19  2690.729980
# 2018-12-10  2637.719971
# 2019-02-28  2784.489990
# 2019-04-12  2907.409912

# %% [markdown]
# ## MA

# %%
def MA(dataset,short_window = 10,long_window = 50):
    # Initiate short and long windows

    # Initialise the `signals` dataframe and add the `signal` column
    signals = pd.DataFrame(index=dataset.index)
    signals['signal'] = 0.0

    # Calculate short term simple moving averages
    signals['short_mavg'] = dataset['Adj Close'].rolling(window=short_window, min_periods=1).mean()

    # Calculate long term simple moving averages
    signals['long_mavg'] = dataset['Adj Close'].rolling(window=long_window, min_periods=1).mean()

    # Generate signal
    signals['signal'][short_window:] = np.where(signals['short_mavg'][short_window:] 
                                                > signals['long_mavg'][short_window:], 1.0, 0.0)   

    # Generate trading orders
    signals['positions'] = signals['signal'].diff()
    return signals

# %%
GSPC_test_ma=MA(GSPC_test,short_window = 10,long_window = 50)
pure_mm_cnn_ma=MA(pure_mm_cnn,short_window = 10,long_window = 50)
#pure_mm_lstm_ma=MA(pure_mm_lstm,short_window = 10,long_window = 50)

plt.figure(figsize=(15,9),dpi=150)
plt.subplot(3,1,1)
plt.title('GSPC_test')
plt.plot(GSPC_test['Adj Close'], color='r', lw=1,label='Close')
plt.plot(GSPC_test_ma[['short_mavg', 'long_mavg']], lw=2,label=['short_mavg', 'long_mavg'])
plt.plot(GSPC_test_ma.loc[GSPC_test_ma.positions == 1.0].index, 
         GSPC_test_ma.short_mavg[GSPC_test_ma.positions == 1.0],
         '^', markersize=5, color='m',label='long')
plt.plot(GSPC_test_ma.loc[GSPC_test_ma.positions == -1.0].index, 
         GSPC_test_ma.short_mavg[GSPC_test_ma.positions == -1.0],
         'v', markersize=5, color='k',label='short')
plt.legend()         


plt.subplot(3,1,2)
plt.title('pure_mm_cnn')
plt.plot(pure_mm_cnn['Adj Close'], color='r', lw=1,label='Close')
plt.plot(pure_mm_cnn_ma[['short_mavg', 'long_mavg']], lw=2,label=['short_mavg', 'long_mavg'])
plt.plot(pure_mm_cnn_ma.loc[pure_mm_cnn_ma.positions == 1.0].index, 
         pure_mm_cnn_ma.short_mavg[pure_mm_cnn_ma.positions == 1.0],
         '^', markersize=5, color='m',label='long')
plt.plot(pure_mm_cnn_ma.loc[pure_mm_cnn_ma.positions == -1.0].index, 
         pure_mm_cnn_ma.short_mavg[pure_mm_cnn_ma.positions == -1.0],
         'v', markersize=5, color='k',label='short')
plt.legend()

# %%
print('GSPC_test_ma:\n',GSPC_test_ma.positions.value_counts(),'\n')
print('pure_mm_cnn_ma:\n',pure_mm_cnn_ma.positions.value_counts(),'\n')
# Out:
# GSPC_test_ma:
#   0.0    244
#  1.0      3
# -1.0      3
# Name: positions, dtype: int64
#
# pure_mm_cnn_ma:
#   0.0    244
#  1.0      3
# -1.0      3
# Name: positions, dtype: int64

# %%
print(GSPC_test[GSPC_test_ma['positions']==1])
print(GSPC_test[pure_mm_cnn_ma['positions']==1])
# Out:
#               Adj Close
# Date
# 2018-06-15  2779.659912
# 2018-07-13  2801.310059
# 2019-01-24  2642.330078
#               Adj Close
# Date
# 2018-06-15  2779.659912
# 2018-07-12  2798.290039
# 2019-01-24  2642.330078

# %%
print(GSPC_test[GSPC_test_ma['positions']==-1])
print(GSPC_test[pure_mm_cnn_ma['positions']==-1])
# Out:
#               Adj Close
# Date
# 2018-06-26  2723.060059
# 2018-10-11  2728.370117
# 2019-05-17  2859.530029
#               Adj Close
# Date
# 2018-06-28  2716.310059
# 2018-10-11  2728.370117
# 2019-05-20  2840.229980

# %% [markdown]
# # Only emd

# %%
emdre=emd_calculate(GSPC_test)
reedm=reconstruction(emdre)

# %%
pure_mm_cnn=pd.DataFrame(reedm.iloc[1,:]).rename(columns={'sum1':'Adj Close'})
pure_mm_cnn
# Out:
#               Adj Close
# Date
# 2018-06-01  2737.099396
# 2018-06-04  2742.196722
# 2018-06-05  2753.754986
# 2018-06-06  2766.825349
# 2018-06-07  2776.308263
# ...                 ...
# 2019-05-24  2818.127094
# 2019-05-28  2806.287141
# 2019-05-29  2793.139232
# 2019-05-30  2777.063424
# 2019-05-31  2764.700316
#
# [251 rows x 1 columns]

# %%
# Log Returns
GSPC_test_n=GSPC_test.copy()
GSPC_test_n['log_ret'] = np.log(GSPC_test.iloc[:,0]).diff()
pure_mm_cnn['log_ret'] = np.log(pure_mm_cnn.iloc[:,0]).diff()


plt.figure(figsize=(20,4),dpi=200)
plt.subplot(1,2,1)
plt.plot(GSPC_test_n['log_ret'], 'r-', linewidth=2, label='Original log return')
plt.ylim(-0.2,0.2)
plt.title('log return of original data')
plt.legend(loc='best')

plt.subplot(1,2,2)
plt.plot(pure_mm_cnn['log_ret'] , 'b-', linewidth=2, label='Denoised log return')
plt.ylim(-0.2,0.2)
plt.title('log return of denoised data(CNN)')
plt.legend(loc='best')


plt.show()

# %%
original=pd.DataFrame(GSPC_test['Adj Close'])
recon=pd.DataFrame(pure_mm_cnn['Adj Close'])

# %%
def features(dataset):
    ret_dataset=pd.DataFrame(index=dataset.index)
    for i in range(2,52,1):
        window = i
        # Volatility
        ret_dataset[str('SMA'+str(i))] = talib.SMA(dataset['Adj Close'],timeperiod=window).shift(1)
        ret_dataset[str('EMA'+str(i))] = talib.EMA(dataset['Adj Close'],timeperiod=window).shift(1)
        ret_dataset[str('STDDEV'+str(i))] = talib.STDDEV(dataset['Adj Close'],timeperiod=window).shift(1)
        ret_dataset[str('Lag'+str(i))] = dataset['Adj Close'].shift(i)
    return ret_dataset

# %%
from sklearn.model_selection import TimeSeriesSplit
import xgboost as xgb
import talib
splits=10

# %%
recon_fea=features(recon)
recon_fea=recon_fea.iloc[51:]
original_m=original.iloc[51::]
recon_m=recon.iloc[51::]
tscv = TimeSeriesSplit(n_splits=splits)
msetestav=0

for train_index, test_index in tscv.split(recon_fea):
    model = xgb.XGBRegressor()
    model.fit(recon_fea.iloc[train_index,:],original_m.iloc[train_index,:])
    test_predict=model.predict(recon_fea.iloc[test_index,:])
    msetest=mean_squared_error(original_m.iloc[test_index,:],test_predict)
    i=1+int(len(train_index)/int(len(recon_fea)/splits))
    plt.figure(figsize=(10,15))
    plt.subplot(1 +splits,1,i)
    past=np.asarray(original_m.iloc[train_index,:]).reshape(len(original_m.iloc[train_index,:]))
    whole=np.concatenate((past, test_predict))
    true=np.asarray(original_m.iloc[test_index,:]).reshape(len(original_m.iloc[test_index,:]))
    whole_t=np.concatenate((past, true))
    plt.plot(whole,"r",label='Predicted')
    plt.plot(whole_t,"b",label='Original')
    plt.ylabel('TimeSeriesSplit'+str(i))
    print(msetest)
    msetestav+=msetest
msetestav=msetestav/splits
print('The last MSE:',msetest)
print('The average MSE:',msetestav)
# Out:
# 1067.3863187001812
# 18756.494846337373
# 3154.2294611103007
# 18494.587710761363
# 11201.449254436626
# 945.2297269602617
# 895.3407976064417
# 1517.8915586305989
# 1618.0559349225628
# 605.3924884630574
# The last MSE: 605.3924884630574
# The average MSE: 5825.605809792876

# %%
from bayes_opt import BayesianOptimization
def rf_do(max_depth, learning_rate, n_estimators, min_child_weight, subsample, colsample_bytree,reg_alpha,reg_lambda,scale_pos_weight,gamma):
    val = xgb.XGBRegressor(max_depth = round(max_depth),
                           learning_rate = float(learning_rate),
                           n_estimators = round(n_estimators),
                           min_child_weight = round(min_child_weight),
                           #max_delta_step = float(max_delta_step),
                           subsample = float(subsample),
                           colsample_bytree = float(colsample_bytree),
                           reg_alpha = float(reg_alpha),
                           reg_lambda = float(reg_lambda),
                           scale_pos_weight = float(scale_pos_weight),
                           gamma = float(gamma),
                           eval_metric=mean_squared_error)
    msetest=0
    val.fit(recon_fea.iloc[train_index,:],original_m.iloc[train_index,:])
    test_predict=val.predict(recon_fea.iloc[test_index,:])
    msetest=-1*mean_squared_error(recon_m.iloc[test_index,:],test_predict)
    return msetest

# %%
rf_bo = BayesianOptimization(
        rf_do,
                {'max_depth':(1,20),
                'learning_rate': (0.01,0.3),
                'n_estimators': (100,1000),
                'min_child_weight': (0,2),
                #'max_delta_step': (0.01,1),
                'subsample':(0.5,1),
                'colsample_bytree': (0.5,1),
                'reg_alpha': (0.01,1),
                'reg_lambda': (0.2,1),
                'scale_pos_weight': (0.2,1),
                'gamma':(0,1)}
    )
rf_bo.maximize()#init_points=20, n_iter=10
rf_bo_p=rf_bo.max
rf_bo_p['params']['max_depth'] = round(rf_bo_p['params']['max_depth'])
rf_bo_p['params']['n_estimators'] = round(rf_bo_p['params']['n_estimators'])
rf_bo_p['params']['min_child_weight'] = round(rf_bo_p['params']['min_child_weight'])
rf_bo_p
# Out:
# |   iter    |  target   | colsam... |   gamma   | learni... | max_depth | min_ch... | n_esti... | reg_alpha | reg_la... | scale_... | subsample |
# -------------------------------------------------------------------------------------------------------------------------------------------------
# |  1        | -485.7    |  0.6411   |  0.9161   |  0.02306  |  10.1     |  1.371    |  304.2    |  0.3117   |  0.6275   |  0.8036   |  0.5276   |
# |  2        | -1.132e+0 |  0.9504   |  0.06791  |  0.2623   |  3.543    |  1.987    |  721.6    |  0.6534   |  0.9939   |  0.4252   |  0.5617   |
# |  3        | -686.7    |  0.7514   |  0.4892   |  0.1645   |  2.085    |  1.972    |  474.6    |  0.8269   |  0.3413   |  0.5829   |  0.9463   |
# |  4        | -819.5    |  0.5062   |  0.7416   |  0.229    |  2.147    |  0.7528   |  120.4    |  0.9051   |  0.8915   |  0.4326   |  0.8048   |
# |  5        | -826.1    |  0.755    |  0.3595   |  0.1768   |  7.23     |  1.651    |  439.3    |  0.3839   |  0.894    |  0.2932   |  0.8007   |
# |  6        | -792.2    |  0.8434   |  0.5374   |  0.2602   |  9.56     |  0.3675   |  304.3    |  0.5399   |  0.6175   |  0.4423   |  0.9562   |
# |  7        | -1.31e+03 |  0.9032   |  0.6974   |  0.154    |  2.47     |  1.081    |  699.6    |  0.06384  |  0.8719   |  0.4127   |  0.5517   |
# |  8        | -1.058e+0 |  0.6742   |  0.8519   |  0.2715   |  10.77    |  1.5      |  304.9    |  0.3658   |  0.446    |  0.5443   |  0.6045   |
# |  9        | -493.3    |  0.8678   |  0.9219   |  0.01231  |  18.05    |  0.8241   |  981.4    |  0.2216   |  0.7368   |  0.2403   |  0.8262   |
# |  10       | -616.4    |  0.6743   |  0.8213   |  0.1594   |  9.302    |  0.1983   |  909.0    |  0.2341   |  0.8671   |  0.4395   |  0.6947   |
# |  11       | -654.0    |  0.8767   |  0.9421   |  0.2389   |  13.17    |  0.1549   |  544.3    |  0.6784   |  0.6119   |  0.3204   |  0.5373   |
# |  12       | -433.4    |  0.9304   |  0.09147  |  0.2604   |  11.27    |  1.398    |  174.8    |  0.4161   |  0.4218   |  0.5927   |  0.7984   |
# |  13       | -1.154e+0 |  0.6445   |  0.6896   |  0.2709   |  16.76    |  0.906    |  528.3    |  0.2994   |  0.3587   |  0.8938   |  0.9203   |
# |  14       | -684.9    |  0.6842   |  0.5872   |  0.1136   |  9.834    |  1.763    |  250.4    |  0.9566   |  0.637    |  0.2946   |  0.6102   |
# |  15       | -1.016e+0 |  0.8518   |  0.2223   |  0.1316   |  6.619    |  1.938    |  565.4    |  0.1434   |  0.9397   |  0.5774   |  0.7676   |
# |  16       | -1.291e+0 |  0.6699   |  0.6735   |  0.2792   |  15.64    |  1.394    |  165.1    |  0.9894   |  0.5962   |  0.3943   |  0.6806   |
# |  17       | -864.3    |  0.767    |  0.4017   |  0.1912   |  9.541    |  0.2696   |  908.2    |  0.2378   |  0.881    |  0.9375   |  0.5037   |
# |  18       | -990.3    |  0.8357   |  0.7643   |  0.018    |  2.816    |  0.4091   |  300.1    |  0.4492   |  0.849    |  0.99     |  0.9807   |
# |  19       | -343.5    |  0.976    |  0.6867   |  0.1233   |  10.9     |  1.443    |  870.1    |  0.4882   |  0.7001   |  0.3301   |  0.5831   |
# |  20       | -537.4    |  0.9918   |  0.1072   |  0.2866   |  10.35    |  1.086    |  938.1    |  0.6106   |  0.6052   |  0.2306   |  0.8555   |
# |  21       | -1.119e+0 |  0.6123   |  0.8691   |  0.2629   |  6.144    |  0.2738   |  843.4    |  0.2048   |  0.2408   |  0.855    |  0.9073   |
# |  22       | -1.289e+0 |  0.622    |  0.9859   |  0.1615   |  3.623    |  1.475    |  314.3    |  0.7212   |  0.4287   |  0.8914   |  0.7516   |
# |  23       | -1.24e+03 |  0.852    |  0.6137   |  0.2147   |  19.76    |  1.202    |  736.6    |  0.9468   |  0.3066   |  0.7356   |  0.5267   |
# |  24       | -1.112e+0 |  0.9859   |  0.02436  |  0.09854  |  1.054    |  0.5352   |  688.0    |  0.5121   |  0.735    |  0.3242   |  0.9893   |
# |  25       | -1.531e+0 |  0.518    |  0.9646   |  0.2207   |  1.686    |  0.1201   |  192.2    |  0.4792   |  0.5471   |  0.5654   |  0.8466   |
# |  26       | -461.4    |  0.9988   |  0.9129   |  0.1101   |  15.19    |  0.8794   |  327.9    |  0.08459  |  0.4345   |  0.6827   |  0.8304   |
# |  27       | -926.4    |  0.8621   |  0.6588   |  0.1193   |  18.29    |  1.786    |  831.5    |  0.5335   |  0.7096   |  0.6817   |  0.9992   |
# |  28       | -1.705e+0 |  0.5315   |  0.6188   |  0.2665   |  4.385    |  0.5866   |  508.1    |  0.2805   |  0.7533   |  0.2413   |  0.5239   |
# |  29       | -483.7    |  0.933    |  0.9847   |  0.09125  |  2.747    |  1.677    |  271.2    |  0.2313   |  0.5966   |  0.756    |  0.6036   |
# |  30       | -568.7    |  0.7888   |  0.3785   |  0.09252  |  14.79    |  0.3602   |  917.4    |  0.541    |  0.9397   |  0.3366   |  0.6984   |
# =================================================================================================================================================
# {'target': -343.4975720002178,
#  'params': {'colsample_bytree': 0.9759672227092321,
#   'gamma': 0.6866678755457315,
#   'learning_rate': 0.12334533922447219,
#   'max_depth': 11,
#   'min_child_weight': 1,
#   'n_estimators': 870,
#   'reg_alpha': 0.4882242253549184,
#   'reg_lambda': 0.7001027874597208,
#   'scale_pos_weight': 0.3301378540858019,
#   'subsample': 0.5831437040935257}}

# %%
original_fea=features(original)
original_fea=original_fea.iloc[51:]
original_m=original.iloc[51::]
tscv = TimeSeriesSplit(n_splits=splits)
msetestav=0
for train_index, test_index in tscv.split(original_fea):
    model = xgb.XGBRegressor()
    model.fit (original_fea.iloc[train_index,:],original_m.iloc[train_index,:])
    test_predict=model.predict(original_fea.iloc[test_index,:])
    msetest=mean_squared_error(original_m.iloc[test_index,:],test_predict)
    i=1+int(len(train_index)/int(len(recon_fea)/splits))
    plt.figure(figsize=(10,15))
    plt.subplot(1 +splits,1,i)
    past=np.asarray(original_m.iloc[train_index,:]).reshape(len(original_m.iloc[train_index,:]))
    whole=np.concatenate((past, test_predict))
    true=np.asarray(original_m.iloc[test_index,:]).reshape(len(original_m.iloc[test_index,:]))
    whole_t=np.concatenate((past, true))
    plt.plot(whole,"r",label='Predicted')
    plt.plot(whole_t,"b",label='Original')
    plt.ylabel('TimeSeriesSplit'+str(i))
    print(msetest)
    msetestav+=msetest
msetestav=msetestav/splits
print('The last MSE:',msetest)
print('The average MSE:',msetestav)
# Out:
# 982.0803887678517
# 20546.38716178139
# 3796.9784186018837
# 24085.62260669801
# 8463.652027852006
# 1464.257284141249
# 1930.2761801977952
# 1641.761314455006
# 3082.314583059814
# 1896.106842233075
# The last MSE: 1896.106842233075
# The average MSE: 6788.943680778806

# %%
def svmf1_ori(dataset,dataset2,long_predict=10,percentage=1):
    f11=np.empty(0)
    f12=np.empty(0)
    max_t=0
    if dataset['log_ret'].max()>dataset2['log_ret'].max():
        max_t=dataset2['log_ret'].max()
    else:
        max_t=dataset['log_ret'].max()
    for n in np.arange(0.0, (percentage*max_t), (percentage*max_t)/100):#get multiple threshold
        threshold = n
        # for dataset
        daily_label=np.empty(0)#make the data labelled
        for i in range(0,len(dataset)):
            if dataset.iloc[i,1]<-threshold:
                n=-1
                daily_label=np.append(daily_label,n)
            elif abs(dataset.iloc[i,1])<=threshold:
                n=0
                daily_label=np.append(daily_label,n)
            else:
                n=1
                daily_label=np.append(daily_label,n)
        X=pd.DataFrame()
        Y=pd.DataFrame()
        for i in range(1,len(dataset)-long_predict):
            X=pd.concat([X, pd.DataFrame(dataset.iloc[:,1].values[i:i+long_predict]).T],ignore_index=True)#n values of log return to predict trends
            Y=pd.concat([Y, pd.DataFrame(daily_label[i+long_predict:i+long_predict+1]).T],ignore_index=True)#labels of trends
        X=np.array(X)
        Y=np.array(Y[0])
        X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2,random_state=1,shuffle=False)
        svc_rbf = SVC(kernel='rbf',decision_function_shape='ovo')
        model = svc_rbf.fit(X_train,Y_train)
        Y_pred = model.predict(X_test)
        f1 = f1_score(Y_test,Y_pred,average='weighted')
        f11=np.append(f11,f1)
        
        # for dataset2
    for n in np.arange(0.0, (0.5*max_t), (0.5*max_t)/100):#get multiple threshold
        threshold = n
        daily_label2=np.empty(0)#make the data labelled
        for i in range(0,len(dataset2)):
            if dataset.iloc[i,1]<-threshold:
                n=-1
                daily_label2=np.append(daily_label2,n)
            elif abs(dataset.iloc[i,1])<=threshold:
                n=0
                daily_label2=np.append(daily_label2,n)
            else:
                n=1
                daily_label2=np.append(daily_label2,n)
        X=pd.DataFrame()
        Y=pd.DataFrame()
        for i in range(1,len(dataset2)-long_predict):
            X=pd.concat([X, pd.DataFrame(dataset2.iloc[:,1].values[i:i+long_predict]).T],ignore_index=True)#n values of log return to predict trends
            Y=pd.concat([Y, pd.DataFrame(daily_label2[i+long_predict:i+long_predict+1]).T],ignore_index=True)#labels of trends
        X=np.array(X)
        Y=np.array(Y[0])
        X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2,random_state=1,shuffle=False)
        svc_rbf = SVC(kernel='rbf',decision_function_shape='ovo')
        model = svc_rbf.fit(X_train,Y_train)
        Y_pred = model.predict(X_test)
        f1 = f1_score(Y_test,Y_pred,average='weighted')
        f12=np.append(f12,f1)
    return f11,f12

# %%
original_svm_ori,denoised_svm_ori=svmf1_ori(GSPC_test_n,pure_mm_cnn,long_predict=1)

# %%
plt.figure(figsize=(10,3),dpi=100)
percentage=1
max_t=0
if GSPC_test_n['log_ret'].max()>pure_mm_cnn['log_ret'].max():
    max_t=pure_mm_cnn['log_ret'].max()
else:
    max_t=GSPC_test_n['log_ret'].max()
plt.plot(np.arange(0.0,(percentage*max_t), (percentage*max_t)/100),original_svm_ori,label='orignal_svm', color='red', linewidth=1.0)
plt.plot(np.arange(0.0,(percentage*max_t), (percentage*max_t)/100),denoised_svm_ori,label='denoised_svm', color='blue', linewidth=1.0, linestyle='--')

plt.xticks(np.arange(0.0,(percentage*max_t), (percentage*max_t)/6))
plt.xlabel('threshold')
plt.ylabel('f1_value')
plt.legend()

# %% [markdown]
# ## Strategies

# %% [markdown]
# ## Bollinger band

# %%
def bbands(close_prices, window, no_of_stdev):#bollinger  bands, using today's closing price

    rolling_mean = close_prices.rolling(window,min_periods=1).mean()#.shift(1)
    rolling_std = close_prices.rolling(window,min_periods=1).std()#.shift(1)
    

    upper_band = rolling_mean + (rolling_std * no_of_stdev)
    lower_band = rolling_mean - (rolling_std * no_of_stdev)

    return rolling_mean, upper_band, lower_band

# %%
def buy_signal_function(dataset):
    buy_signal=pd.DataFrame(columns=['Price'],index=dataset.index)
    buy_signal['Price']=dataset['Adj Close']
    buy_signal['mean'],buy_signal['upper'],buy_signal['lower']=bbands(dataset['Adj Close'],20,2)
    buy_signal['side'] = np.nan 
    buy_signal['signal'] = np.nan 
    for i in range(0,len(dataset)):
        if (buy_signal.iloc[i,0]<buy_signal.iloc[i,3]):
            buy_signal.iloc[i,4]=1
            if (buy_signal.iloc[i-1,0]>=buy_signal.iloc[i-1,3]):
                buy_signal.iloc[i,5]=1
        elif (buy_signal.iloc[i,0]>buy_signal.iloc[i,2]):
            buy_signal.iloc[i,4]=-1
            if (buy_signal.iloc[i-1,0]<=buy_signal.iloc[i-1,2]):
                buy_signal.iloc[i,5]=-1
    return buy_signal

# %%
pure_mm_cnn
# Out:
#               Adj Close   log_ret
# Date
# 2018-06-01  2737.099396       NaN
# 2018-06-04  2742.196722  0.001861
# 2018-06-05  2753.754986  0.004206
# 2018-06-06  2766.825349  0.004735
# 2018-06-07  2776.308263  0.003422
# ...                 ...       ...
# 2019-05-24  2818.127094 -0.004664
# 2019-05-28  2806.287141 -0.004210
# 2019-05-29  2793.139232 -0.004696
# 2019-05-30  2777.063424 -0.005772
# 2019-05-31  2764.700316 -0.004462
#
# [251 rows x 2 columns]

# %%
GSPC_test_signal=buy_signal_function(GSPC_test_n)


pure_mm_cnn_signal=buy_signal_function(pure_mm_cnn)

# %%
print('GSPC_test_signal:\n',GSPC_test_signal.signal.value_counts(),'\n')
print('pure_mm_cnn_signal:\n',pure_mm_cnn_signal.signal.value_counts(),'\n')
# Out:
# GSPC_test_signal:
#   1.0    8
# -1.0    4
# Name: signal, dtype: int64
#
# pure_mm_cnn_signal:
#  -1.0    5
#  1.0    4
# Name: signal, dtype: int64

# %%
print(GSPC_test[GSPC_test_signal.signal == 1.0])
print(GSPC_test[pure_mm_cnn_signal.signal == 1.0])
# Out:
#               Adj Close
# Date
# 2018-06-25  2717.070068
# 2018-06-27  2699.629883
# 2018-10-10  2785.679932
# 2018-10-24  2656.100098
# 2018-12-17  2545.939941
# 2018-12-19  2506.959961
# 2019-05-13  2811.870117
# 2019-05-31  2752.060059
#               Adj Close
# Date
# 2018-06-25  2717.070068
# 2018-10-09  2880.340088
# 2018-12-18  2546.159912
# 2019-05-09  2870.719971

# %%
print(GSPC_test[GSPC_test_signal.signal == -1.0])
print(GSPC_test[pure_mm_cnn_signal.signal == -1.0])
# Out:
#               Adj Close
# Date
# 2018-08-27  2896.739990
# 2018-09-20  2930.750000
# 2019-03-18  2832.939941
# 2019-03-21  2854.879883
#               Adj Close
# Date
# 2018-08-06  2850.399902
# 2018-08-24  2874.689941
# 2018-09-20  2930.750000
# 2019-02-04  2724.870117
# 2019-03-19  2832.570068

# %%
plt.figure(figsize=(15,9),dpi=150)
plt.subplot(2,1,1)
plt.title('GSPC_test')
plt.plot(GSPC_test_signal['Price'], color='r', lw=1,label='Close')
plt.plot(GSPC_test_signal[['mean','upper','lower']], lw=1,label=['mean','upper','lower'])
plt.plot(GSPC_test_signal.loc[GSPC_test_signal.signal == 1.0].index, 
         GSPC_test_signal.Price[GSPC_test_signal.signal == 1.0],
         '^', markersize=5, color='m',label='long')
plt.plot(GSPC_test_signal.loc[GSPC_test_signal.signal == -1.0].index, 
         GSPC_test_signal.Price[GSPC_test_signal.signal == -1.0],
         'v', markersize=5, color='k',label='short')
plt.legend()         


plt.subplot(2,1,2)
plt.title('pure_mm_cnn_signal')
plt.plot(pure_mm_cnn_signal['Price'], color='r', lw=1,label='Close')
plt.plot(pure_mm_cnn_signal[['mean','upper','lower']], lw=1,label=['mean','upper','lower'])
plt.plot(pure_mm_cnn_signal.loc[pure_mm_cnn_signal.signal == 1.0].index, 
         pure_mm_cnn_signal.Price[pure_mm_cnn_signal.signal == 1.0],
         '^', markersize=5, color='m',label='long')
plt.plot(pure_mm_cnn_signal.loc[pure_mm_cnn_signal.signal == -1.0].index, 
         pure_mm_cnn_signal.Price[pure_mm_cnn_signal.signal == -1.0],
         'v', markersize=5, color='k',label='short')
plt.legend()

# %% [markdown]
# ## MACD

# %%
def MACD(dataset,short_window = 12,long_window = 26, signal_window=9):
    # Initiate short and long windows

    # Initialise the `signals` dataframe and add the `signal` column
    signals = pd.DataFrame(index=dataset.index)
    signals['signal'] = 0.0

    # Calculate short term moving averages
    signals['short_mavg'] = dataset['Adj Close'].ewm(span=short_window, min_periods=1).mean()

    # Calculate long term moving averages
    signals['long_mavg'] = dataset['Adj Close'].ewm(span=long_window, min_periods=1).mean()
    
    # Calculate DIF 
    signals['DIF'] = signals['short_mavg']-signals['long_mavg']
    
     # Calculate DIF moving averages
    signals['DEA'] = signals['DIF'].ewm(span=signal_window, min_periods=1).mean()

    # Generate signal
    signals['signal'] = np.where(signals['DIF']> signals['DEA'], 1.0, 0.0)   

    # Generate trading orders
    signals['positions'] = signals['signal'].diff()
    return signals

# %%
GSPC_test_macd=MACD(GSPC_test_n,short_window = 14,long_window = 22)
pure_mm_cnn_macd=MACD(pure_mm_cnn,short_window = 14,long_window = 22)
#pure_mm_lstm_macd=MACD(pure_mm_lstm,short_window = 14,long_window = 22)

plt.figure(figsize=(15,9),dpi=150)
plt.subplot(2,1,1)
plt.title('GSPC_test')
plt.plot(GSPC_test_n['Adj Close'], color='r', lw=1,label='Close')
plt.plot(GSPC_test_macd[['short_mavg', 'long_mavg']], lw=2,label=['short_mavg', 'long_mavg'])
plt.plot(GSPC_test_macd.loc[GSPC_test_macd.positions == 1.0].index, 
         GSPC_test_macd.short_mavg[GSPC_test_macd.positions == 1.0],
         '^', markersize=5, color='m',label='long')
plt.plot(GSPC_test_macd.loc[GSPC_test_macd.positions == -1.0].index, 
         GSPC_test_macd.short_mavg[GSPC_test_macd.positions == -1.0],
         'v', markersize=5, color='k',label='short')
plt.legend()         


plt.subplot(2,1,2)
plt.title('pure_mm_cnn')
plt.plot(pure_mm_cnn['Adj Close'], color='r', lw=1,label='Close')
plt.plot(pure_mm_cnn_macd[['short_mavg', 'long_mavg']], lw=2,label=['short_mavg', 'long_mavg'])
plt.plot(pure_mm_cnn_macd.loc[pure_mm_cnn_macd.positions == 1.0].index, 
         pure_mm_cnn_macd.short_mavg[pure_mm_cnn_macd.positions == 1.0],
         '^', markersize=5, color='m',label='long')
plt.plot(pure_mm_cnn_macd.loc[pure_mm_cnn_macd.positions == -1.0].index, 
         pure_mm_cnn_macd.short_mavg[pure_mm_cnn_macd.positions == -1.0],
         'v', markersize=5, color='k',label='short')
plt.legend()

# %%
print('GSPC_test_macd:\n',GSPC_test_macd.positions.value_counts(),'\n')
print('pure_mm_cnn_macd:\n',pure_mm_cnn_macd.positions.value_counts(),'\n')
# Out:
# GSPC_test_macd:
#   0.0    226
#  1.0     12
# -1.0     12
# Name: positions, dtype: int64
#
# pure_mm_cnn_macd:
#   0.0    228
#  1.0     11
# -1.0     11
# Name: positions, dtype: int64

# %%
print(GSPC_test[GSPC_test_macd['positions']==1])
print(GSPC_test[pure_mm_cnn_macd['positions']==1])
# Out:
#               Adj Close
# Date
# 2018-06-04  2746.870117
# 2018-07-06  2759.820068
# 2018-08-03  2840.350098
# 2018-08-22  2861.820068
# 2018-08-24  2874.689941
# 2018-09-20  2930.750000
# 2018-11-02  2723.060059
# 2018-11-28  2743.790039
# 2019-01-02  2510.030029
# 2019-03-19  2832.570068
# 2019-04-02  2867.239990
# 2019-04-23  2933.679932
#               Adj Close
# Date
# 2018-06-04  2746.870117
# 2018-07-06  2759.820068
# 2018-08-03  2840.350098
# 2018-08-23  2856.979980
# 2018-09-20  2930.750000
# 2018-11-02  2723.060059
# 2018-11-28  2743.790039
# 2019-01-02  2510.030029
# 2019-03-19  2832.570068
# 2019-04-02  2867.239990
# 2019-04-24  2927.250000

# %%
print(GSPC_test[GSPC_test_macd['positions']==-1])
print(GSPC_test[pure_mm_cnn_macd['positions']==-1])
# Out:
#               Adj Close
# Date
# 2018-06-19  2762.590088
# 2018-08-01  2813.360107
# 2018-08-13  2821.929932
# 2018-08-23  2856.979980
# 2018-09-06  2878.050049
# 2018-09-26  2905.969971
# 2018-11-20  2641.889893
# 2018-12-10  2637.719971
# 2019-02-28  2784.489990
# 2019-03-22  2800.709961
# 2019-04-18  2905.030029
# 2019-05-01  2923.729980
#               Adj Close
# Date
# 2018-06-18  2773.750000
# 2018-08-01  2813.360107
# 2018-08-13  2821.929932
# 2018-09-06  2878.050049
# 2018-09-26  2905.969971
# 2018-11-20  2641.889893
# 2018-12-10  2637.719971
# 2019-02-28  2784.489990
# 2019-03-22  2800.709961
# 2019-04-18  2905.030029
# 2019-04-30  2945.830078

# %% [markdown]
# ## MA

# %%
def MA(dataset,short_window = 10,long_window = 50):
    # Initiate short and long windows

    # Initialise the `signals` dataframe and add the `signal` column
    signals = pd.DataFrame(index=dataset.index)
    signals['signal'] = 0.0

    # Calculate short term simple moving averages
    signals['short_mavg'] = dataset['Adj Close'].rolling(window=short_window, min_periods=1).mean()

    # Calculate long term simple moving averages
    signals['long_mavg'] = dataset['Adj Close'].rolling(window=long_window, min_periods=1).mean()

    # Generate signal
    signals['signal'][short_window:] = np.where(signals['short_mavg'][short_window:] 
                                                > signals['long_mavg'][short_window:], 1.0, 0.0)   

    # Generate trading orders
    signals['positions'] = signals['signal'].diff()
    return signals

# %%
GSPC_test_ma=MA(GSPC_test,short_window = 10,long_window = 50)
pure_mm_cnn_ma=MA(pure_mm_cnn,short_window = 10,long_window = 50)
#pure_mm_lstm_ma=MA(pure_mm_lstm,short_window = 10,long_window = 50)

plt.figure(figsize=(15,9),dpi=150)
plt.subplot(3,1,1)
plt.title('GSPC_test')
plt.plot(GSPC_test['Adj Close'], color='r', lw=1,label='Close')
plt.plot(GSPC_test_ma[['short_mavg', 'long_mavg']], lw=2,label=['short_mavg', 'long_mavg'])
plt.plot(GSPC_test_ma.loc[GSPC_test_ma.positions == 1.0].index, 
         GSPC_test_ma.short_mavg[GSPC_test_ma.positions == 1.0],
         '^', markersize=5, color='m',label='long')
plt.plot(GSPC_test_ma.loc[GSPC_test_ma.positions == -1.0].index, 
         GSPC_test_ma.short_mavg[GSPC_test_ma.positions == -1.0],
         'v', markersize=5, color='k',label='short')
plt.legend()         


plt.subplot(3,1,2)
plt.title('pure_mm_cnn')
plt.plot(pure_mm_cnn['Adj Close'], color='r', lw=1,label='Close')
plt.plot(pure_mm_cnn_ma[['short_mavg', 'long_mavg']], lw=2,label=['short_mavg', 'long_mavg'])
plt.plot(pure_mm_cnn_ma.loc[pure_mm_cnn_ma.positions == 1.0].index, 
         pure_mm_cnn_ma.short_mavg[pure_mm_cnn_ma.positions == 1.0],
         '^', markersize=5, color='m',label='long')
plt.plot(pure_mm_cnn_ma.loc[pure_mm_cnn_ma.positions == -1.0].index, 
         pure_mm_cnn_ma.short_mavg[pure_mm_cnn_ma.positions == -1.0],
         'v', markersize=5, color='k',label='short')
plt.legend()

# %%
print('GSPC_test_ma:\n',GSPC_test_ma.positions.value_counts(),'\n')
print('pure_mm_cnn_ma:\n',pure_mm_cnn_ma.positions.value_counts(),'\n')
# Out:
# GSPC_test_ma:
#   0.0    244
#  1.0      3
# -1.0      3
# Name: positions, dtype: int64
#
# pure_mm_cnn_ma:
#   0.0    244
#  1.0      3
# -1.0      3
# Name: positions, dtype: int64

# %%
print(GSPC_test[GSPC_test_ma['positions']==1])
print(GSPC_test[pure_mm_cnn_ma['positions']==1])
# Out:
#               Adj Close
# Date
# 2018-06-15  2779.659912
# 2018-07-13  2801.310059
# 2019-01-24  2642.330078
#               Adj Close
# Date
# 2018-06-15  2779.659912
# 2018-07-13  2801.310059
# 2019-01-23  2638.699951

# %%
print(GSPC_test[GSPC_test_ma['positions']==-1])
print(GSPC_test[pure_mm_cnn_ma['positions']==-1])
# Out:
#               Adj Close
# Date
# 2018-06-26  2723.060059
# 2018-10-11  2728.370117
# 2019-05-17  2859.530029
#               Adj Close
# Date
# 2018-06-26  2723.060059
# 2018-10-12  2767.129883
# 2019-05-17  2859.530029
