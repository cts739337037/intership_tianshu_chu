# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 

import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"  
import keras
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC
from sklearn.metrics import f1_score
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Conv1D, Dropout,  Input, Layer
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers.schedules import LearningRateSchedule
from tensorflow.keras.optimizers import Adam


from pandas_datareader import data

from PyEMD import EMD,EEMD,CEEMDAN,Visualisation

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
bit_test = pd.read_csv('bit_c_1m.csv')
bit_test['Open Time']=pd.to_datetime(bit_test['Open Time'])
bit_test.set_index('Open Time', inplace=True)
bit_test=bit_test[1:]
bit_test=pd.DataFrame(bit_test['Close'])
bit_test
# Out:
#                         Close
# Open Time
# 2021-01-01 00:01:00  29009.91
# 2021-01-01 00:02:00  28989.30
# 2021-01-01 00:03:00  28982.69
# 2021-01-01 00:04:00  28975.65
# 2021-01-01 00:05:00  28937.11
# ...                       ...
# 2021-05-12 05:35:00  57485.07
# 2021-05-12 05:36:00  57481.49
# 2021-05-12 05:37:00  57470.00
# 2021-05-12 05:38:00  57450.90
# 2021-05-12 05:39:00  57450.19
#
# [188316 rows x 1 columns]

# %%
def emd_calculate(data,emdtype=EMD, plots=True):
    EMD_C=emdtype()#EMD,EEMD,CEEMDAN
    imfs = EMD_C(data.values.reshape(len(data)))
        
    if plots:
        series_index = data.index
        fig = plt.figure(figsize=(16,2*len(imfs)))
        plt.subplot(1+len(imfs), 1, 1 )
        plt.plot(series_index, data, color='#0070C0') #F27F19 orange #0070C0 blue
        plt.ylabel('Original data')

        # Plot IMFs
        for i in range(len(imfs)):
            plt.subplot(1 +len(imfs),1,2 + i)
            plt.plot(series_index, imfs[i, :], color='#F27F19')
            plt.ylabel('IMF'+str(i))
        plt.show()
    imfs=pd.DataFrame(imfs,columns=data.index)
    return imfs

# %%
def create_noisy(data,percentage=0.5,size=10):
    data_noisy = pd.DataFrame()
    window=int(len(data) * percentage)
    for i in range(window,len(data),size):
        data_noisy= pd.concat([data_noisy,pd.Series(data.values[i-window:i,0])], axis=1)
    return data_noisy.T

# %%
def create_pure(data,percentage=0.5,size=10,emdtype=EMD):
    data_pure = pd.DataFrame()
    window=int(len(data) * percentage)
    for i in range(window,len(data),size):
        temp=emd_calculate
        data_pure= pd.concat([data_pure,pd.Series(data.values[i-window:i,0])], axis=1)
    return data_pure.T

# %%
def reconstruction(data_emd):
    reconstruction = pd.DataFrame()
    for i in range(len(data_emd)):
        reconstruction['sum'+str(i)]=data_emd.iloc[i:,:].sum(axis=0)
    return reconstruction.T

# %%
GSPC_pure=create_pure(bit_test,size=2000)

GSPC_noisy=create_noisy(bit_test,size=2000)

# %%
mm_t_g = MinMaxScaler()
noise_mm = mm_t_g.fit_transform(GSPC_noisy.T).T
prue_mm=mm_t_g.fit_transform(GSPC_pure.T).T
print(prue_mm.shape)
print(noise_mm.shape)
# Out:
# (48, 94158)
# (48, 94158)

# %%
X_train_mm = np.asarray(noise_mm)
X_train_mm=X_train_mm.reshape((len(X_train_mm), len(X_train_mm[0]), 1))
Y_train_mm = np.asarray(prue_mm)
Y_train_mm=Y_train_mm.reshape((len(Y_train_mm), len(Y_train_mm[0]), 1))
X_train_mm, X_val_mm, Y_train_mm, Y_val_mm = train_test_split(X_train_mm, Y_train_mm, test_size=0.2,random_state=0,shuffle=False)

# %%
keras.backend.clear_session()

# %%
def set_model_encoding_mm():
    model = Sequential()
    model.add(Conv1D(128, kernel_size=3, activation='relu', padding='same',input_shape=(None, 1)))
    model.add(Conv1D(64, kernel_size=3,activation='relu',padding='same'))
    model.add(Conv1D(64, kernel_size=3, activation='relu', padding='same'))
    model.add(Conv1D(128, kernel_size=3,activation='relu',padding='same'))
    model.add(Conv1D(1,kernel_size=1,activation='sigmoid', padding='same'))
    model.compile(optimizer='adam' , loss='mse', metrics=['mae'])
    
    return model
modelen_mm = set_model_encoding_mm()
modelen_mm.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, None, 128)         512
#
#  conv1d_1 (Conv1D)           (None, None, 64)          24640
#
#  conv1d_2 (Conv1D)           (None, None, 64)          12352
#
#  conv1d_3 (Conv1D)           (None, None, 128)         24704
#
#  conv1d_4 (Conv1D)           (None, None, 1)           129
#
# =================================================================
# Total params: 62,337
# Trainable params: 62,337
# Non-trainable params: 0
# _________________________________________________________________

# %%
callback = EarlyStopping(monitor='loss', patience=10)
history_mm = modelen_mm.fit(X_train_mm, Y_train_mm, validation_data = (X_val_mm, Y_val_mm), epochs=400, batch_size=32, verbose=1, callbacks=[callback])
# Out:
# Epoch 1/400
# 2/2 [==============================] - 10s 2s/step - loss: 0.0683 - mae: 0.2284 - val_loss: 0.0383 - val_mae: 0.1603
# Epoch 2/400
# 2/2 [==============================] - 9s 2s/step - loss: 0.0634 - mae: 0.2182 - val_loss: 0.0352 - val_mae: 0.1518
# Epoch 3/400
# 2/2 [==============================] - 9s 2s/step - loss: 0.0593 - mae: 0.2084 - val_loss: 0.0314 - val_mae: 0.1405
# Epoch 4/400
# 2/2 [==============================] - 9s 2s/step - loss: 0.0538 - mae: 0.1945 - val_loss: 0.0287 - val_mae: 0.1308
# Epoch 5/400
# 2/2 [==============================] - 9s 2s/step - loss: 0.0490 - mae: 0.1802 - val_loss: 0.0282 - val_mae: 0.1276
# Epoch 6/400
# 2/2 [==============================] - 9s 2s/step - loss: 0.0460 - mae: 0.1701 - val_loss: 0.0301 - val_mae: 0.1340
# Epoch 7/400
# 2/2 [==============================] - 10s 2s/step - loss: 0.0453 - mae: 0.1669 - val_loss: 0.0289 - val_mae: 0.1318
# Epoch 8/400
# 2/2 [==============================] - 9s 2s/step - loss: 0.0430 - mae: 0.1626 - val_loss: 0.0250 - val_mae: 0.1200
# Epoch 9/400
# 2/2 [==============================] - 9s 2s/step - loss: 0.0399 - mae: 0.1576 - val_loss: 0.0226 - val_mae: 0.1141
# Epoch 10/400
# 2/2 [==============================] - 9s 2s/step - loss: 0.0387 - mae: 0.1573 - val_loss: 0.0211 - val_mae: 0.1097
# Epoch 11/400
# 2/2 [==============================] - 9s 2s/step - loss: 0.0363 - mae: 0.1515 - val_loss: 0.0197 - val_mae: 0.1053
# Epoch 12/400
# 2/2 [==============================] - 9s 2s/step - loss: 0.0325 - mae: 0.1403 - val_loss: 0.0197 - val_mae: 0.1090
# Epoch 13/400
# 2/2 [==============================] - 9s 2s/step - loss: 0.0303 - mae: 0.1345 - val_loss: 0.0167 - val_mae: 0.0990
# Epoch 14/400
# 2/2 [==============================] - 9s 2s/step - loss: 0.0268 - mae: 0.1241 - val_loss: 0.0124 - val_mae: 0.0774
# Epoch 15/400
# 2/2 [==============================] - 9s 2s/step - loss: 0.0239 - mae: 0.1144 - val_loss: 0.0100 - val_mae: 0.0649
# Epoch 16/400
# 2/2 [==============================] - 9s 2s/step - loss: 0.0199 - mae: 0.0997 - val_loss: 0.0090 - val_mae: 0.0704
# Epoch 17/400
# 2/2 [==============================] - 9s 2s/step - loss: 0.0163 - mae: 0.0900 - val_loss: 0.0055 - val_mae: 0.0413
# Epoch 18/400
# 2/2 [==============================] - 9s 2s/step - loss: 0.0120 - mae: 0.0675 - val_loss: 0.0043 - val_mae: 0.0433
# Epoch 19/400
# 2/2 [==============================] - 10s 2s/step - loss: 0.0089 - mae: 0.0615 - val_loss: 0.0032 - val_mae: 0.0406
# Epoch 20/400
# 2/2 [==============================] - 10s 2s/step - loss: 0.0062 - mae: 0.0533 - val_loss: 0.0037 - val_mae: 0.0447
# Epoch 21/400
# 2/2 [==============================] - 9s 2s/step - loss: 0.0047 - mae: 0.0472 - val_loss: 0.0040 - val_mae: 0.0509
# Epoch 22/400
# 2/2 [==============================] - 10s 2s/step - loss: 0.0043 - mae: 0.0525 - val_loss: 0.0046 - val_mae: 0.0551
# Epoch 23/400
# 2/2 [==============================] - 9s 2s/step - loss: 0.0044 - mae: 0.0536 - val_loss: 0.0050 - val_mae: 0.0552
# Epoch 24/400
# 2/2 [==============================] - 9s 2s/step - loss: 0.0044 - mae: 0.0518 - val_loss: 0.0038 - val_mae: 0.0526
# Epoch 25/400
# 2/2 [==============================] - 9s 2s/step - loss: 0.0037 - mae: 0.0515 - val_loss: 0.0030 - val_mae: 0.0419
# Epoch 26/400
# 2/2 [==============================] - 9s 2s/step - loss: 0.0028 - mae: 0.0393 - val_loss: 0.0017 - val_mae: 0.0346
# Epoch 27/400
# 2/2 [==============================] - 9s 2s/step - loss: 0.0019 - mae: 0.0361 - val_loss: 9.7364e-04 - val_mae: 0.0222
# Epoch 28/400
# 2/2 [==============================] - 9s 2s/step - loss: 0.0014 - mae: 0.0256 - val_loss: 6.0633e-04 - val_mae: 0.0165
# Epoch 29/400
# 2/2 [==============================] - 9s 2s/step - loss: 0.0012 - mae: 0.0225 - val_loss: 5.4459e-04 - val_mae: 0.0127
# Epoch 30/400
# 2/2 [==============================] - 9s 2s/step - loss: 0.0013 - mae: 0.0209 - val_loss: 5.6204e-04 - val_mae: 0.0141
# Epoch 31/400
# 2/2 [==============================] - 9s 2s/step - loss: 0.0012 - mae: 0.0222 - val_loss: 4.6933e-04 - val_mae: 0.0120
# Epoch 32/400
# 2/2 [==============================] - 9s 2s/step - loss: 0.0010 - mae: 0.0196 - val_loss: 4.8111e-04 - val_mae: 0.0158
# Epoch 33/400
# 2/2 [==============================] - 9s 2s/step - loss: 8.1187e-04 - mae: 0.0194 - val_loss: 3.5271e-04 - val_mae: 0.0115
# Epoch 34/400
# 2/2 [==============================] - 9s 2s/step - loss: 6.4685e-04 - mae: 0.0166 - val_loss: 4.3701e-04 - val_mae: 0.0177
# Epoch 35/400
# 2/2 [==============================] - 9s 2s/step - loss: 5.7580e-04 - mae: 0.0197 - val_loss: 4.4717e-04 - val_mae: 0.0151
# Epoch 36/400
# 2/2 [==============================] - 9s 2s/step - loss: 6.2411e-04 - mae: 0.0185 - val_loss: 5.1002e-04 - val_mae: 0.0200
# Epoch 37/400
# 2/2 [==============================] - 9s 2s/step - loss: 5.6500e-04 - mae: 0.0206 - val_loss: 3.9262e-04 - val_mae: 0.0139
# Epoch 38/400
# 2/2 [==============================] - 9s 2s/step - loss: 5.4700e-04 - mae: 0.0171 - val_loss: 5.9756e-04 - val_mae: 0.0212
# Epoch 39/400
# 2/2 [==============================] - 9s 2s/step - loss: 5.5515e-04 - mae: 0.0195 - val_loss: 2.9735e-04 - val_mae: 0.0112
# Epoch 40/400
# 2/2 [==============================] - 9s 2s/step - loss: 4.6331e-04 - mae: 0.0145 - val_loss: 6.7159e-04 - val_mae: 0.0226
# Epoch 41/400
# 2/2 [==============================] - 9s 2s/step - loss: 5.9234e-04 - mae: 0.0192 - val_loss: 2.6470e-04 - val_mae: 0.0096
# Epoch 42/400
# 2/2 [==============================] - 9s 2s/step - loss: 4.5742e-04 - mae: 0.0138 - val_loss: 2.6985e-04 - val_mae: 0.0124
# Epoch 43/400
# 2/2 [==============================] - 9s 2s/step - loss: 3.5907e-04 - mae: 0.0133 - val_loss: 2.1180e-04 - val_mae: 0.0088
# Epoch 44/400
# 2/2 [==============================] - 9s 2s/step - loss: 3.7420e-04 - mae: 0.0125 - val_loss: 2.0970e-04 - val_mae: 0.0102
# Epoch 45/400
# 2/2 [==============================] - 9s 2s/step - loss: 3.3012e-04 - mae: 0.0124 - val_loss: 2.7981e-04 - val_mae: 0.0135
# Epoch 46/400
# 2/2 [==============================] - 9s 2s/step - loss: 3.3671e-04 - mae: 0.0141 - val_loss: 2.1686e-04 - val_mae: 0.0103
# Epoch 47/400
# 2/2 [==============================] - 9s 2s/step - loss: 3.3211e-04 - mae: 0.0128 - val_loss: 2.4923e-04 - val_mae: 0.0128
# Epoch 48/400
# 2/2 [==============================] - 9s 2s/step - loss: 3.1474e-04 - mae: 0.0137 - val_loss: 2.1606e-04 - val_mae: 0.0109
# Epoch 49/400
# 2/2 [==============================] - 9s 2s/step - loss: 3.1409e-04 - mae: 0.0129 - val_loss: 2.6268e-04 - val_mae: 0.0133
# Epoch 50/400
# 2/2 [==============================] - 9s 2s/step - loss: 3.2216e-04 - mae: 0.0138 - val_loss: 2.7579e-04 - val_mae: 0.0137
# Epoch 51/400
# 2/2 [==============================] - 9s 2s/step - loss: 3.1595e-04 - mae: 0.0138 - val_loss: 2.2469e-04 - val_mae: 0.0100
# Epoch 52/400
# 2/2 [==============================] - 9s 2s/step - loss: 3.3250e-04 - mae: 0.0123 - val_loss: 2.9813e-04 - val_mae: 0.0142
# Epoch 53/400
# 2/2 [==============================] - 9s 2s/step - loss: 3.3064e-04 - mae: 0.0138 - val_loss: 1.9828e-04 - val_mae: 0.0102
# Epoch 54/400
# 2/2 [==============================] - 9s 2s/step - loss: 2.9115e-04 - mae: 0.0120 - val_loss: 2.0491e-04 - val_mae: 0.0108
# Epoch 55/400
# 2/2 [==============================] - 9s 2s/step - loss: 2.8447e-04 - mae: 0.0118 - val_loss: 1.9438e-04 - val_mae: 0.0101
# Epoch 56/400
# 2/2 [==============================] - 9s 2s/step - loss: 2.8848e-04 - mae: 0.0118 - val_loss: 1.9204e-04 - val_mae: 0.0096
# Epoch 57/400
# 2/2 [==============================] - 9s 2s/step - loss: 2.8868e-04 - mae: 0.0113 - val_loss: 3.0542e-04 - val_mae: 0.0144
# Epoch 58/400
# 2/2 [==============================] - 9s 2s/step - loss: 3.2122e-04 - mae: 0.0136 - val_loss: 1.9252e-04 - val_mae: 0.0096
# Epoch 59/400
# 2/2 [==============================] - 9s 2s/step - loss: 2.9516e-04 - mae: 0.0117 - val_loss: 1.9039e-04 - val_mae: 0.0095
# Epoch 60/400
# 2/2 [==============================] - 9s 2s/step - loss: 2.8263e-04 - mae: 0.0112 - val_loss: 1.9288e-04 - val_mae: 0.0106
# Epoch 61/400
# 2/2 [==============================] - 9s 2s/step - loss: 2.5881e-04 - mae: 0.0115 - val_loss: 2.2546e-04 - val_mae: 0.0120
# Epoch 62/400
# 2/2 [==============================] - 9s 2s/step - loss: 2.6999e-04 - mae: 0.0120 - val_loss: 1.9460e-04 - val_mae: 0.0108
# Epoch 63/400
# 2/2 [==============================] - 9s 2s/step - loss: 2.5509e-04 - mae: 0.0116 - val_loss: 2.2436e-04 - val_mae: 0.0099
# Epoch 64/400
# 2/2 [==============================] - 9s 2s/step - loss: 3.2671e-04 - mae: 0.0123 - val_loss: 1.6686e-04 - val_mae: 0.0087
# Epoch 65/400
# 2/2 [==============================] - 9s 2s/step - loss: 2.5223e-04 - mae: 0.0103 - val_loss: 2.4784e-04 - val_mae: 0.0128
# Epoch 66/400
# 2/2 [==============================] - 9s 2s/step - loss: 2.6620e-04 - mae: 0.0122 - val_loss: 1.6951e-04 - val_mae: 0.0086
# Epoch 67/400
# 2/2 [==============================] - 9s 2s/step - loss: 2.6327e-04 - mae: 0.0107 - val_loss: 1.6101e-04 - val_mae: 0.0088
# Epoch 68/400
# 2/2 [==============================] - 9s 2s/step - loss: 2.3661e-04 - mae: 0.0100 - val_loss: 2.7337e-04 - val_mae: 0.0136
# Epoch 69/400
# 2/2 [==============================] - 9s 2s/step - loss: 2.7358e-04 - mae: 0.0125 - val_loss: 1.5555e-04 - val_mae: 0.0078
# Epoch 70/400
# 2/2 [==============================] - 9s 2s/step - loss: 2.4583e-04 - mae: 0.0100 - val_loss: 1.4605e-04 - val_mae: 0.0086
# Epoch 71/400
# 2/2 [==============================] - 9s 2s/step - loss: 2.2076e-04 - mae: 0.0099 - val_loss: 3.9628e-04 - val_mae: 0.0168
# Epoch 72/400
# 2/2 [==============================] - 9s 2s/step - loss: 3.5206e-04 - mae: 0.0146 - val_loss: 1.4884e-04 - val_mae: 0.0083
# Epoch 73/400
# 2/2 [==============================] - 9s 2s/step - loss: 2.2496e-04 - mae: 0.0101 - val_loss: 1.4308e-04 - val_mae: 0.0083
# Epoch 74/400
# 2/2 [==============================] - 9s 2s/step - loss: 2.0835e-04 - mae: 0.0094 - val_loss: 2.4749e-04 - val_mae: 0.0129
# Epoch 75/400
# 2/2 [==============================] - 9s 2s/step - loss: 2.4855e-04 - mae: 0.0120 - val_loss: 1.4119e-04 - val_mae: 0.0076
# Epoch 76/400
# 2/2 [==============================] - 9s 2s/step - loss: 2.1375e-04 - mae: 0.0094 - val_loss: 1.2575e-04 - val_mae: 0.0076
# Epoch 77/400
# 2/2 [==============================] - 9s 2s/step - loss: 1.8766e-04 - mae: 0.0086 - val_loss: 1.8707e-04 - val_mae: 0.0109
# Epoch 78/400
# 2/2 [==============================] - 9s 2s/step - loss: 2.0718e-04 - mae: 0.0106 - val_loss: 1.1874e-04 - val_mae: 0.0070
# Epoch 79/400
# 2/2 [==============================] - 9s 2s/step - loss: 1.7964e-04 - mae: 0.0084 - val_loss: 1.1708e-04 - val_mae: 0.0076
# Epoch 80/400
# 2/2 [==============================] - 9s 2s/step - loss: 1.7234e-04 - mae: 0.0085 - val_loss: 2.5535e-04 - val_mae: 0.0131
# Epoch 81/400
# 2/2 [==============================] - 9s 2s/step - loss: 2.4521e-04 - mae: 0.0120 - val_loss: 1.1339e-04 - val_mae: 0.0068
# Epoch 82/400
# 2/2 [==============================] - 9s 2s/step - loss: 1.7887e-04 - mae: 0.0085 - val_loss: 1.4941e-04 - val_mae: 0.0082
# Epoch 83/400
# 2/2 [==============================] - 9s 2s/step - loss: 2.0091e-04 - mae: 0.0090 - val_loss: 2.0728e-04 - val_mae: 0.0119
# Epoch 84/400
# 2/2 [==============================] - 9s 2s/step - loss: 2.1715e-04 - mae: 0.0114 - val_loss: 1.2128e-04 - val_mae: 0.0084
# Epoch 85/400
# 2/2 [==============================] - 9s 2s/step - loss: 1.5474e-04 - mae: 0.0089 - val_loss: 1.6563e-04 - val_mae: 0.0096
# Epoch 86/400
# 2/2 [==============================] - 9s 2s/step - loss: 2.0672e-04 - mae: 0.0101 - val_loss: 1.0086e-04 - val_mae: 0.0073
# Epoch 87/400
# 2/2 [==============================] - 9s 2s/step - loss: 1.4860e-04 - mae: 0.0083 - val_loss: 1.7355e-04 - val_mae: 0.0108
# Epoch 88/400
# 2/2 [==============================] - 9s 2s/step - loss: 1.7865e-04 - mae: 0.0101 - val_loss: 1.3729e-04 - val_mae: 0.0084
# Epoch 89/400
# 2/2 [==============================] - 9s 2s/step - loss: 1.9468e-04 - mae: 0.0096 - val_loss: 9.2535e-05 - val_mae: 0.0060
# Epoch 90/400
# 2/2 [==============================] - 9s 2s/step - loss: 1.3775e-04 - mae: 0.0069 - val_loss: 2.1008e-04 - val_mae: 0.0121
# Epoch 91/400
# 2/2 [==============================] - 9s 2s/step - loss: 2.1076e-04 - mae: 0.0114 - val_loss: 7.6959e-05 - val_mae: 0.0057
# Epoch 92/400
# 2/2 [==============================] - 9s 2s/step - loss: 1.2201e-04 - mae: 0.0071 - val_loss: 1.7774e-04 - val_mae: 0.0110
# Epoch 93/400
# 2/2 [==============================] - 9s 2s/step - loss: 2.0961e-04 - mae: 0.0110 - val_loss: 7.4412e-05 - val_mae: 0.0059
# Epoch 94/400
# 2/2 [==============================] - 9s 2s/step - loss: 1.2034e-04 - mae: 0.0071 - val_loss: 1.9091e-04 - val_mae: 0.0116
# Epoch 95/400
# 2/2 [==============================] - 9s 2s/step - loss: 1.9069e-04 - mae: 0.0108 - val_loss: 8.3640e-05 - val_mae: 0.0061
# Epoch 96/400
# 2/2 [==============================] - 9s 2s/step - loss: 1.2701e-04 - mae: 0.0073 - val_loss: 8.1211e-05 - val_mae: 0.0060
# Epoch 97/400
# 2/2 [==============================] - 9s 2s/step - loss: 1.1379e-04 - mae: 0.0065 - val_loss: 1.4229e-04 - val_mae: 0.0098
# Epoch 98/400
# 2/2 [==============================] - 9s 2s/step - loss: 1.5499e-04 - mae: 0.0096 - val_loss: 5.9949e-05 - val_mae: 0.0043
# Epoch 99/400
# 2/2 [==============================] - 9s 2s/step - loss: 1.0272e-04 - mae: 0.0060 - val_loss: 9.1017e-05 - val_mae: 0.0068
# Epoch 100/400
# 2/2 [==============================] - 9s 2s/step - loss: 1.1890e-04 - mae: 0.0068 - val_loss: 8.8519e-05 - val_mae: 0.0072
# Epoch 101/400
# 2/2 [==============================] - 9s 2s/step - loss: 1.1778e-04 - mae: 0.0078 - val_loss: 8.5495e-05 - val_mae: 0.0069
# Epoch 102/400
# 2/2 [==============================] - 9s 2s/step - loss: 1.0781e-04 - mae: 0.0073 - val_loss: 7.1133e-05 - val_mae: 0.0057
# Epoch 103/400
# 2/2 [==============================] - 9s 2s/step - loss: 1.0054e-04 - mae: 0.0064 - val_loss: 5.4961e-05 - val_mae: 0.0042
# Epoch 104/400
# 2/2 [==============================] - 9s 2s/step - loss: 8.5510e-05 - mae: 0.0049 - val_loss: 6.8328e-05 - val_mae: 0.0061
# Epoch 105/400
# 2/2 [==============================] - 9s 2s/step - loss: 9.4021e-05 - mae: 0.0066 - val_loss: 5.4483e-05 - val_mae: 0.0049
# Epoch 106/400
# 2/2 [==============================] - 9s 2s/step - loss: 8.1012e-05 - mae: 0.0057 - val_loss: 5.5886e-05 - val_mae: 0.0048
# Epoch 107/400
# 2/2 [==============================] - 9s 2s/step - loss: 8.1446e-05 - mae: 0.0054 - val_loss: 4.8108e-05 - val_mae: 0.0040
# Epoch 108/400
# 2/2 [==============================] - 9s 2s/step - loss: 7.4389e-05 - mae: 0.0047 - val_loss: 5.3899e-05 - val_mae: 0.0051
# Epoch 109/400
# 2/2 [==============================] - 9s 2s/step - loss: 7.9136e-05 - mae: 0.0057 - val_loss: 5.0340e-05 - val_mae: 0.0048
# Epoch 110/400
# 2/2 [==============================] - 9s 2s/step - loss: 7.5479e-05 - mae: 0.0055 - val_loss: 5.3969e-05 - val_mae: 0.0052
# Epoch 111/400
# 2/2 [==============================] - 9s 2s/step - loss: 7.8459e-05 - mae: 0.0058 - val_loss: 4.9708e-05 - val_mae: 0.0048
# Epoch 112/400
# 2/2 [==============================] - 9s 2s/step - loss: 7.3237e-05 - mae: 0.0055 - val_loss: 3.9820e-05 - val_mae: 0.0034
# Epoch 113/400
# 2/2 [==============================] - 9s 2s/step - loss: 6.4889e-05 - mae: 0.0044 - val_loss: 4.7340e-05 - val_mae: 0.0042
# Epoch 114/400
# 2/2 [==============================] - 9s 2s/step - loss: 7.0931e-05 - mae: 0.0048 - val_loss: 4.2954e-05 - val_mae: 0.0038
# Epoch 115/400
# 2/2 [==============================] - 9s 2s/step - loss: 6.4802e-05 - mae: 0.0044 - val_loss: 3.7896e-05 - val_mae: 0.0037
# Epoch 116/400
# 2/2 [==============================] - 9s 2s/step - loss: 6.2156e-05 - mae: 0.0046 - val_loss: 4.2179e-05 - val_mae: 0.0043
# Epoch 117/400
# 2/2 [==============================] - 9s 2s/step - loss: 6.4990e-05 - mae: 0.0051 - val_loss: 3.5864e-05 - val_mae: 0.0035
# Epoch 118/400
# 2/2 [==============================] - 9s 2s/step - loss: 5.7814e-05 - mae: 0.0043 - val_loss: 3.8655e-05 - val_mae: 0.0037
# Epoch 119/400
# 2/2 [==============================] - 9s 2s/step - loss: 5.9459e-05 - mae: 0.0043 - val_loss: 4.6839e-05 - val_mae: 0.0044
# Epoch 120/400
# 2/2 [==============================] - 9s 2s/step - loss: 6.6311e-05 - mae: 0.0048 - val_loss: 3.9506e-05 - val_mae: 0.0035
# Epoch 121/400
# 2/2 [==============================] - 9s 2s/step - loss: 6.0808e-05 - mae: 0.0041 - val_loss: 3.2263e-05 - val_mae: 0.0031
# Epoch 122/400
# 2/2 [==============================] - 9s 2s/step - loss: 5.1933e-05 - mae: 0.0038 - val_loss: 3.3139e-05 - val_mae: 0.0036
# Epoch 123/400
# 2/2 [==============================] - 9s 2s/step - loss: 5.3819e-05 - mae: 0.0044 - val_loss: 3.6307e-05 - val_mae: 0.0040
# Epoch 124/400
# 2/2 [==============================] - 9s 2s/step - loss: 5.3899e-05 - mae: 0.0045 - val_loss: 2.8886e-05 - val_mae: 0.0028
# Epoch 125/400
# 2/2 [==============================] - 9s 2s/step - loss: 4.7971e-05 - mae: 0.0036 - val_loss: 4.7225e-05 - val_mae: 0.0050
# Epoch 126/400
# 2/2 [==============================] - 9s 2s/step - loss: 6.2584e-05 - mae: 0.0052 - val_loss: 6.3169e-05 - val_mae: 0.0062
# Epoch 127/400
# 2/2 [==============================] - 9s 2s/step - loss: 7.9351e-05 - mae: 0.0064 - val_loss: 4.7047e-05 - val_mae: 0.0050
# Epoch 128/400
# 2/2 [==============================] - 9s 2s/step - loss: 5.9511e-05 - mae: 0.0049 - val_loss: 2.8010e-05 - val_mae: 0.0030
# Epoch 129/400
# 2/2 [==============================] - 9s 2s/step - loss: 4.4210e-05 - mae: 0.0036 - val_loss: 3.1746e-05 - val_mae: 0.0038
# Epoch 130/400
# 2/2 [==============================] - 9s 2s/step - loss: 4.8360e-05 - mae: 0.0043 - val_loss: 2.8038e-05 - val_mae: 0.0033
# Epoch 131/400
# 2/2 [==============================] - 9s 2s/step - loss: 4.3491e-05 - mae: 0.0038 - val_loss: 3.8275e-05 - val_mae: 0.0044
# Epoch 132/400
# 2/2 [==============================] - 9s 2s/step - loss: 5.3665e-05 - mae: 0.0047 - val_loss: 7.1764e-05 - val_mae: 0.0072
# Epoch 133/400
# 2/2 [==============================] - 9s 2s/step - loss: 8.3938e-05 - mae: 0.0071 - val_loss: 5.2640e-05 - val_mae: 0.0055
# Epoch 134/400
# 2/2 [==============================] - 9s 2s/step - loss: 6.6957e-05 - mae: 0.0056 - val_loss: 2.4145e-05 - val_mae: 0.0026
# Epoch 135/400
# 2/2 [==============================] - 9s 2s/step - loss: 3.9316e-05 - mae: 0.0033 - val_loss: 2.6249e-05 - val_mae: 0.0032
# Epoch 136/400
# 2/2 [==============================] - 9s 2s/step - loss: 4.5520e-05 - mae: 0.0041 - val_loss: 3.5011e-05 - val_mae: 0.0045
# Epoch 137/400
# 2/2 [==============================] - 9s 2s/step - loss: 4.7693e-05 - mae: 0.0047 - val_loss: 3.1909e-05 - val_mae: 0.0041
# Epoch 138/400
# 2/2 [==============================] - 9s 2s/step - loss: 4.7379e-05 - mae: 0.0048 - val_loss: 2.2185e-05 - val_mae: 0.0027
# Epoch 139/400
# 2/2 [==============================] - 9s 2s/step - loss: 3.7798e-05 - mae: 0.0035 - val_loss: 2.3761e-05 - val_mae: 0.0027
# Epoch 140/400
# 2/2 [==============================] - 9s 2s/step - loss: 3.7580e-05 - mae: 0.0032 - val_loss: 3.3473e-05 - val_mae: 0.0040
# Epoch 141/400
# 2/2 [==============================] - 9s 2s/step - loss: 4.6422e-05 - mae: 0.0043 - val_loss: 3.4136e-05 - val_mae: 0.0044
# Epoch 142/400
# 2/2 [==============================] - 9s 2s/step - loss: 4.0881e-05 - mae: 0.0042 - val_loss: 1.9817e-05 - val_mae: 0.0023
# Epoch 143/400
# 2/2 [==============================] - 9s 2s/step - loss: 3.1472e-05 - mae: 0.0028 - val_loss: 2.1141e-05 - val_mae: 0.0027
# Epoch 144/400
# 2/2 [==============================] - 9s 2s/step - loss: 3.2268e-05 - mae: 0.0030 - val_loss: 1.9663e-05 - val_mae: 0.0027
# Epoch 145/400
# 2/2 [==============================] - 9s 2s/step - loss: 3.2815e-05 - mae: 0.0034 - val_loss: 2.2195e-05 - val_mae: 0.0031
# Epoch 146/400
# 2/2 [==============================] - 9s 2s/step - loss: 3.5180e-05 - mae: 0.0037 - val_loss: 2.4849e-05 - val_mae: 0.0036
# Epoch 147/400
# 2/2 [==============================] - 9s 2s/step - loss: 3.4801e-05 - mae: 0.0039 - val_loss: 1.9712e-05 - val_mae: 0.0028
# Epoch 148/400
# 2/2 [==============================] - 9s 2s/step - loss: 3.1878e-05 - mae: 0.0034 - val_loss: 1.8954e-05 - val_mae: 0.0027
# Epoch 149/400
# 2/2 [==============================] - 9s 2s/step - loss: 3.1091e-05 - mae: 0.0033 - val_loss: 2.2593e-05 - val_mae: 0.0033
# Epoch 150/400
# 2/2 [==============================] - 9s 2s/step - loss: 3.2570e-05 - mae: 0.0037 - val_loss: 2.1399e-05 - val_mae: 0.0032
# Epoch 151/400
# 2/2 [==============================] - 9s 2s/step - loss: 3.3956e-05 - mae: 0.0038 - val_loss: 2.9405e-05 - val_mae: 0.0043
# Epoch 152/400
# 2/2 [==============================] - 9s 2s/step - loss: 3.9484e-05 - mae: 0.0046 - val_loss: 5.0362e-05 - val_mae: 0.0062
# Epoch 153/400
# 2/2 [==============================] - 9s 2s/step - loss: 6.2664e-05 - mae: 0.0065 - val_loss: 1.5967e-04 - val_mae: 0.0117
# Epoch 154/400
# 2/2 [==============================] - 9s 2s/step - loss: 1.8428e-04 - mae: 0.0121 - val_loss: 4.0221e-04 - val_mae: 0.0190
# Epoch 155/400
# 2/2 [==============================] - 9s 2s/step - loss: 3.5059e-04 - mae: 0.0171 - val_loss: 1.1077e-04 - val_mae: 0.0097
# Epoch 156/400
# 2/2 [==============================] - 9s 2s/step - loss: 8.9082e-05 - mae: 0.0079 - val_loss: 1.4503e-04 - val_mae: 0.0113
# Epoch 157/400
# 2/2 [==============================] - 9s 2s/step - loss: 1.8056e-04 - mae: 0.0117 - val_loss: 4.4847e-04 - val_mae: 0.0204
# Epoch 158/400
# 2/2 [==============================] - 9s 2s/step - loss: 3.9030e-04 - mae: 0.0183 - val_loss: 3.8798e-05 - val_mae: 0.0032
# Epoch 159/400
# 2/2 [==============================] - 9s 2s/step - loss: 7.8464e-05 - mae: 0.0050 - val_loss: 1.6834e-04 - val_mae: 0.0121

# %%
modelen_mm.load_weights('model_weights_mmbit.h5')

# %%
modelen_mm.save_weights('model_weights_mmbit.h5', overwrite=True)

# %%
# Check how loss & mae went down
epoch_loss = history_mm.history['loss']
epoch_val_loss = history_mm.history['val_loss']

plt.figure(figsize=(20,6),dpi=200)
plt.plot(range(0,len(epoch_loss)), epoch_loss, 'b-', linewidth=2, label='Train Loss')
plt.plot(range(0,len(epoch_val_loss)), epoch_val_loss, 'r-', linewidth=2, label='Val Loss')
plt.title('Evolution of loss on train & validation datasets over epochs')
plt.legend(loc='best')


plt.show()

# %%
start = '2017-01-01'
end = '2019-01-01'
GSPC_test = bit_test#Choose the data
GSPC_test
# Out:
#                         Close
# Open Time
# 2021-01-01 00:01:00  29009.91
# 2021-01-01 00:02:00  28989.30
# 2021-01-01 00:03:00  28982.69
# 2021-01-01 00:04:00  28975.65
# 2021-01-01 00:05:00  28937.11
# ...                       ...
# 2021-05-12 05:35:00  57485.07
# 2021-05-12 05:36:00  57481.49
# 2021-05-12 05:37:00  57470.00
# 2021-05-12 05:38:00  57450.90
# 2021-05-12 05:39:00  57450.19
#
# [188316 rows x 1 columns]

# %%
mm_t = MinMaxScaler()
noise_mm_T=mm_t.fit_transform(GSPC_test)
Y_test_mm_cnn = modelen_mm.predict(noise_mm_T.T)
Y_test_mm_cnn=Y_test_mm_cnn.reshape((len(GSPC_test),1))
pure_mm_cnn = mm_t.inverse_transform(Y_test_mm_cnn)
noise_mm_T=pd.DataFrame(noise_mm_T,columns=['Adj Close'],index=GSPC_test.index)
Y_test_mm_cnn=pd.DataFrame(Y_test_mm_cnn,columns=['Adj Close'],index=GSPC_test.index)
pure_mm_cnn=pd.DataFrame(pure_mm_cnn,columns=['Adj Close'],index=GSPC_test.index)
plt.figure(figsize=(15,4),dpi=200)
plt.plot(pure_mm_cnn)
plt.plot(GSPC_test,'r')
plt.title('Adj close price')
plt.legend(['denoised', 'original'], loc='upper left')
# Out:
# 1/1 [==============================] - 0s 206ms/step

# %%
original=GSPC_test
recon=pure_mm_cnn

# %%
def features(dataset):
    ret_dataset=pd.DataFrame(index=dataset.index)
    for i in range(2,52,1):
        window = i
        # Volatility
        ret_dataset[str('SMA'+str(i))] = talib.SMA(dataset['Adj Close'],timeperiod=window).shift(1)
        ret_dataset[str('EMA'+str(i))] = talib.EMA(dataset['Adj Close'],timeperiod=window).shift(1)
        ret_dataset[str('STDDEV'+str(i))] = talib.STDDEV(dataset['Adj Close'],timeperiod=window).shift(1)
        ret_dataset[str('Lag'+str(i))] = dataset['Adj Close'].shift(i)
    return ret_dataset

# %%
from sklearn.model_selection import TimeSeriesSplit
import xgboost as xgb
import talib
splits=10

# %%
recon_fea=features(recon)
recon_fea=recon_fea.iloc[51:]
original_m=original.iloc[51::]
recon_m=recon.iloc[51::]
tscv = TimeSeriesSplit(n_splits=splits)
msetestav=0

for train_index, test_index in tscv.split(recon_fea):
    model = xgb.XGBRegressor()
    model.fit(recon_fea.iloc[train_index,:],original_m.iloc[train_index,:])
    test_predict=model.predict(recon_fea.iloc[test_index,:])
    msetest=mean_squared_error(original_m.iloc[test_index,:],test_predict)
    i=1+int(len(train_index)/int(len(recon_fea)/splits))
    plt.figure(figsize=(10,15))
    plt.subplot(1 +splits,1,i)
    past=np.asarray(original_m.iloc[train_index,:]).reshape(len(original_m.iloc[train_index,:]))
    whole=np.concatenate((past, test_predict))
    true=np.asarray(original_m.iloc[test_index,:]).reshape(len(original_m.iloc[test_index,:]))
    whole_t=np.concatenate((past, true))
    plt.plot(whole,"r",label='Predicted')
    plt.plot(whole_t,"b",label='Original')
    plt.ylabel('TimeSeriesSplit'+str(i))
    msetestav+=msetest
    print(msetest)
msetestav=msetestav/splits
print('The last MSE:',msetest)
print('The average MSE:',msetestav)
# Out:
# 4345.666452900449
# 2588.2888830457146
# 30625254.054178476
# 6081187.032415942
# 9791.543952229345
# 170693.29706492097
# 2542.0604584936887
# 598957.014773393
# 5590.302897423391
# 3775.5785444924863
# The last MSE: 3775.5785444924863
# The average MSE: 3750472.483962131

# %%
original=pd.DataFrame(original).rename(columns={'Close':'Adj Close'})
original
# Out:
#                      Adj Close
# Open Time
# 2021-01-01 00:01:00   29009.91
# 2021-01-01 00:02:00   28989.30
# 2021-01-01 00:03:00   28982.69
# 2021-01-01 00:04:00   28975.65
# 2021-01-01 00:05:00   28937.11
# ...                        ...
# 2021-05-12 05:35:00   57485.07
# 2021-05-12 05:36:00   57481.49
# 2021-05-12 05:37:00   57470.00
# 2021-05-12 05:38:00   57450.90
# 2021-05-12 05:39:00   57450.19
#
# [188316 rows x 1 columns]

# %%
original_fea=features(original)
original_fea=original_fea.iloc[51:]
original_m=original.iloc[51::]
tscv = TimeSeriesSplit(n_splits=splits)
msetestav=0
for train_index, test_index in tscv.split(original_fea):
    
    model = xgb.XGBRegressor()
    model.fit (original_fea.iloc[train_index,:],original_m.iloc[train_index,:])
    test_predict=model.predict(original_fea.iloc[test_index,:])
    msetest=mean_squared_error(original_m.iloc[test_index,:],test_predict)
    i=1+int(len(train_index)/int(len(recon_fea)/splits))
    plt.figure(figsize=(10,15))
    plt.subplot(1 +splits,1,i)
    past=np.asarray(original_m.iloc[train_index,:]).reshape(len(original_m.iloc[train_index,:]))
    whole=np.concatenate((past, test_predict))
    true=np.asarray(original_m.iloc[test_index,:]).reshape(len(original_m.iloc[test_index,:]))
    whole_t=np.concatenate((past, true))
    plt.plot(whole,"r",label='Predicted')
    plt.plot(whole_t,"b",label='Original')
    plt.ylabel('TimeSeriesSplit'+str(i))
    msetestav+=msetest
    print(msetest)
msetestav=msetestav/splits
print('The last MSE:',msetest)
print('The average MSE:',msetestav)
# Out:
# 6959.288549566705
# 4641.225435585642
# 28271068.21184866
# 6095684.625164483
# 10902.335757344075
# 198253.59791907933
# 3662.9754652226393
# 717363.6937461786
# 8267.96235254641
# 4237.80436168226
# The last MSE: 4237.80436168226
# The average MSE: 3532104.1720600342

# %% [markdown]
# # EMDCNN

# %%
# Log Returns
GSPC_test_n=GSPC_test.copy()
GSPC_test_n['log_ret'] = np.log(GSPC_test.iloc[:,0]).diff()
pure_mm_cnn['log_ret'] = np.log(pure_mm_cnn.iloc[:,0]).diff()


plt.figure(figsize=(20,4),dpi=200)
plt.subplot(1,2,1)
plt.plot(GSPC_test_n['log_ret'], 'r-', linewidth=2, label='Original log return')
plt.ylim(-0.1,0.1)
plt.title('log return of original data')
plt.legend(loc='best')

plt.subplot(1,2,2)
plt.plot(pure_mm_cnn['log_ret'] , 'b-', linewidth=2, label='Denoised log return')
plt.ylim(-0.1,0.1)
plt.title('log return of denoised data(CNN)')
plt.legend(loc='best')


plt.show()

# %%
def svmf1_ori(dataset,dataset2,long_predict=10,percentage=0.8):
    f11=np.empty(0)
    f12=np.empty(0)
    max_t=0
    if dataset['log_ret'].max()>dataset2['log_ret'].max():
        max_t=dataset2['log_ret'].max()
    else:
        max_t=dataset['log_ret'].max()
    for n in np.arange(0.0, (percentage*max_t), (percentage*max_t)/30):#get multiple threshold
        threshold = n
        # for dataset
        daily_label=np.empty(0)#make the data labelled
        for i in range(0,len(dataset)):
            if dataset.iloc[i,1]<-threshold:
                n=-1
                daily_label=np.append(daily_label,n)
            elif abs(dataset.iloc[i,1])<=threshold:
                n=0
                daily_label=np.append(daily_label,n)
            else:
                n=1
                daily_label=np.append(daily_label,n)
        X=pd.DataFrame()
        Y=pd.DataFrame()
        for i in range(1,len(dataset)-long_predict):
            X=pd.concat([X, pd.DataFrame(dataset.iloc[:,1].values[i:i+long_predict]).T],ignore_index=True)#n values of log return to predict trends
            Y=pd.concat([Y, pd.DataFrame(daily_label[i+long_predict:i+long_predict+1]).T],ignore_index=True)#labels of trends
        X=np.array(X)
        Y=np.array(Y[0])
        X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2,random_state=1,shuffle=False)
        svc_rbf = SVC(kernel='rbf',decision_function_shape='ovo')
        model = svc_rbf.fit(X_train,Y_train)
        Y_pred = model.predict(X_test)
        f1 = f1_score(Y_test,Y_pred,average='weighted')
        f11=np.append(f11,f1)
        
        # for dataset2
    for n in np.arange(0.0, (percentage*max_t), (percentage*max_t)/30):#get multiple threshold
        threshold = n
        daily_label2=np.empty(0)#make the data labelled
        for i in range(0,len(dataset2)):
            if dataset.iloc[i,1]<-threshold:
                n=-1
                daily_label2=np.append(daily_label2,n)
            elif abs(dataset.iloc[i,1])<=threshold:
                n=0
                daily_label2=np.append(daily_label2,n)
            else:
                n=1
                daily_label2=np.append(daily_label2,n)
        X=pd.DataFrame()
        Y=pd.DataFrame()
        for i in range(1,len(dataset2)-long_predict):
            X=pd.concat([X, pd.DataFrame(dataset2.iloc[:,1].values[i:i+long_predict]).T],ignore_index=True)#n values of log return to predict trends
            Y=pd.concat([Y, pd.DataFrame(daily_label2[i+long_predict:i+long_predict+1]).T],ignore_index=True)#labels of trends
        X=np.array(X)
        Y=np.array(Y[0])
        X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2,random_state=1,shuffle=False)
        svc_rbf = SVC(kernel='rbf',decision_function_shape='ovo')
        model = svc_rbf.fit(X_train,Y_train)
        Y_pred = model.predict(X_test)
        f1 = f1_score(Y_test,Y_pred,average='weighted')
        f12=np.append(f12,f1)
    return f11,f12

# %%
original_svm_ori,denoised_svm_ori=svmf1_ori(GSPC_test_n,pure_mm_cnn,long_predict=1,percentage=1)

# %%
plt.figure(figsize=(10,3),dpi=100)
percentage=1
max_t=0
if GSPC_test_n['log_ret'].max()>pure_mm_cnn['log_ret'].max():
    max_t=pure_mm_cnn['log_ret'].max()
else:
    max_t=GSPC_test_n['log_ret'].max()
plt.plot(np.arange(0.0,(percentage*max_t), (percentage*max_t)/30),original_svm_ori,label='orignal_svm', color='red', linewidth=1.0)
plt.plot(np.arange(0.0,(percentage*max_t), (percentage*max_t)/30),denoised_svm_ori,label='denoised_svm', color='blue', linewidth=1.0, linestyle='--')

plt.xticks(np.arange(0.0,(percentage*max_t), (percentage*max_t)/6))
plt.xlabel('threshold')
plt.ylabel('f1_value')
plt.legend()

# %% [markdown]
# # Only emd

# %%
emdre=emd_calculate(GSPC_test)
reedm=reconstruction(emdre)

# %%
pure_mm_cnn=pd.DataFrame(reedm.iloc[1,:]).rename(columns={'sum1':'Adj Close'})
pure_mm_cnn
# Out:
#                         Adj Close
# Open Time
# 2021-01-01 00:01:00  29011.754173
# 2021-01-01 00:02:00  28998.744510
# 2021-01-01 00:03:00  28983.301520
# 2021-01-01 00:04:00  28965.643884
# 2021-01-01 00:05:00  28947.819923
# ...                           ...
# 2021-05-12 05:35:00  57492.810371
# 2021-05-12 05:36:00  57474.040430
# 2021-05-12 05:37:00  57464.885043
# 2021-05-12 05:38:00  57458.114393
# 2021-05-12 05:39:00  57444.404361
#
# [188316 rows x 1 columns]

# %%
# Log Returns
GSPC_test_n=GSPC_test.copy()
GSPC_test_n['log_ret'] = np.log(GSPC_test.iloc[:,0]).diff()
pure_mm_cnn['log_ret'] = np.log(pure_mm_cnn.iloc[:,0]).diff()


plt.figure(figsize=(20,4),dpi=200)
plt.subplot(1,2,1)
plt.plot(GSPC_test_n['log_ret'], 'r-', linewidth=2, label='Original log return')
plt.ylim(-0.2,0.2)
plt.title('log return of original data')
plt.legend(loc='best')

plt.subplot(1,2,2)
plt.plot(pure_mm_cnn['log_ret'] , 'b-', linewidth=2, label='Denoised log return')
plt.ylim(-0.2,0.2)
plt.title('log return of denoised data(CNN)')
plt.legend(loc='best')


plt.show()

# %%
GSPC_test=pd.DataFrame(GSPC_test).rename(columns={'Close':'Adj Close'})

# %%
original=pd.DataFrame(GSPC_test['Adj Close'])
recon=pd.DataFrame(pure_mm_cnn['Adj Close'])

# %%
def features(dataset):
    ret_dataset=pd.DataFrame(index=dataset.index)
    for i in range(2,52,1):
        window = i
        # Volatility
        ret_dataset[str('SMA'+str(i))] = talib.SMA(dataset['Adj Close'],timeperiod=window).shift(1)
        ret_dataset[str('EMA'+str(i))] = talib.EMA(dataset['Adj Close'],timeperiod=window).shift(1)
        ret_dataset[str('STDDEV'+str(i))] = talib.STDDEV(dataset['Adj Close'],timeperiod=window).shift(1)
        ret_dataset[str('Lag'+str(i))] = dataset['Adj Close'].shift(i)
    return ret_dataset

# %%
from sklearn.model_selection import TimeSeriesSplit
import xgboost as xgb
import talib
splits=10

# %%
recon_fea=features(recon)
recon_fea=recon_fea.iloc[51:]
original_m=original.iloc[51::]
recon_m=recon.iloc[51::]
tscv = TimeSeriesSplit(n_splits=splits)
msetestav=0

for train_index, test_index in tscv.split(recon_fea):
    model = xgb.XGBRegressor()
    model.fit(recon_fea.iloc[train_index,:],original_m.iloc[train_index,:])
    test_predict=model.predict(recon_fea.iloc[test_index,:])
    msetest=mean_squared_error(original_m.iloc[test_index,:],test_predict)
    i=1+int(len(train_index)/int(len(recon_fea)/splits))
    plt.figure(figsize=(10,15))
    plt.subplot(1 +splits,1,i)
    past=np.asarray(original_m.iloc[train_index,:]).reshape(len(original_m.iloc[train_index,:]))
    whole=np.concatenate((past, test_predict))
    true=np.asarray(original_m.iloc[test_index,:]).reshape(len(original_m.iloc[test_index,:]))
    whole_t=np.concatenate((past, true))
    plt.plot(whole,"r",label='Predicted')
    plt.plot(whole_t,"b",label='Original')
    plt.ylabel('TimeSeriesSplit'+str(i))
    print(msetest)
    msetestav+=msetest
msetestav=msetestav/splits
print('The last MSE:',msetest)
print('The average MSE:',msetestav)
# Out:
# 5036.898512939216
# 3392.601675801687
# 27773179.98963661
# 6036827.555560247
# 10274.759888982268
# 196104.92407630896
# 3081.3663654929774
# 679774.8453030193
# 6659.9219486224165
# 3176.919211401009
# The last MSE: 3176.919211401009
# The average MSE: 3471750.978217943

# %%
original_fea=features(original)
original_fea=original_fea.iloc[51:]
original_m=original.iloc[51::]
tscv = TimeSeriesSplit(n_splits=splits)
msetestav=0
for train_index, test_index in tscv.split(original_fea):
    model = xgb.XGBRegressor()
    model.fit (original_fea.iloc[train_index,:],original_m.iloc[train_index,:])
    test_predict=model.predict(original_fea.iloc[test_index,:])
    msetest=mean_squared_error(original_m.iloc[test_index,:],test_predict)
    i=1+int(len(train_index)/int(len(recon_fea)/splits))
    plt.figure(figsize=(10,15))
    plt.subplot(1 +splits,1,i)
    past=np.asarray(original_m.iloc[train_index,:]).reshape(len(original_m.iloc[train_index,:]))
    whole=np.concatenate((past, test_predict))
    true=np.asarray(original_m.iloc[test_index,:]).reshape(len(original_m.iloc[test_index,:]))
    whole_t=np.concatenate((past, true))
    plt.plot(whole,"r",label='Predicted')
    plt.plot(whole_t,"b",label='Original')
    plt.ylabel('TimeSeriesSplit'+str(i))
    print(msetest)
    msetestav+=msetest
msetestav=msetestav/splits
print('The last MSE:',msetest)
print('The average MSE:',msetestav)
# Out:
# 6959.288549566705
# 4641.225435585642
# 28271068.21184866
# 6095684.625164483
# 10902.335757344075
# 198253.59791907933
# 3662.9754652226393
# 717363.6937461786
# 8267.96235254641
# 4237.80436168226
# The last MSE: 4237.80436168226
# The average MSE: 3532104.1720600342

# %%
def svmf1_ori(dataset,dataset2,long_predict=10,percentage=1):
    f11=np.empty(0)
    f12=np.empty(0)
    max_t=0
    if dataset['log_ret'].max()>dataset2['log_ret'].max():
        max_t=dataset2['log_ret'].max()
    else:
        max_t=dataset['log_ret'].max()
    for n in np.arange(0.0, (percentage*max_t), (percentage*max_t)/30):#get multiple threshold
        threshold = n
        # for dataset
        daily_label=np.empty(0)#make the data labelled
        for i in range(0,len(dataset)):
            if dataset.iloc[i,1]<-threshold:
                n=-1
                daily_label=np.append(daily_label,n)
            elif abs(dataset.iloc[i,1])<=threshold:
                n=0
                daily_label=np.append(daily_label,n)
            else:
                n=1
                daily_label=np.append(daily_label,n)
        X=pd.DataFrame()
        Y=pd.DataFrame()
        for i in range(1,len(dataset)-long_predict):
            X=pd.concat([X, pd.DataFrame(dataset.iloc[:,1].values[i:i+long_predict]).T],ignore_index=True)#n values of log return to predict trends
            Y=pd.concat([Y, pd.DataFrame(daily_label[i+long_predict:i+long_predict+1]).T],ignore_index=True)#labels of trends
        X=np.array(X)
        Y=np.array(Y[0])
        X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2,random_state=1,shuffle=False)
        svc_rbf = SVC(kernel='rbf',decision_function_shape='ovo')
        model = svc_rbf.fit(X_train,Y_train)
        Y_pred = model.predict(X_test)
        f1 = f1_score(Y_test,Y_pred,average='weighted')
        f11=np.append(f11,f1)
        
        # for dataset2
    for n in np.arange(0.0, (0.5*max_t), (0.5*max_t)/30):#get multiple threshold
        threshold = n
        daily_label2=np.empty(0)#make the data labelled
        for i in range(0,len(dataset2)):
            if dataset.iloc[i,1]<-threshold:
                n=-1
                daily_label2=np.append(daily_label2,n)
            elif abs(dataset.iloc[i,1])<=threshold:
                n=0
                daily_label2=np.append(daily_label2,n)
            else:
                n=1
                daily_label2=np.append(daily_label2,n)
        X=pd.DataFrame()
        Y=pd.DataFrame()
        for i in range(1,len(dataset2)-long_predict):
            X=pd.concat([X, pd.DataFrame(dataset2.iloc[:,1].values[i:i+long_predict]).T],ignore_index=True)#n values of log return to predict trends
            Y=pd.concat([Y, pd.DataFrame(daily_label2[i+long_predict:i+long_predict+1]).T],ignore_index=True)#labels of trends
        X=np.array(X)
        Y=np.array(Y[0])
        X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2,random_state=1,shuffle=False)
        svc_rbf = SVC(kernel='rbf',decision_function_shape='ovo')
        model = svc_rbf.fit(X_train,Y_train)
        Y_pred = model.predict(X_test)
        f1 = f1_score(Y_test,Y_pred,average='weighted')
        f12=np.append(f12,f1)
    return f11,f12

# %%
original_svm_ori,denoised_svm_ori=svmf1_ori(GSPC_test_n,pure_mm_cnn,long_predict=1)

# %%
plt.figure(figsize=(10,3),dpi=100)
percentage=1
max_t=0
if GSPC_test_n['log_ret'].max()>pure_mm_cnn['log_ret'].max():
    max_t=pure_mm_cnn['log_ret'].max()
else:
    max_t=GSPC_test_n['log_ret'].max()
plt.plot(np.arange(0.0,(percentage*max_t), (percentage*max_t)/30),original_svm_ori,label='orignal_svm', color='red', linewidth=1.0)
plt.plot(np.arange(0.0,(percentage*max_t), (percentage*max_t)/30),denoised_svm_ori,label='denoised_svm', color='blue', linewidth=1.0, linestyle='--')

plt.xticks(np.arange(0.0,(percentage*max_t), (percentage*max_t)/6))
plt.xlabel('threshold')
plt.ylabel('f1_value')
plt.legend()

# %%
pd.DataFrame(original_svm_ori).to_csv('original_svm_ori_emd.csv')
pd.DataFrame(denoised_svm_ori).to_csv('denoised_svm_ori_emd.csv')
