# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"   
import cv2
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler, Normalizer
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, UpSampling1D, Dropout, BatchNormalization, Input, Layer, Dense,LSTM
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers.schedules import LearningRateSchedule
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.metrics import Mean, SparseCategoricalAccuracy
from pandas_datareader import data
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC#Download data from the web via this package


from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
GSPC = pd.read_csv('GSPC_index_close_test123.csv')
del GSPC['Date']
GSPC=GSPC.T
GSPC_noisy = pd.DataFrame(np.repeat(GSPC.values,100,axis=0))
GSPC_noisy=GSPC_noisy.iloc[:, 52:]

# %%
GSPC_noisy
# Out:
#             52          53           54           55          56   \
# 0   2373.469971  2344.02002  2348.449951  2345.959961  2343.97998
# 1   2373.469971  2344.02002  2348.449951  2345.959961  2343.97998
# 2   2373.469971  2344.02002  2348.449951  2345.959961  2343.97998
# 3   2373.469971  2344.02002  2348.449951  2345.959961  2343.97998
# 4   2373.469971  2344.02002  2348.449951  2345.959961  2343.97998
# ..          ...         ...          ...          ...         ...
# 95  2373.469971  2344.02002  2348.449951  2345.959961  2343.97998
# 96  2373.469971  2344.02002  2348.449951  2345.959961  2343.97998
# 97  2373.469971  2344.02002  2348.449951  2345.959961  2343.97998
# 98  2373.469971  2344.02002  2348.449951  2345.959961  2343.97998
# 99  2373.469971  2344.02002  2348.449951  2345.959961  2343.97998
#
#             57           58           59           60           61   ...  \
# 0   2341.590088  2358.570068  2361.129883  2368.060059  2362.719971  ...
# 1   2341.590088  2358.570068  2361.129883  2368.060059  2362.719971  ...
# 2   2341.590088  2358.570068  2361.129883  2368.060059  2362.719971  ...
# 3   2341.590088  2358.570068  2361.129883  2368.060059  2362.719971  ...
# 4   2341.590088  2358.570068  2361.129883  2368.060059  2362.719971  ...
# ..          ...          ...          ...          ...          ...  ...
# 95  2341.590088  2358.570068  2361.129883  2368.060059  2362.719971  ...
# 96  2341.590088  2358.570068  2361.129883  2368.060059  2362.719971  ...
# 97  2341.590088  2358.570068  2361.129883  2368.060059  2362.719971  ...
# 98  2341.590088  2358.570068  2361.129883  2368.060059  2362.719971  ...
# 99  2341.590088  2358.570068  2361.129883  2368.060059  2362.719971  ...
#
#             492          493          494          495          496  \
# 0   2545.939941  2546.159912  2506.959961  2467.419922  2416.620117
# 1   2545.939941  2546.159912  2506.959961  2467.419922  2416.620117
# 2   2545.939941  2546.159912  2506.959961  2467.419922  2416.620117
# 3   2545.939941  2546.159912  2506.959961  2467.419922  2416.620117
# 4   2545.939941  2546.159912  2506.959961  2467.419922  2416.620117
# ..          ...          ...          ...          ...          ...
# 95  2545.939941  2546.159912  2506.959961  2467.419922  2416.620117
# 96  2545.939941  2546.159912  2506.959961  2467.419922  2416.620117
# 97  2545.939941  2546.159912  2506.959961  2467.419922  2416.620117
# 98  2545.939941  2546.159912  2506.959961  2467.419922  2416.620117
# 99  2545.939941  2546.159912  2506.959961  2467.419922  2416.620117
#
#             497          498          499         500          501
# 0   2351.100098  2467.699951  2488.830078  2485.73999  2506.850098
# 1   2351.100098  2467.699951  2488.830078  2485.73999  2506.850098
# 2   2351.100098  2467.699951  2488.830078  2485.73999  2506.850098
# 3   2351.100098  2467.699951  2488.830078  2485.73999  2506.850098
# 4   2351.100098  2467.699951  2488.830078  2485.73999  2506.850098
# ..          ...          ...          ...         ...          ...
# 95  2351.100098  2467.699951  2488.830078  2485.73999  2506.850098
# 96  2351.100098  2467.699951  2488.830078  2485.73999  2506.850098
# 97  2351.100098  2467.699951  2488.830078  2485.73999  2506.850098
# 98  2351.100098  2467.699951  2488.830078  2485.73999  2506.850098
# 99  2351.100098  2467.699951  2488.830078  2485.73999  2506.850098
#
# [100 rows x 450 columns]

# %%
plt.plot(GSPC_noisy.iloc[0],label='Close price')
plt.title('Orignal close data')
plt.legend()

# %%
close=np.array(GSPC)[0]
GSPC_pure=pd.DataFrame()
for i in range(2,52):#SMA
    #print(i)
    n=np.ones(i)
    weights_sma=n/i
    empty=np.ones(i-1)
    sma=np.convolve(weights_sma, close, mode='valid')
    sma_full=np.hstack((empty,sma))
    GSPC_pure=pd.concat([GSPC_pure, pd.DataFrame(sma_full).T],ignore_index=True)
    weights_ema=np.exp(np.linspace(0,1,i))
    weights_ema =weights_ema/np.sum(weights_ema)
    ema=np.convolve(weights_ema, close, mode='valid')
    ema_full=np.hstack((empty,sma))
    GSPC_pure=pd.concat([GSPC_pure, pd.DataFrame(ema_full).T],ignore_index=True)
GSPC_pure=GSPC_pure.iloc[:, 52:]

# %%
GSPC_pure
# Out:
#             52           53           54           55           56   \
# 0   2375.859985  2358.744995  2346.234985  2347.204956  2344.969971
# 1   2375.859985  2358.744995  2346.234985  2347.204956  2344.969971
# 2   2377.699951  2365.246663  2355.313314  2346.143311  2346.129964
# 3   2377.699951  2365.246663  2355.313314  2346.143311  2346.129964
# 4   2379.589966  2369.279968  2361.047485  2352.974976  2345.602478
# ..          ...          ...          ...          ...          ...
# 95  2325.683464  2327.216528  2328.839998  2330.281629  2331.782446
# 96  2324.709395  2326.050195  2327.641196  2329.182397  2330.555596
# 97  2324.709395  2326.050195  2327.641196  2329.182397  2330.555596
# 98  2323.617053  2325.088034  2326.489406  2328.000388  2329.472546
# 99  2323.617053  2325.088034  2326.489406  2328.000388  2329.472546
#
#             57           58           59           60           61   ...  \
# 0   2342.785034  2350.080078  2359.849976  2364.594971  2365.390015  ...
# 1   2342.785034  2350.080078  2359.849976  2364.594971  2365.390015  ...
# 2   2343.843343  2348.046712  2353.763346  2362.586670  2363.969971  ...
# 3   2343.843343  2348.046712  2353.763346  2362.586670  2363.969971  ...
# 4   2344.994995  2347.525024  2351.317505  2357.337524  2362.619995  ...
# ..          ...          ...          ...          ...          ...  ...
# 95  2333.148776  2334.999392  2336.820616  2338.950619  2340.816127  ...
# 96  2331.978599  2333.657202  2335.522002  2337.445405  2339.426006  ...
# 97  2331.978599  2333.657202  2335.522002  2337.445405  2339.426006  ...
# 98  2330.771958  2332.500000  2334.195882  2336.160003  2337.940985  ...
# 99  2330.771958  2332.500000  2334.195882  2336.160003  2337.940985  ...
#
#             492          493          494          495          496  \
# 0   2572.944946  2546.049927  2526.559937  2487.189941  2442.020020
# 1   2572.944946  2546.049927  2526.559937  2487.189941  2442.020020
# 2   2598.809977  2564.016602  2533.019938  2506.846598  2463.666667
# 3   2598.809977  2564.016602  2533.019938  2506.846598  2463.666667
# 4   2611.875000  2585.647461  2549.752441  2516.619934  2484.289978
# ..          ...          ...          ...          ...          ...
# 95  2719.067343  2712.163873  2704.543871  2698.048768  2691.686523
# 96  2722.397397  2715.609194  2708.059795  2699.801392  2692.420195
# 97  2722.397397  2715.609194  2708.059795  2699.801392  2692.420195
# 98  2725.911372  2718.941760  2711.518033  2703.341366  2694.248818
# 99  2725.911372  2718.941760  2711.518033  2703.341366  2694.248818
#
#             497          498          499          500          501
# 0   2383.860107  2409.400024  2478.265015  2487.285034  2496.295044
# 1   2383.860107  2409.400024  2478.265015  2487.285034  2496.295044
# 2   2411.713379  2411.806722  2435.876709  2480.756673  2493.806722
# 3   2411.713379  2411.806722  2435.876709  2480.756673  2493.806722
# 4   2435.525024  2425.710022  2431.062561  2448.342529  2487.280029
# ..          ...          ...          ...          ...          ...
# 95  2683.196120  2677.418771  2670.865917  2664.264489  2658.918980
# 96  2684.874795  2678.886196  2673.646997  2667.163398  2661.116201
# 97  2684.874795  2678.886196  2673.646997  2667.163398  2661.116201
# 98  2685.727644  2680.616465  2675.159606  2669.962546  2664.020000
# 99  2685.727644  2680.616465  2675.159606  2669.962546  2664.020000
#
# [100 rows x 450 columns]

# %% [markdown]
# ## MinMaxScaler

# %%
mm = MinMaxScaler()
noise_mm = mm.fit_transform(GSPC_noisy.T).T
prue_mm=mm.transform(GSPC_pure.T).T

# %%
train_cleaned_mm=np.reshape(prue_mm, (100, 450, 1))
train_mm=np.reshape(noise_mm, (100, 450, 1))

# %%
# convert list to numpy array
X_train_mm = np.asarray(train_mm)
Y_train_mm = np.asarray(train_cleaned_mm)
X_train_mm, X_val_mm, Y_train_mm, Y_val_mm = train_test_split(X_train_mm, Y_train_mm, test_size=0.2,random_state=0)

# %% [markdown]
# ## LSTM

# %%
def set_model_LSTM():
    model = Sequential()
    model.add(LSTM(128, input_shape=(450, 1),activation='tanh', return_sequences = True))
    model.add(LSTM(64, activation='tanh',return_sequences = True))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(2, padding='same'))
    model.add(Dropout(0.2))
    model.add(LSTM(64, activation='tanh',return_sequences = True))
    model.add(LSTM(128, activation='tanh',return_sequences = True))
    model.add(BatchNormalization())
    model.add(UpSampling1D(2))
    model.add(Dense(1,activation='sigmoid'))
    model.compile(optimizer='adam' , loss='mean_squared_error', metrics=['mse'])
    return model
modelen_LSTM = set_model_LSTM()
modelen_LSTM.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_36 (LSTM)              (None, 450, 128)          66560
#
#  lstm_37 (LSTM)              (None, 450, 64)           49408
#
#  batch_normalization_28 (Bat  (None, 450, 64)          256
#  chNormalization)
#
#  max_pooling1d_12 (MaxPoolin  (None, 225, 64)          0
#  g1D)
#
#  dropout_6 (Dropout)         (None, 225, 64)           0
#
#  lstm_38 (LSTM)              (None, 225, 64)           33024
#
#  lstm_39 (LSTM)              (None, 225, 128)          98816
#
#  batch_normalization_29 (Bat  (None, 225, 128)         512
#  chNormalization)
#
#  up_sampling1d_12 (UpSamplin  (None, 450, 128)         0
#  g1D)
#
#  dense_9 (Dense)             (None, 450, 1)            129
#
# =================================================================
# Total params: 248,705
# Trainable params: 248,321
# Non-trainable params: 384
# _________________________________________________________________

# %%
callback = EarlyStopping(monitor='loss', patience=30)
history_LSTM = modelen_LSTM.fit(X_train_mm, Y_train_mm, validation_data = (X_val_mm, Y_val_mm), epochs=200, batch_size=8, verbose=1, callbacks=[callback])
# Out:
# Epoch 1/200
# 10/10 [==============================] - 9s 509ms/step - loss: 0.0251 - mse: 0.0251 - val_loss: 0.0646 - val_mse: 0.0646
# Epoch 2/200
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0589 - val_mse: 0.0589
# Epoch 3/200
# 10/10 [==============================] - 4s 391ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0563 - val_mse: 0.0563
# Epoch 4/200
# 10/10 [==============================] - 4s 390ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0540 - val_mse: 0.0540
# Epoch 5/200
# 10/10 [==============================] - 4s 387ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0517 - val_mse: 0.0517
# Epoch 6/200
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0492 - val_mse: 0.0492
# Epoch 7/200
# 10/10 [==============================] - 4s 387ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0477 - val_mse: 0.0477
# Epoch 8/200
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0452 - val_mse: 0.0452
# Epoch 9/200
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0431 - val_mse: 0.0431
# Epoch 10/200
# 10/10 [==============================] - 4s 384ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0404 - val_mse: 0.0404
# Epoch 11/200
# 10/10 [==============================] - 4s 388ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0385 - val_mse: 0.0385
# Epoch 12/200
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0367 - val_mse: 0.0367
# Epoch 13/200
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0348 - val_mse: 0.0348
# Epoch 14/200
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0320 - val_mse: 0.0320
# Epoch 15/200
# 10/10 [==============================] - 4s 384ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0292 - val_mse: 0.0292
# Epoch 16/200
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0286 - val_mse: 0.0286
# Epoch 17/200
# 10/10 [==============================] - 4s 384ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0274 - val_mse: 0.0274
# Epoch 18/200
# 10/10 [==============================] - 4s 384ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0267 - val_mse: 0.0267
# Epoch 19/200
# 10/10 [==============================] - 4s 384ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0243 - val_mse: 0.0243
# Epoch 20/200
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0243 - val_mse: 0.0243
# Epoch 21/200
# 10/10 [==============================] - 4s 387ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0231 - val_mse: 0.0231
# Epoch 22/200
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0234 - val_mse: 0.0234
# Epoch 23/200
# 10/10 [==============================] - 4s 384ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0209 - val_mse: 0.0209
# Epoch 24/200
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0202 - val_mse: 0.0202
# Epoch 25/200
# 10/10 [==============================] - 4s 384ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0182 - val_mse: 0.0182
# Epoch 26/200
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0197 - val_mse: 0.0197
# Epoch 27/200
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0180 - val_mse: 0.0180
# Epoch 28/200
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0180 - val_mse: 0.0180
# Epoch 29/200
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0178 - val_mse: 0.0178
# Epoch 30/200
# 10/10 [==============================] - 4s 384ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0158 - val_mse: 0.0158
# Epoch 31/200
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0149 - val_mse: 0.0149
# Epoch 32/200
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0162 - val_mse: 0.0162
# Epoch 33/200
# 10/10 [==============================] - 4s 384ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0167 - val_mse: 0.0167
# Epoch 34/200
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0162 - val_mse: 0.0162
# Epoch 35/200
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0156 - val_mse: 0.0156
# Epoch 36/200
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0142 - val_mse: 0.0142
# Epoch 37/200
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0144 - val_mse: 0.0144
# Epoch 38/200
# 10/10 [==============================] - 4s 388ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0149 - val_mse: 0.0149
# Epoch 39/200
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0149 - val_mse: 0.0149
# Epoch 40/200
# 10/10 [==============================] - 4s 387ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0146 - val_mse: 0.0146
# Epoch 41/200
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0149 - val_mse: 0.0149
# Epoch 42/200
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0138 - val_mse: 0.0138
# Epoch 43/200
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0118 - val_mse: 0.0118
# Epoch 44/200
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 45/200
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 46/200
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0134 - val_mse: 0.0134
# Epoch 47/200
# 10/10 [==============================] - 4s 392ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0132 - val_mse: 0.0132
# Epoch 48/200
# 10/10 [==============================] - 4s 396ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 49/200
# 10/10 [==============================] - 4s 392ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 50/200
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 51/200
# 10/10 [==============================] - 4s 390ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 52/200
# 10/10 [==============================] - 4s 399ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 53/200
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 54/200
# 10/10 [==============================] - 4s 387ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 55/200
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 56/200
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 57/200
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 58/200
# 10/10 [==============================] - 4s 387ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 59/200
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 60/200
# 10/10 [==============================] - 4s 384ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 61/200
# 10/10 [==============================] - 4s 388ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 62/200
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 63/200
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 64/200
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 65/200
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 66/200
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 67/200
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 68/200
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 69/200
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 70/200
# 10/10 [==============================] - 4s 388ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 71/200
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 72/200
# 10/10 [==============================] - 4s 387ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 73/200
# 10/10 [==============================] - 4s 384ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 74/200
# 10/10 [==============================] - 4s 384ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 75/200
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 76/200
# 10/10 [==============================] - 4s 384ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 77/200
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 78/200
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 79/200
# 10/10 [==============================] - 4s 384ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 80/200
# 10/10 [==============================] - 4s 383ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 81/200
# 10/10 [==============================] - 4s 387ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 82/200
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 83/200
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 84/200
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 85/200
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 86/200
# 10/10 [==============================] - 4s 387ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 87/200
# 10/10 [==============================] - 4s 387ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 88/200
# 10/10 [==============================] - 4s 384ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 89/200
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 90/200
# 10/10 [==============================] - 4s 400ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 91/200
# 10/10 [==============================] - 4s 407ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 92/200
# 10/10 [==============================] - 4s 387ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 93/200
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 94/200
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 95/200
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 96/200
# 10/10 [==============================] - 4s 384ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 97/200
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 98/200
# 10/10 [==============================] - 4s 384ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 99/200
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 100/200
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 101/200
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 102/200
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 103/200
# 10/10 [==============================] - 4s 385ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 104/200
# 10/10 [==============================] - 4s 386ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 105/200
# 10/10 [==============================] - 4s 384ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 106/200
# 10/10 [==============================] - 4s 384ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0023 - val_mse: 0.0023

# %%
modelen_LSTM.save_weights('model_weights_LSTM.h5', overwrite=True)

# %%
modelen_LSTM.load_weights('model_weights_LSTM.h5')

# %%
# Check how loss & mae went down
epoch_loss = history_LSTM.history['loss']
epoch_val_loss = history_LSTM.history['val_loss']
epoch_mse = history_LSTM.history['mse']
epoch_val_mse = history_LSTM.history['val_mse']

plt.figure(figsize=(20,6))
plt.subplot(1,2,1)
plt.plot(range(0,len(epoch_loss)), epoch_loss, 'b-', linewidth=2, label='Train Loss')
plt.plot(range(0,len(epoch_val_loss)), epoch_val_loss, 'r-', linewidth=2, label='Val Loss')
plt.title('Evolution of loss on train & validation datasets over epochs')
plt.legend(loc='best')

plt.subplot(1,2,2)
plt.plot(range(0,len(epoch_mse)), epoch_mse, 'b-', linewidth=2, label='Train MSE')
plt.plot(range(0,len(epoch_val_mse)), epoch_val_mse, 'r-', linewidth=2,label='Val MSE')
plt.title('Evolution of MSE on train & validation datasets over epochs')
plt.legend(loc='best')

plt.show()

# %%
GSPC_test = pd.read_csv('GSPC_index_close_test123.csv')
Date=pd.to_datetime(GSPC_test['Date'])
del GSPC_test['Date']
#GSPC_test=GSPC_test.T
GSPC_test=GSPC_test[0:450]

# %%
mm_t = MinMaxScaler()
noise_mm_T=mm_t.fit_transform(GSPC_test)
Y_test_mm_lstm = modelen_LSTM.predict(noise_mm_T.T, batch_size=32)
Y_test_mm_lstm=Y_test_mm_lstm.reshape((450,1))
pure_mm_lstm = mm_t.inverse_transform(Y_test_mm_lstm)
plt.figure(figsize=(10,6))
plt.plot(pure_mm_lstm,'r')
plt.plot(GSPC_test)
plt.title('2017-2019 450 values')
plt.legend(['denoised', 'original'], loc='upper left')
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
def set_model_encoding_mm():
    model = Sequential()
    #encoding
    model.add(Conv1D(128, kernel_size=3, activation='tanh', padding='same',input_shape=(450, 1)))
    model.add(Conv1D(64, kernel_size=3,activation='tanh',padding='same'))
    model.add(BatchNormalization())
    #Use the normalization preprocessing of the data as mentioned before, so that the input x does not vary too much
    model.add(MaxPooling1D(2, padding='same'))
    model.add(Dropout(0.2))
    #decoding
    model.add(Conv1D(64, kernel_size=3, activation='tanh', padding='same'))
    model.add(Conv1D(128, kernel_size=3,activation='tanh',padding='same'))
    model.add(BatchNormalization())
    model.add(UpSampling1D(2))
    
    model.add(Conv1D(1,kernel_size=3,activation='sigmoid', padding='same'))
    model.compile(optimizer='Adadelta' , loss='mean_squared_error', metrics=['mse'])
    
    return model
modelen_mm = set_model_encoding_mm()
modelen_mm.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_10 (Conv1D)          (None, 450, 128)          512
#
#  conv1d_11 (Conv1D)          (None, 450, 64)           24640
#
#  batch_normalization_22 (Bat  (None, 450, 64)          256
#  chNormalization)
#
#  max_pooling1d_9 (MaxPooling  (None, 225, 64)          0
#  1D)
#
#  dropout_3 (Dropout)         (None, 225, 64)           0
#
#  conv1d_12 (Conv1D)          (None, 225, 64)           12352
#
#  conv1d_13 (Conv1D)          (None, 225, 128)          24704
#
#  batch_normalization_23 (Bat  (None, 225, 128)         512
#  chNormalization)
#
#  up_sampling1d_9 (UpSampling  (None, 450, 128)         0
#  1D)
#
#  conv1d_14 (Conv1D)          (None, 450, 1)            385
#
# =================================================================
# Total params: 63,361
# Trainable params: 62,977
# Non-trainable params: 384
# _________________________________________________________________

# %%
callback = EarlyStopping(monitor='loss', patience=100)
history_mm = modelen_mm.fit(X_train_mm, Y_train_mm, validation_data = (X_val_mm, Y_val_mm), epochs=500, batch_size=8, verbose=1, callbacks=[callback])
# Out:
# Epoch 1/500
# 10/10 [==============================] - 2s 41ms/step - loss: 0.2763 - mse: 0.2763 - val_loss: 0.0817 - val_mse: 0.0817
# Epoch 2/500
# 10/10 [==============================] - 0s 24ms/step - loss: 0.2682 - mse: 0.2682 - val_loss: 0.0820 - val_mse: 0.0820
# Epoch 3/500
# 10/10 [==============================] - 0s 24ms/step - loss: 0.2579 - mse: 0.2579 - val_loss: 0.0824 - val_mse: 0.0824
# Epoch 4/500
# 10/10 [==============================] - 0s 25ms/step - loss: 0.2482 - mse: 0.2482 - val_loss: 0.0828 - val_mse: 0.0828
# Epoch 5/500
# 10/10 [==============================] - 0s 25ms/step - loss: 0.2369 - mse: 0.2369 - val_loss: 0.0831 - val_mse: 0.0831
# Epoch 6/500
# 10/10 [==============================] - 0s 25ms/step - loss: 0.2260 - mse: 0.2260 - val_loss: 0.0834 - val_mse: 0.0834
# Epoch 7/500
# 10/10 [==============================] - 0s 25ms/step - loss: 0.2151 - mse: 0.2151 - val_loss: 0.0837 - val_mse: 0.0837
# Epoch 8/500
# 10/10 [==============================] - 0s 24ms/step - loss: 0.2026 - mse: 0.2026 - val_loss: 0.0840 - val_mse: 0.0840
# Epoch 9/500
# 10/10 [==============================] - 0s 24ms/step - loss: 0
# 77  0.489510  0.449349  0.418974  0.387658  0.365400  0.345761
# 78  0.527340  0.502142  0.484291  0.470871  0.460493  0.450982
# 79  0.576948  0.564587  0.554947  0.548062  0.541760  0.534636
#
# [80 rows x 450 columns]

# %%
modelen_mm.save_weights('model_weights_mm.h5', overwrite=True)

# %%
# Check how loss & mae went down
epoch_loss = history_mm.history['loss']
epoch_val_loss = history_mm.history['val_loss']
epoch_mse = history_mm.history['mse']
epoch_val_mse = history_mm.history['val_mse']

plt.figure(figsize=(20,6))
plt.subplot(1,2,1)
plt.plot(range(0,len(epoch_loss)), epoch_loss, 'b-', linewidth=2, label='Train Loss')
plt.plot(range(0,len(epoch_val_loss)), epoch_val_loss, 'r-', linewidth=2, label='Val Loss')
plt.title('Evolution of loss on train & validation datasets over epochs')
plt.legend(loc='best')

plt.subplot(1,2,2)
plt.plot(range(0,len(epoch_mse)), epoch_mse, 'b-', linewidth=2, label='Train MSE')
plt.plot(range(0,len(epoch_val_mse)), epoch_val_mse, 'r-', linewidth=2,label='Val MSE')
plt.title('Evolution of MSE on train & validation datasets over epochs')
plt.legend(loc='best')

plt.show()

# %%
modelen_mm.load_weights('model_weights_mm.h5')

# %%
GSPC_test = pd.read_csv('GSPC_index_close_test123.csv')
Date=pd.to_datetime(GSPC_test['Date'])
del GSPC_test['Date']
#GSPC_test=GSPC_test.T
GSPC_test=GSPC_test[0:450]

# %%
mm_t = MinMaxScaler()
noise_mm_T=mm_t.fit_transform(GSPC_test)
Y_test_mm_cnn = modelen_mm.predict(noise_mm_T.T, batch_size=8)
Y_test_mm_cnn=Y_test_mm_cnn.reshape((450,1))
pure_mm_cnn = mm_t.inverse_transform(Y_test_mm_cnn)
plt.figure(figsize=(10,6))
plt.plot(pure_mm_cnn,'r')
plt.plot(GSPC_test)
plt.title('2017-2019 450 values')
plt.legend(['denoised', 'original'], loc='upper left')
# Out:
# 1/1 [==============================] - 0s 114ms/step

# %%
pure_mm_cnn
a=pd.DataFrame(pure_mm_cnn.reshape(450))
a.T
# Out:
#            0            1            2            3            4    \
# 0  2363.345947  2317.814209  2371.842285  2329.071045  2310.946777
#
#            5            6            7            8            9    ...  \
# 0  2288.307373  2288.834961  2289.037354  2288.751709  2289.680908  ...
#
#            440          441          442          443          444  \
# 0  2889.846436  2885.429443  2886.505127  2890.063965  2870.776367
#
#            445          446          447          448          449
# 0  2843.274414  2876.717529  2872.759033  2866.932373  2763.390625
#
# [1 rows x 450 columns]

# %%
def log_return(dataset):
    daily_log_rets = np.diff(np.log(dataset).T)
    daily_log_rets=daily_log_rets.reshape(len(dataset)-1)
    daily_rets_series = pd.DataFrame(daily_log_rets)#calculate the log return
    return daily_rets_series

# %%
o=log_return(GSPC_test)
d_cnn=log_return(pure_mm_cnn)
d_lstm=log_return(pure_mm_lstm)

plt.figure(figsize=(20,6))
plt.subplot(1,3,1)
plt.plot(o, 'r-', linewidth=2, label='Original log return')
plt.ylim(-0.2,0.2)
plt.title('log return of original data')
plt.legend(loc='best')

plt.subplot(1,3,2)
plt.plot(d_cnn, 'b-', linewidth=2, label='Denoised log return')
plt.ylim(-0.2,0.2)
plt.title('log return of denoised data(CNN)')
plt.legend(loc='best')

plt.subplot(1,3,3)
plt.plot(d_lstm, 'y-', linewidth=2, label='Denoised log return')
plt.ylim(-0.2,0.2)
plt.title('log return of denoised data(LSTM)')
plt.legend(loc='best')

plt.show()

# %%
def svmf1(dataset,long_predict=10):
    daily_log_rets = np.diff(np.log(dataset).T)
    daily_log_rets=daily_log_rets.reshape(len(dataset)-1)
    daily_rets_series = pd.DataFrame(daily_log_rets)#calculate the log return
    f1=np.empty(0)
    for n in range(0,1500,5):#get multiple threshold
        threshold = n/100000
        daily_label=np.empty(0)#make the data labelled
        for i in range(0,len(daily_rets_series)):
            if daily_rets_series.iloc[i,0]<-threshold:
                n=-1
                daily_label=np.append(daily_label,n)
            elif abs(daily_rets_series.iloc[i,0])<=threshold:
                n=0
                daily_label=np.append(daily_label,n)
            else:
                n=1
                daily_label=np.append(daily_label,n)
        X=pd.DataFrame()
        Y=pd.DataFrame()
        for i in range(len(daily_rets_series)-long_predict):
            X=pd.concat([X, pd.DataFrame(daily_log_rets[i:i+long_predict]).T],ignore_index=True)#n values of log return to predict trends
            Y=pd.concat([Y, pd.DataFrame(daily_label[i+long_predict:i+long_predict+1]).T],ignore_index=True)#labels of trends
        X=np.array(X)
        Y=np.array(Y[0])
        X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2,random_state=0)
        svc_rbf = SVC(kernel='rbf',decision_function_shape='ovo')
        f1=np.append(f1,cross_val_score(svc_rbf , X_train, Y_train, scoring='f1_micro',cv=2).mean())
    return f1

# %%
orignal_svm=svmf1(GSPC_test)
denoised_svm=svmf1(pure_mm_cnn)
# Out:
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(

# %%
plt.figure(figsize=(20,6))
plt.plot(np.arange(0,1500,5),orignal_svm,label='orignal_svm', color='red', linewidth=2.0)
plt.plot(np.arange(0,1500,5),denoised_svm,label='denoised_svm', color='blue', linewidth=4.0, linestyle='--')
plt.xticks(np.arange(0,1501,100))
plt.xlabel('threshold*100000')
plt.ylabel('f1_value')
plt.legend()

# %% [markdown]
# ## LSTM

# %%
orignal_svm=svmf1(GSPC_test)
denoised_svm=svmf1(pure_mm_lstm)
# Out:
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
# ...
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 2 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)

# %%
plt.figure(figsize=(20,6))
plt.plot(pure_mm_lstm,'r-',label='pure_mm_lstm')
plt.plot(pure_mm_cnn,label='pure_mm_cnn')
plt.plot(GSPC_test,'b-',label='GSPC_test')
plt.legend()

# %%
plt.figure(figsize=(20,6))
plt.plot(np.arange(0,1500,5),orignal_svm,label='orignal_svm', color='red', linewidth=2.0)
plt.plot(np.arange(0,1500,5),denoised_svm,label='denoised_svm', color='blue', linewidth=4.0, linestyle='--')
plt.xticks(np.arange(0,1501,100))
plt.xlabel('threshold*10000')
plt.ylabel('f1_value')
plt.legend()

# %%
def svmf1_real(dataset1, dataset2,long_predict=10):
    daily_log_rets1 = np.diff(np.log(dataset1).T)
    daily_log_rets1=daily_log_rets1.reshape(len(dataset1)-1)
    daily_rets_series1 = pd.DataFrame(daily_log_rets1)#calculate the log return
    daily_log_rets2 = np.diff(np.log(dataset2).T)
    daily_log_rets2=daily_log_rets2.reshape(len(dataset2)-1)
    daily_rets_series2 = pd.DataFrame(daily_log_rets2)#calculate the log return
    
    f11=np.empty(0)
    f12=np.empty(0)
    
    for n in range(0,1500,5):#get multiple threshold
        threshold = n/100000
        daily_label=np.empty(0)#make the data labelled
        for i in range(0,len(daily_rets_series1)):
            if daily_rets_series1.iloc[i,0]<-threshold:
                n=-1
                daily_label=np.append(daily_label,n)
            elif abs(daily_rets_series1.iloc[i,0])<=threshold:
                n=0
                daily_label=np.append(daily_label,n)
            else:
                n=1
                daily_label=np.append(daily_label,n)
        
        X1=pd.DataFrame()
        X2=pd.DataFrame()
        Y=pd.DataFrame()
        for i in range(len(daily_rets_series1)-long_predict):
            X1=pd.concat([X1, pd.DataFrame(daily_log_rets1[i:i+long_predict]).T],ignore_index=True)#n values of log return to predict trends
            X2=pd.concat([X2, pd.DataFrame(daily_log_rets2[i:i+long_predict]).T],ignore_index=True)#n values of log return to predict trends
            Y=pd.concat([Y, pd.DataFrame(daily_label[i+long_predict:i+long_predict+1]).T],ignore_index=True)#labels of trends
        X1=np.array(X1)
        X2=np.array(X2)
        Y=np.array(Y[0])
        
        X_train1, X_test1, Y_train1, Y_test1 = train_test_split(X1, Y, test_size=0.2,random_state=0)
        svc_rbf1 = SVC(kernel='rbf',decision_function_shape='ovo')
        f11=np.append(f11,cross_val_score(svc_rbf1 , X_train1, Y_train1, scoring='f1_micro',cv=2).mean())
        
        X_train2, X_test2, Y_train2, Y_test2 = train_test_split(X2, Y, test_size=0.2,random_state=0)
        svc_rbf2 = SVC(kernel='rbf',decision_function_shape='ovo')
        f12=np.append(f12,cross_val_score(svc_rbf2 , X_train2, Y_train2, scoring='f1_micro',cv=2).mean())
    return f11,f12

# %%
orignal_svm_lstm,denoised_svm_lstm=svmf1_real(GSPC_test,pure_mm_lstm,5)
plt.figure(figsize=(20,6))
plt.plot(np.arange(0,1500,5),orignal_svm_lstm,label='orignal_svm_lstm', color='red', linewidth=2.0)
plt.plot(np.arange(0,1500,5),denoised_svm_lstm,label='denoised_svm_lstm', color='blue', linewidth=4.0, linestyle='--')
plt.xticks(np.arange(0,1501,100))
plt.xlabel('threshold*10000')
plt.ylabel('f1_value')
plt.legend()

# %%
orignal_svm_cnn,denoised_svm_cnn=svmf1_real(GSPC_test,pure_mm_cnn,5)
plt.figure(figsize=(20,6))
plt.plot(np.arange(0,1500,5),orignal_svm_cnn,label='orignal_svm_cnn', color='red', linewidth=2.0)
plt.plot(np.arange(0,1500,5),denoised_svm_cnn,label='denoised_svm_cnn', color='blue', linewidth=4.0, linestyle='--')
plt.xticks(np.arange(0,1501,100))
plt.xlabel('threshold*10000')
plt.ylabel('f1_value')
plt.legend()
