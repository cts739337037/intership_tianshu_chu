# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"   
import cv2
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler, Normalizer
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, UpSampling1D, Dropout, BatchNormalization, Input, Layer, Dense,LSTM
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers.schedules import LearningRateSchedule
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.metrics import Mean, SparseCategoricalAccuracy
from pandas_datareader import data
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC#Download data from the web via this package


from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
GSPC = pd.read_csv('GSPC_index_close_test123.csv')
del GSPC['Date']
GSPC=GSPC.T
GSPC_noisy = pd.DataFrame(np.repeat(GSPC.values,100,axis=0))
GSPC_noisy=GSPC_noisy.iloc[:, 52:]

# %%
GSPC_noisy
# Out:
#             52          53           54           55          56   \
# 0   2373.469971  2344.02002  2348.449951  2345.959961  2343.97998
# 1   2373.469971  2344.02002  2348.449951  2345.959961  2343.97998
# 2   2373.469971  2344.02002  2348.449951  2345.959961  2343.97998
# 3   2373.469971  2344.02002  2348.449951  2345.959961  2343.97998
# 4   2373.469971  2344.02002  2348.449951  2345.959961  2343.97998
# ..          ...         ...          ...          ...         ...
# 95  2373.469971  2344.02002  2348.449951  2345.959961  2343.97998
# 96  2373.469971  2344.02002  2348.449951  2345.959961  2343.97998
# 97  2373.469971  2344.02002  2348.449951  2345.959961  2343.97998
# 98  2373.469971  2344.02002  2348.449951  2345.959961  2343.97998
# 99  2373.469971  2344.02002  2348.449951  2345.959961  2343.97998
#
#             57           58           59           60           61   ...  \
# 0   2341.590088  2358.570068  2361.129883  2368.060059  2362.719971  ...
# 1   2341.590088  2358.570068  2361.129883  2368.060059  2362.719971  ...
# 2   2341.590088  2358.570068  2361.129883  2368.060059  2362.719971  ...
# 3   2341.590088  2358.570068  2361.129883  2368.060059  2362.719971  ...
# 4   2341.590088  2358.570068  2361.129883  2368.060059  2362.719971  ...
# ..          ...          ...          ...          ...          ...  ...
# 95  2341.590088  2358.570068  2361.129883  2368.060059  2362.719971  ...
# 96  2341.590088  2358.570068  2361.129883  2368.060059  2362.719971  ...
# 97  2341.590088  2358.570068  2361.129883  2368.060059  2362.719971  ...
# 98  2341.590088  2358.570068  2361.129883  2368.060059  2362.719971  ...
# 99  2341.590088  2358.570068  2361.129883  2368.060059  2362.719971  ...
#
#             492          493          494          495          496  \
# 0   2545.939941  2546.159912  2506.959961  2467.419922  2416.620117
# 1   2545.939941  2546.159912  2506.959961  2467.419922  2416.620117
# 2   2545.939941  2546.159912  2506.959961  2467.419922  2416.620117
# 3   2545.939941  2546.159912  2506.959961  2467.419922  2416.620117
# 4   2545.939941  2546.159912  2506.959961  2467.419922  2416.620117
# ..          ...          ...          ...          ...          ...
# 95  2545.939941  2546.159912  2506.959961  2467.419922  2416.620117
# 96  2545.939941  2546.159912  2506.959961  2467.419922  2416.620117
# 97  2545.939941  2546.159912  2506.959961  2467.419922  2416.620117
# 98  2545.939941  2546.159912  2506.959961  2467.419922  2416.620117
# 99  2545.939941  2546.159912  2506.959961  2467.419922  2416.620117
#
#             497          498          499         500          501
# 0   2351.100098  2467.699951  2488.830078  2485.73999  2506.850098
# 1   2351.100098  2467.699951  2488.830078  2485.73999  2506.850098
# 2   2351.100098  2467.699951  2488.830078  2485.73999  2506.850098
# 3   2351.100098  2467.699951  2488.830078  2485.73999  2506.850098
# 4   2351.100098  2467.699951  2488.830078  2485.73999  2506.850098
# ..          ...          ...          ...         ...          ...
# 95  2351.100098  2467.699951  2488.830078  2485.73999  2506.850098
# 96  2351.100098  2467.699951  2488.830078  2485.73999  2506.850098
# 97  2351.100098  2467.699951  2488.830078  2485.73999  2506.850098
# 98  2351.100098  2467.699951  2488.830078  2485.73999  2506.850098
# 99  2351.100098  2467.699951  2488.830078  2485.73999  2506.850098
#
# [100 rows x 450 columns]

# %%
plt.plot(GSPC_noisy.iloc[0],label='Close price')
plt.title('Orignal close data')
plt.legend()

# %%
close=np.array(GSPC)[0]
GSPC_pure=pd.DataFrame()
for i in range(2,52):#SMA
    #print(i)
    n=np.ones(i)
    weights_sma=n/i
    empty=np.ones(i-1)
    sma=np.convolve(weights_sma, close, mode='valid')
    sma_full=np.hstack((empty,sma))
    GSPC_pure=pd.concat([GSPC_pure, pd.DataFrame(sma_full).T],ignore_index=True)
    weights_ema=np.exp(np.linspace(0,1,i))
    weights_ema =weights_ema/np.sum(weights_ema)
    ema=np.convolve(weights_ema, close, mode='valid')
    ema_full=np.hstack((empty,sma))
    GSPC_pure=pd.concat([GSPC_pure, pd.DataFrame(ema_full).T],ignore_index=True)
GSPC_pure=GSPC_pure.iloc[:, 52:]

# %%
GSPC_pure
# Out:
#             52           53           54           55           56   \
# 0   2375.859985  2358.744995  2346.234985  2347.204956  2344.969971
# 1   2375.859985  2358.744995  2346.234985  2347.204956  2344.969971
# 2   2377.699951  2365.246663  2355.313314  2346.143311  2346.129964
# 3   2377.699951  2365.246663  2355.313314  2346.143311  2346.129964
# 4   2379.589966  2369.279968  2361.047485  2352.974976  2345.602478
# ..          ...          ...          ...          ...          ...
# 95  2325.683464  2327.216528  2328.839998  2330.281629  2331.782446
# 96  2324.709395  2326.050195  2327.641196  2329.182397  2330.555596
# 97  2324.709395  2326.050195  2327.641196  2329.182397  2330.555596
# 98  2323.617053  2325.088034  2326.489406  2328.000388  2329.472546
# 99  2323.617053  2325.088034  2326.489406  2328.000388  2329.472546
#
#             57           58           59           60           61   ...  \
# 0   2342.785034  2350.080078  2359.849976  2364.594971  2365.390015  ...
# 1   2342.785034  2350.080078  2359.849976  2364.594971  2365.390015  ...
# 2   2343.843343  2348.046712  2353.763346  2362.586670  2363.969971  ...
# 3   2343.843343  2348.046712  2353.763346  2362.586670  2363.969971  ...
# 4   2344.994995  2347.525024  2351.317505  2357.337524  2362.619995  ...
# ..          ...          ...          ...          ...          ...  ...
# 95  2333.148776  2334.999392  2336.820616  2338.950619  2340.816127  ...
# 96  2331.978599  2333.657202  2335.522002  2337.445405  2339.426006  ...
# 97  2331.978599  2333.657202  2335.522002  2337.445405  2339.426006  ...
# 98  2330.771958  2332.500000  2334.195882  2336.160003  2337.940985  ...
# 99  2330.771958  2332.500000  2334.195882  2336.160003  2337.940985  ...
#
#             492          493          494          495          496  \
# 0   2572.944946  2546.049927  2526.559937  2487.189941  2442.020020
# 1   2572.944946  2546.049927  2526.559937  2487.189941  2442.020020
# 2   2598.809977  2564.016602  2533.019938  2506.846598  2463.666667
# 3   2598.809977  2564.016602  2533.019938  2506.846598  2463.666667
# 4   2611.875000  2585.647461  2549.752441  2516.619934  2484.289978
# ..          ...          ...          ...          ...          ...
# 95  2719.067343  2712.163873  2704.543871  2698.048768  2691.686523
# 96  2722.397397  2715.609194  2708.059795  2699.801392  2692.420195
# 97  2722.397397  2715.609194  2708.059795  2699.801392  2692.420195
# 98  2725.911372  2718.941760  2711.518033  2703.341366  2694.248818
# 99  2725.911372  2718.941760  2711.518033  2703.341366  2694.248818
#
#             497          498          499          500          501
# 0   2383.860107  2409.400024  2478.265015  2487.285034  2496.295044
# 1   2383.860107  2409.400024  2478.265015  2487.285034  2496.295044
# 2   2411.713379  2411.806722  2435.876709  2480.756673  2493.806722
# 3   2411.713379  2411.806722  2435.876709  2480.756673  2493.806722
# 4   2435.525024  2425.710022  2431.062561  2448.342529  2487.280029
# ..          ...          ...          ...          ...          ...
# 95  2683.196120  2677.418771  2670.865917  2664.264489  2658.918980
# 96  2684.874795  2678.886196  2673.646997  2667.163398  2661.116201
# 97  2684.874795  2678.886196  2673.646997  2667.163398  2661.116201
# 98  2685.727644  2680.616465  2675.159606  2669.962546  2664.020000
# 99  2685.727644  2680.616465  2675.159606  2669.962546  2664.020000
#
# [100 rows x 450 columns]

# %% [markdown]
# ## MinMaxScaler

# %%
mm = MinMaxScaler()
noise_mm = mm.fit_transform(GSPC_noisy.T).T
prue_mm=mm.transform(GSPC_pure.T).T

# %%
train_cleaned_mm=np.reshape(prue_mm, (100, 450, 1))
train_mm=np.reshape(noise_mm, (100, 450, 1))

# %%
# convert list to numpy array
X_train_mm = np.asarray(train_mm)
Y_train_mm = np.asarray(train_cleaned_mm)
X_train_mm, X_val_mm, Y_train_mm, Y_val_mm = train_test_split(X_train_mm, Y_train_mm, test_size=0.2,random_state=0)

# %% [markdown]
# ## LSTM

# %%
def set_model_LSTM():
    model = Sequential()
    model.add(LSTM(128, input_shape=(450, 1),activation='tanh', return_sequences = True))
    model.add(LSTM(64, activation='tanh',return_sequences = True))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(2, padding='same'))
    model.add(Dropout(0.2))
    model.add(LSTM(64, activation='tanh',return_sequences = True))
    model.add(LSTM(128, activation='tanh',return_sequences = True))
    model.add(BatchNormalization())
    model.add(UpSampling1D(2))
    model.add(Dense(1,activation='sigmoid'))
    model.compile(optimizer='adam' , loss='mean_squared_error', metrics=['mse'])
    return model
modelen_LSTM = set_model_LSTM()
modelen_LSTM.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 450, 128)          66560
#
#  lstm_5 (LSTM)               (None, 450, 64)           49408
#
#  batch_normalization_2 (Batc  (None, 450, 64)          256
#  hNormalization)
#
#  max_pooling1d_1 (MaxPooling  (None, 225, 64)          0
#  1D)
#
#  dropout_1 (Dropout)         (None, 225, 64)           0
#
#  lstm_6 (LSTM)               (None, 225, 64)           33024
#
#  lstm_7 (LSTM)               (None, 225, 128)          98816
#
#  batch_normalization_3 (Batc  (None, 225, 128)         512
#  hNormalization)
#
#  up_sampling1d_1 (UpSampling  (None, 450, 128)         0
#  1D)
#
#  dense_1 (Dense)             (None, 450, 1)            129
#
# =================================================================
# Total params: 248,705
# Trainable params: 248,321
# Non-trainable params: 384
# _________________________________________________________________

# %%
callback = EarlyStopping(monitor='loss', patience=30)
history_LSTM = modelen_LSTM.fit(X_train_mm, Y_train_mm, validation_data = (X_val_mm, Y_val_mm), epochs=200, batch_size=8, verbose=1, callbacks=[callback])
# Out:
# Epoch 1/200
# 10/10 [==============================] - 8s 351ms/step - loss: 0.0436 - mse: 0.0436 - val_loss: 0.0668 - val_mse: 0.0668
# Epoch 2/200
# 10/10 [==============================] - 2s 245ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0633 - val_mse: 0.0633
# Epoch 3/200
# 10/10 [==============================] - 2s 247ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0614 - val_mse: 0.0614
# Epoch 4/200
# 10/10 [==============================] - 2s 242ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0604 - val_mse: 0.0604
# Epoch 5/200
# 10/10 [==============================] - 2s 242ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0592 - val_mse: 0.0592
# Epoch 6/200
# 10/10 [==============================] - 2s 239ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0577 - val_mse: 0.0577
# Epoch 7/200
# 10/10 [==============================] - 2s 239ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0557 - val_mse: 0.0557
# Epoch 8/200
# 10/10 [==============================] - 2s 239ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0546 - val_mse: 0.0546
# Epoch 9/200
# 10/10 [==============================] - 2s 242ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0524 - val_mse: 0.0524
# Epoch 10/200
# 10/10 [==============================] - 2s 239ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0504 - val_mse: 0.0504
# Epoch 11/200
# 10/10 [==============================] - 2s 239ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0486 - val_mse: 0.0486
# Epoch 12/200
# 10/10 [==============================] - 2s 239ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0466 - val_mse: 0.0466
# Epoch 13/200
# 10/10 [==============================] - 2s 238ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0447 - val_mse: 0.0447
# Epoch 14/200
# 10/10 [==============================] - 2s 239ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 15/200
# 10/10 [==============================] - 2s 240ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0410 - val_mse: 0.0410
# Epoch 16/200
# 10/10 [==============================] - 2s 238ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0392 - val_mse: 0.0392
# Epoch 17/200
# 10/10 [==============================] - 2s 238ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0365 - val_mse: 0.0365
# Epoch 18/200
# 10/10 [==============================] - 2s 241ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0350 - val_mse: 0.0350
# Epoch 19/200
# 10/10 [==============================] - 2s 251ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0343 - val_mse: 0.0343
# Epoch 20/200
# 10/10 [==============================] - 3s 256ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0325 - val_mse: 0.0325
# Epoch 21/200
# 10/10 [==============================] - 2s 243ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0321 - val_mse: 0.0321
# Epoch 22/200
# 10/10 [==============================] - 2s 250ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0289 - val_mse: 0.0289
# Epoch 23/200
# 10/10 [==============================] - 3s 262ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0281 - val_mse: 0.0281
# Epoch 24/200
# 10/10 [==============================] - 3s 266ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0263 - val_mse: 0.0263
# Epoch 25/200
# 10/10 [==============================] - 3s 261ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0249 - val_mse: 0.0249
# Epoch 26/200
# 10/10 [==============================] - 3s 271ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0241 - val_mse: 0.0241
# Epoch 27/200
# 10/10 [==============================] - 3s 275ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0229 - val_mse: 0.0229
# Epoch 28/200
# 10/10 [==============================] - 3s 258ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0215 - val_mse: 0.0215
# Epoch 29/200
# 10/10 [==============================] - 3s 261ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0212 - val_mse: 0.0212
# Epoch 30/200
# 10/10 [==============================] - 2s 251ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0205 - val_mse: 0.0205
# Epoch 31/200
# 10/10 [==============================] - 3s 270ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0195 - val_mse: 0.0195
# Epoch 32/200
# 10/10 [==============================] - 3s 279ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0215 - val_mse: 0.0215
# Epoch 33/200
# 10/10 [==============================] - 3s 253ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 34/200
# 10/10 [==============================] - 3s 271ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0200 - val_mse: 0.0200
# Epoch 35/200
# 10/10 [==============================] - 3s 345ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0184 - val_mse: 0.0184
# Epoch 36/200
# 10/10 [==============================] - 4s 355ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0192 - val_mse: 0.0192
# Epoch 37/200
# 10/10 [==============================] - 3s 289ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 38/200
# 10/10 [==============================] - 2s 246ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0169 - val_mse: 0.0169
# Epoch 39/200
# 10/10 [==============================] - 2s 243ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0169 - val_mse: 0.0169
# Epoch 40/200
# 10/10 [==============================] - 2s 242ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0185 - val_mse: 0.0185
# Epoch 41/200
# 10/10 [==============================] - 2s 240ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0194 - val_mse: 0.0194
# Epoch 42/200
# 10/10 [==============================] - 2s 240ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0169 - val_mse: 0.0169
# Epoch 43/200
# 10/10 [==============================] - 2s 241ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0141 - val_mse: 0.0141
# Epoch 44/200
# 10/10 [==============================] - 2s 239ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0149 - val_mse: 0.0149
# Epoch 45/200
# 10/10 [==============================] - 2s 239ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 46/200
# 10/10 [==============================] - 2s 238ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0133 - val_mse: 0.0133
# Epoch 47/200
# 10/10 [==============================] - 2s 239ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0147 - val_mse: 0.0147
# Epoch 48/200
# 10/10 [==============================] - 2s 239ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0154 - val_mse: 0.0154
# Epoch 49/200
# 10/10 [==============================] - 2s 238ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0135 - val_mse: 0.0135
# Epoch 50/200
# 10/10 [==============================] - 2s 240ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 51/200
# 10/10 [==============================] - 2s 238ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0112 - val_mse: 0.0112
# Epoch 52/200
# 10/10 [==============================] - 2s 238ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 53/200
# 10/10 [==============================] - 2s 237ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 54/200
# 10/10 [==============================] - 2s 238ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0123 - val_mse: 0.0123
# Epoch 55/200
# 10/10 [==============================] - 2s 239ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 56/200
# 10/10 [==============================] - 2s 238ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 57/200
# 10/10 [==============================] - 2s 241ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0086 - val_mse: 0.0086
# Epoch 58/200
# 10/10 [==============================] - 2s 237ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0094 - val_mse: 0.0094
# Epoch 59/200
# 10/10 [==============================] - 2s 238ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 60/200
# 10/10 [==============================] - 2s 237ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0081 - val_mse: 0.0081
# Epoch 61/200
# 10/10 [==============================] - 2s 238ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0081 - val_mse: 0.0081
# Epoch 62/200
# 10/10 [==============================] - 2s 237ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 63/200
# 10/10 [==============================] - 2s 238ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0078 - val_mse: 0.0078
# Epoch 64/200
# 10/10 [==============================] - 2s 236ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 65/200
# 10/10 [==============================] - 2s 237ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 66/200
# 10/10 [==============================] - 2s 236ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 67/200
# 10/10 [==============================] - 2s 236ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 68/200
# 10/10 [==============================] - 2s 235ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 69/200
# 10/10 [==============================] - 2s 234ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 70/200
# 10/10 [==============================] - 2s 235ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 71/200
# 10/10 [==============================] - 2s 235ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 72/200
# 10/10 [==============================] - 2s 234ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 73/200
# 10/10 [==============================] - 2s 236ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 74/200
# 10/10 [==============================] - 2s 233ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 75/200
# 10/10 [==============================] - 2s 234ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 76/200
# 10/10 [==============================] - 2s 234ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 77/200
# 10/10 [==============================] - 2s 234ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 78/200
# 10/10 [==============================] - 2s 233ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 79/200
# 10/10 [==============================] - 2s 233ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 80/200
# 10/10 [==============================] - 2s 233ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 81/200
# 10/10 [==============================] - 2s 233ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 82/200
# 10/10 [==============================] - 2s 233ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 83/200
# 10/10 [==============================] - 2s 233ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 84/200
# 10/10 [==============================] - 2s 233ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 85/200
# 10/10 [==============================] - 2s 232ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 86/200
# 10/10 [==============================] - 2s 233ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 87/200
# 10/10 [==============================] - 2s 233ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 88/200
# 10/10 [==============================] - 2s 231ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 89/200
# 10/10 [==============================] - 2s 232ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 90/200
# 10/10 [==============================] - 2s 232ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 91/200
# 10/10 [==============================] - 2s 231ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 92/200
# 10/10 [==============================] - 2s 232ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 93/200
# 10/10 [==============================] - 2s 231ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 94/200
# 10/10 [==============================] - 2s 234ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 95/200
# 10/10 [==============================] - 2s 231ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 96/200
# 10/10 [==============================] - 2s 233ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 97/200
# 10/10 [==============================] - 2s 232ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 98/200
# 10/10 [==============================] - 2s 232ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 99/200
# 10/10 [==============================] - 2s 232ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 100/200
# 10/10 [==============================] - 2s 231ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 101/200
# 10/10 [==============================] - 2s 232ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 102/200
# 10/10 [==============================] - 2s 231ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 103/200
# 10/10 [==============================] - 2s 230ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 104/200
# 10/10 [==============================] - 2s 232ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 105/200
# 10/10 [==============================] - 2s 232ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 106/200
# 10/10 [==============================] - 2s 230ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 107/200
# 10/10 [==============================] - 2s 230ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 108/200
# 10/10 [==============================] - 2s 231ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 109/200
# 10/10 [==============================] - 2s 231ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 110/200
# 10/10 [==============================] - 2s 231ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 111/200
# 10/10 [==============================] - 2s 230ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 112/200
# 10/10 [==============================] - 2s 230ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 113/200
# 10/10 [==============================] - 2s 233ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 114/200
# 10/10 [==============================] - 2s 232ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 115/200
# 10/10 [==============================] - 2s 230ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 116/200
# 10/10 [==============================] - 2s 230ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 117/200
# 10/10 [==============================] - 2s 230ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 118/200
# 10/10 [==============================] - 2s 231ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 119/200
# 10/10 [==============================] - 2s 231ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 120/200
# 10/10 [==============================] - 2s 231ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 121/200
# 10/10 [==============================] - 2s 232ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 122/200
# 10/10 [==============================] - 2s 231ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 123/200
# 10/10 [==============================] - 2s 234ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 124/200
# 10/10 [==============================] - 2s 238ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 125/200
# 10/10 [==============================] - 2s 234ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 126/200
# 10/10 [==============================] - 2s 235ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 127/200
# 10/10 [==============================] - 2s 232ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 128/200
# 10/10 [==============================] - 2s 233ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 129/200
# 10/10 [==============================] - 2s 232ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 130/200
# 10/10 [==============================] - 2s 231ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 131/200
# 10/10 [==============================] - 2s 230ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 132/200
# 10/10 [==============================] - 2s 229ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 133/200
# 10/10 [==============================] - 2s 230ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 134/200
# 10/10 [==============================] - 2s 232ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 135/200
# 10/10 [==============================] - 2s 230ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 136/200
# 10/10 [==============================] - 2s 230ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 137/200
# 10/10 [==============================] - 2s 230ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 138/200
# 10/10 [==============================] - 2s 231ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 139/200
# 10/10 [==============================] - 2s 233ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 140/200
# 10/10 [==============================] - 2s 231ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 141/200
# 10/10 [==============================] - 2s 230ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 142/200
# 10/10 [==============================] - 2s 230ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 143/200
# 10/10 [==============================] - 2s 229ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 144/200
# 10/10 [==============================] - 2s 229ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 145/200
# 10/10 [==============================] - 2s 229ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 146/200
# 10/10 [==============================] - 2s 228ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 147/200
# 10/10 [==============================] - 2s 229ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 148/200
# 10/10 [==============================] - 2s 230ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 149/200
# 10/10 [==============================] - 2s 230ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 150/200
# 10/10 [==============================] - 2s 231ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 151/200
# 10/10 [==============================] - 2s 229ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 152/200
# 10/10 [==============================] - 2s 230ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 153/200
# 10/10 [==============================] - 2s 230ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 154/200
# 10/10 [==============================] - 2s 230ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 155/200
# 10/10 [==============================] - 2s 229ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 156/200
# 10/10 [==============================] - 2s 229ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 157/200
# 10/10 [==============================] - 2s 231ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 158/200
# 10/10 [==============================] - 2s 230ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 159/200
# 10/10 [==============================] - 2s 229ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0021 - val_mse: 0.0021

# %%
modelen_LSTM.save_weights('model_weights_LSTM.h5', overwrite=True)

# %%
modelen_LSTM.load_weights('model_weights_LSTM.h5')

# %%
# Check how loss & mae went down
epoch_loss = history_LSTM.history['loss']
epoch_val_loss = history_LSTM.history['val_loss']
epoch_mse = history_LSTM.history['mse']
epoch_val_mse = history_LSTM.history['val_mse']

plt.figure(figsize=(20,6))
plt.subplot(1,2,1)
plt.plot(range(0,len(epoch_loss)), epoch_loss, 'b-', linewidth=2, label='Train Loss')
plt.plot(range(0,len(epoch_val_loss)), epoch_val_loss, 'r-', linewidth=2, label='Val Loss')
plt.title('Evolution of loss on train & validation datasets over epochs')
plt.legend(loc='best')

plt.subplot(1,2,2)
plt.plot(range(0,len(epoch_mse)), epoch_mse, 'b-', linewidth=2, label='Train MSE')
plt.plot(range(0,len(epoch_val_mse)), epoch_val_mse, 'r-', linewidth=2,label='Val MSE')
plt.title('Evolution of MSE on train & validation datasets over epochs')
plt.legend(loc='best')

plt.show()

# %%
GSPC_test = pd.read_csv('GSPC_index_close_test123.csv')
Date=pd.to_datetime(GSPC_test['Date'])
del GSPC_test['Date']
#GSPC_test=GSPC_test.T
GSPC_test=GSPC_test[0:450]

# %%
mm_t = MinMaxScaler()
noise_mm_T=mm_t.fit_transform(GSPC_test)
Y_test_mm_lstm = modelen_LSTM.predict(noise_mm_T.T, batch_size=32)
Y_test_mm_lstm=Y_test_mm_lstm.reshape((450,1))
pure_mm_lstm = mm_t.inverse_transform(Y_test_mm_lstm)
plt.figure(figsize=(10,6))
plt.plot(pure_mm_lstm,'r')
plt.plot(GSPC_test)
plt.title('2017-2019 450 values')
plt.legend(['denoised', 'original'], loc='upper left')
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
def set_model_encoding_mm():
    model = Sequential()
    #encoding
    model.add(Conv1D(128, kernel_size=3, activation='tanh', padding='same',input_shape=(450, 1)))
    model.add(Conv1D(64, kernel_size=3,activation='sigmoid',padding='same'))
    model.add(BatchNormalization())
    #Use the normalization preprocessing of the data as mentioned before, so that the input x does not vary too much
    model.add(MaxPooling1D(2, padding='same'))
    model.add(Dropout(0.5))
    #decoding
    model.add(Conv1D(64, kernel_size=3, activation='sigmoid', padding='same'))
    model.add(Conv1D(128, kernel_size=3,activation='tanh',padding='same'))
    model.add(BatchNormalization())
    model.add(UpSampling1D(2))
    
    model.add(Conv1D(1,kernel_size=3,activation='sigmoid', padding='same'))
    model.compile(optimizer='adam' , loss='mean_squared_error', metrics=['mse'])
    
    return model
modelen_mm = set_model_encoding_mm()
modelen_mm.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_35 (Conv1D)          (None, 450, 128)          512
#
#  conv1d_36 (Conv1D)          (None, 450, 64)           24640
#
#  batch_normalization_18 (Bat  (None, 450, 64)          256
#  chNormalization)
#
#  max_pooling1d_9 (MaxPooling  (None, 225, 64)          0
#  1D)
#
#  dropout_9 (Dropout)         (None, 225, 64)           0
#
#  conv1d_37 (Conv1D)          (None, 225, 64)           12352
#
#  conv1d_38 (Conv1D)          (None, 225, 128)          24704
#
#  batch_normalization_19 (Bat  (None, 225, 128)         512
#  chNormalization)
#
#  up_sampling1d_9 (UpSampling  (None, 450, 128)         0
#  1D)
#
#  conv1d_39 (Conv1D)          (None, 450, 1)            385
#
# =================================================================
# Total params: 63,361
# Trainable params: 62,977
# Non-trainable params: 384
# _________________________________________________________________

# %%
callback = EarlyStopping(monitor='loss', patience=30)
history_mm = modelen_mm.fit(X_train_mm, Y_train_mm, validation_data = (X_val_mm, Y_val_mm), epochs=500, batch_size=4, verbose=1, callbacks=[callback])
# Out:
# Epoch 1/500
# 20/20 [==============================] - 2s 17ms/step - loss: 0.0278 - mse: 0.0278 - val_loss: 0.0967 - val_mse: 0.0967
# Epoch 2/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0946 - val_mse: 0.0946
# Epoch 3/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0842 - val_mse: 0.0842
# Epoch 4/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0900 - val_mse: 0.0900
# Epoch 5/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0917 - val_mse: 0.0917
# Epoch 6/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0936 - val_mse: 0.0936
# Epoch 7/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0909 - val_mse: 0.0909
# Epoch 8/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0826 - val_mse: 0.0826
# Epoch 9/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0899 - val_mse: 0.0899
# Epoch 10/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0831 - val_mse: 0.0831
# Epoch 11/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0910 - val_mse: 0.0910
# Epoch 12/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0762 - val_mse: 0.0762
# Epoch 13/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0762 - val_mse: 0.0762
# Epoch 14/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0753 - val_mse: 0.0753
# Epoch 15/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0743 - val_mse: 0.0743
# Epoch 16/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0759 - val_mse: 0.0759
# Epoch 17/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0663 - val_mse: 0.0663
# Epoch 18/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0637 - val_mse: 0.0637
# Epoch 19/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0656 - val_mse: 0.0656
# Epoch 20/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0591 - val_mse: 0.0591
# Epoch 21/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0656 - val_mse: 0.0656
# Epoch 22/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0473 - val_mse: 0.0473
# Epoch 23/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0534 - val_mse: 0.0534
# Epoch 24/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0400 - val_mse: 0.0400
# Epoch 25/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0503 - val_mse: 0.0503
# Epoch 26/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0377 - val_mse: 0.0377
# Epoch 27/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0346 - val_mse: 0.0346
# Epoch 28/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0350 - val_mse: 0.0350
# Epoch 29/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0327 - val_mse: 0.0327
# Epoch 30/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0281 - val_mse: 0.0281
# Epoch 31/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0377 - val_mse: 0.0377
# Epoch 32/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0248 - val_mse: 0.0248
# Epoch 33/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0173 - val_mse: 0.0173
# Epoch 34/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0145 - val_mse: 0.0145
# Epoch 35/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 36/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 37/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 38/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 39/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 40/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 41/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 42/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 43/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0290 - val_mse: 0.0290
# Epoch 44/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 45/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 46/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0247 - val_mse: 0.0247
# Epoch 47/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0085 - val_mse: 0.0085
# Epoch 48/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 49/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 50/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 51/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 52/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 53/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0160 - val_mse: 0.0160
# Epoch 54/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0149 - val_mse: 0.0149
# Epoch 55/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 56/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 57/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 58/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 59/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 60/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 61/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 62/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 63/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 64/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 65/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 66/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 67/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0508 - val_mse: 0.0508
# Epoch 68/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 69/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 70/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 71/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 72/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 73/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 74/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0103 - val_mse: 0.0103
# Epoch 75/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 76/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 77/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 78/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0086 - val_mse: 0.0086
# Epoch 79/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 80/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 81/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 82/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0094 - val_mse: 0.0094
# Epoch 83/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0088 - val_mse: 0.0088
# Epoch 84/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 85/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 86/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 87/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0068 - val_mse: 0.0068
# Epoch 88/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 89/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 90/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 91/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0088 - val_mse: 0.0088
# Epoch 92/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0392 - val_mse: 0.0392
# Epoch 93/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0086 - val_mse: 0.0086
# Epoch 94/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 95/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0223 - val_mse: 0.0223
# Epoch 96/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0221 - val_mse: 0.0221
# Epoch 97/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 98/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0160 - val_mse: 0.0160
# Epoch 99/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 100/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 101/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 102/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 103/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 104/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 105/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0121 - val_mse: 0.0121
# Epoch 106/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0089 - val_mse: 0.0089
# Epoch 107/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 108/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0139 - val_mse: 0.0139
# Epoch 109/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0109 - val_mse: 0.0109
# Epoch 110/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 111/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 112/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 113/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0223 - val_mse: 0.0223
# Epoch 114/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0267 - val_mse: 0.0267
# Epoch 115/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 116/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 117/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 118/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 119/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 120/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 121/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 122/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 123/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 124/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 125/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 126/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 127/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 128/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 129/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 130/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0082 - val_mse: 0.0082
# Epoch 131/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0075 - val_mse: 0.0075
# Epoch 132/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0085 - val_mse: 0.0085
# Epoch 133/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 134/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 135/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 136/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 137/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 138/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 139/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 140/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 141/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 142/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 143/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 144/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 145/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 146/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 147/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 148/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 149/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 150/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 151/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0090 - val_mse: 0.0090
# Epoch 152/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 153/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0087 - val_mse: 0.0087
# Epoch 154/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 155/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 156/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 157/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 158/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 159/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 160/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 161/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 162/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 163/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0116 - val_mse: 0.0116
# Epoch 164/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 165/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 166/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 167/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 168/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 169/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 170/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 171/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 172/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0048 - val_mse: 0.0048
# Epoch 173/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 174/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 175/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 176/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0146 - val_mse: 0.0146
# Epoch 177/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 178/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0060 - val_mse: 0.0060
# Epoch 179/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 180/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 181/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 182/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 183/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 184/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0077 - val_mse: 0.0077
# Epoch 185/500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 186/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 187/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 188/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 189/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 190/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 191/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 192/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 193/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 194/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 195/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 196/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 197/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0088 - val_mse: 0.0088
# Epoch 198/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 199/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 200/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 201/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 202/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 203/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 204/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 205/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 206/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 207/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0089 - val_mse: 0.0089
# Epoch 208/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 209/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 210/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 211/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 212/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 213/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 214/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 215/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 216/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 217/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 218/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 219/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0067 - val_mse: 0.0067
# Epoch 220/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 221/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 222/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0131 - val_mse: 0.0131
# Epoch 223/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 224/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 225/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 226/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0032 - val_mse: 0.0032
# Epoch 227/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0140 - val_mse: 0.0140
# Epoch 228/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0057 - val_mse: 0.0057
# Epoch 229/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 230/500
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 231/500
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 232/500
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 233/500
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 234/500
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 235/500
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 236/500
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 237/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0071 - val_mse: 0.0071
# Epoch 238/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 239/500
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 240/500
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 241/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 242/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 243/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 244/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0074 - val_mse: 0.0074
# Epoch 245/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 246/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0064 - val_mse: 0.0064
# Epoch 247/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 248/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 249/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 250/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 251/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 252/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 253/500
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 254/500
# 20/20 [==============================] - 0s 13ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 255/500
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 256/500
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 257/500
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 258/500
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 259/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 260/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 261/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0123 - val_mse: 0.0123
# Epoch 262/500
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 263/500
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 264/500
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 265/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 266/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 267/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 268/500
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 269/500
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0044 - val_mse: 0.0044
# Epoch 270/500
# 20/20 [==============================] - 0s 11ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 271/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0082 - val_mse: 0.0082
# Epoch 272/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 273/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 274/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 275/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 276/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 277/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 278/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 279/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 280/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 281/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 282/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 283/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 284/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 285/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 286/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 287/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 288/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 289/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 290/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 291/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 292/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 293/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 294/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 295/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 296/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 297/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 298/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 299/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 300/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 301/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 302/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 303/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 304/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 305/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 306/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 307/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 308/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 309/500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0039 - val_mse: 0.0039

# %%
modelen_mm.save_weights('model_weights_mm.h5', overwrite=True)

# %%
# Check how loss & mae went down
epoch_loss = history_mm.history['loss']
epoch_val_loss = history_mm.history['val_loss']
epoch_mse = history_mm.history['mse']
epoch_val_mse = history_mm.history['val_mse']

plt.figure(figsize=(20,6))
plt.subplot(1,2,1)
plt.plot(range(0,len(epoch_loss)), epoch_loss, 'b-', linewidth=2, label='Train Loss')
plt.plot(range(0,len(epoch_val_loss)), epoch_val_loss, 'r-', linewidth=2, label='Val Loss')
plt.title('Evolution of loss on train & validation datasets over epochs')
plt.legend(loc='best')

plt.subplot(1,2,2)
plt.plot(range(0,len(epoch_mse)), epoch_mse, 'b-', linewidth=2, label='Train MSE')
plt.plot(range(0,len(epoch_val_mse)), epoch_val_mse, 'r-', linewidth=2,label='Val MSE')
plt.title('Evolution of MSE on train & validation datasets over epochs')
plt.legend(loc='best')

plt.show()

# %%
modelen_mm.load_weights('model_weights_mm.h5')

# %%
GSPC_test = pd.read_csv('GSPC_index_close_test123.csv')
Date=pd.to_datetime(GSPC_test['Date'])
del GSPC_test['Date']
#GSPC_test=GSPC_test.T
GSPC_test=GSPC_test[0:450]

# %%
mm_t = MinMaxScaler()
noise_mm_T=mm_t.fit_transform(GSPC_test)
Y_test_mm_cnn = modelen_mm.predict(noise_mm_T.T, batch_size=8)
Y_test_mm_cnn=Y_test_mm_cnn.reshape((450,1))
pure_mm_cnn = mm_t.inverse_transform(Y_test_mm_cnn)
plt.figure(figsize=(10,6))
plt.plot(pure_mm_cnn,'r')
plt.plot(GSPC_test)
plt.title('2017-2019 450 values')
plt.legend(['denoised', 'original'], loc='upper left')
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000020EA3C71A60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 112ms/step

# %%
def log_return(dataset):
    daily_log_rets = np.diff(np.log(dataset).T)
    daily_log_rets=daily_log_rets.reshape(len(dataset)-1)
    daily_rets_series = pd.DataFrame(daily_log_rets)#calculate the log return
    return daily_rets_series

# %%
o=log_return(GSPC_test)
d_cnn=log_return(pure_mm_cnn)
d_lstm=log_return(pure_mm_lstm)

plt.figure(figsize=(20,6))
plt.subplot(1,3,1)
plt.plot(o, 'r-', linewidth=2, label='Original log return')
plt.ylim(-0.2,0.2)
plt.title('log return of original data')
plt.legend(loc='best')

plt.subplot(1,3,2)
plt.plot(d_cnn, 'b-', linewidth=2, label='Denoised log return')
plt.ylim(-0.2,0.2)
plt.title('log return of denoised data(CNN)')
plt.legend(loc='best')

plt.subplot(1,3,3)
plt.plot(d_lstm, 'y-', linewidth=2, label='Denoised log return')
plt.ylim(-0.2,0.2)
plt.title('log return of denoised data(LSTM)')
plt.legend(loc='best')

plt.show()

# %%
def svmf1(dataset,long_predict=10):
    daily_log_rets = np.diff(np.log(dataset).T)
    daily_log_rets=daily_log_rets.reshape(len(dataset)-1)
    daily_rets_series = pd.DataFrame(daily_log_rets)#calculate the log return
    f1=np.empty(0)
    for n in range(0,1500,5):#get multiple threshold
        threshold = n/100000
        daily_label=np.empty(0)#make the data labelled
        for i in range(0,len(daily_rets_series)):
            if daily_rets_series.iloc[i,0]<-threshold:
                n=-1
                daily_label=np.append(daily_label,n)
            elif abs(daily_rets_series.iloc[i,0])<=threshold:
                n=0
                daily_label=np.append(daily_label,n)
            else:
                n=1
                daily_label=np.append(daily_label,n)
        X=pd.DataFrame()
        Y=pd.DataFrame()
        for i in range(len(daily_rets_series)-long_predict):
            X=pd.concat([X, pd.DataFrame(daily_log_rets[i:i+long_predict]).T],ignore_index=True)#n values of log return to predict trends
            Y=pd.concat([Y, pd.DataFrame(daily_label[i+long_predict:i+long_predict+1]).T],ignore_index=True)#labels of trends
        X=np.array(X)
        Y=np.array(Y[0])
        X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2,random_state=0)
        svc_rbf = SVC(kernel='rbf',decision_function_shape='ovo')
        f1=np.append(f1,cross_val_score(svc_rbf , X_train, Y_train, scoring='f1_micro',cv=5).mean())
    return f1

# %%
orignal_svm=svmf1(GSPC_test)
denoised_svm=svmf1(pure_mm_cnn)
# Out:
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
# ...
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)

# %%
plt.figure(figsize=(20,6))
plt.plot(np.arange(0,1500,5),orignal_svm,label='orignal_svm', color='red', linewidth=2.0)
plt.plot(np.arange(0,1500,5),denoised_svm,label='denoised_svm', color='blue', linewidth=4.0, linestyle='--')
plt.xticks(np.arange(0,1501,100))
plt.xlabel('threshold*100000')
plt.ylabel('f1_value')
plt.legend()

# %% [markdown]
# ## LSTM

# %%
orignal_svm=svmf1(GSPC_test)
denoised_svm=svmf1(pure_mm_lstm)
# Out:
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# ...
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)

# %%
plt.figure(figsize=(20,6))
plt.plot(pure_mm_lstm,'r-',label='pure_mm_lstm')
plt.plot(pure_mm_cnn,label='pure_mm_cnn')
plt.plot(GSPC_test,'b-',label='GSPC_test')
plt.legend()

# %%
plt.figure(figsize=(20,6))
plt.plot(np.arange(0,1500,5),orignal_svm,label='orignal_svm', color='red', linewidth=2.0)
plt.plot(np.arange(0,1500,5),denoised_svm,label='denoised_svm', color='blue', linewidth=4.0, linestyle='--')
plt.xticks(np.arange(0,1501,100))
plt.xlabel('threshold*10000')
plt.ylabel('f1_value')
plt.legend()

# %%
def svmf1_real(dataset1, dataset2,long_predict=10):
    daily_log_rets1 = np.diff(np.log(dataset1).T)
    daily_log_rets1=daily_log_rets1.reshape(len(dataset1)-1)
    daily_rets_series1 = pd.DataFrame(daily_log_rets1)#calculate the log return
    daily_log_rets2 = np.diff(np.log(dataset2).T)
    daily_log_rets2=daily_log_rets2.reshape(len(dataset2)-1)
    daily_rets_series2 = pd.DataFrame(daily_log_rets2)#calculate the log return
    
    f11=np.empty(0)
    f12=np.empty(0)
    
    for n in range(0,1500,5):#get multiple threshold
        threshold = n/100000
        daily_label=np.empty(0)#make the data labelled
        for i in range(0,len(daily_rets_series1)):
            if daily_rets_series1.iloc[i,0]<-threshold:
                n=-1
                daily_label=np.append(daily_label,n)
            elif abs(daily_rets_series1.iloc[i,0])<=threshold:
                n=0
                daily_label=np.append(daily_label,n)
            else:
                n=1
                daily_label=np.append(daily_label,n)
        
        X1=pd.DataFrame()
        X2=pd.DataFrame()
        Y=pd.DataFrame()
        for i in range(len(daily_rets_series1)-long_predict):
            X1=pd.concat([X1, pd.DataFrame(daily_log_rets1[i:i+long_predict]).T],ignore_index=True)#n values of log return to predict trends
            X2=pd.concat([X2, pd.DataFrame(daily_log_rets2[i:i+long_predict]).T],ignore_index=True)#n values of log return to predict trends
            Y=pd.concat([Y, pd.DataFrame(daily_label[i+long_predict:i+long_predict+1]).T],ignore_index=True)#labels of trends
        X1=np.array(X1)
        X2=np.array(X2)
        Y=np.array(Y[0])
        
        X_train1, X_test1, Y_train1, Y_test1 = train_test_split(X1, Y, test_size=0.2,random_state=0)
        svc_rbf1 = SVC(kernel='rbf',decision_function_shape='ovo')
        f11=np.append(f11,cross_val_score(svc_rbf1 , X_train1, Y_train1, scoring='f1_micro',cv=5).mean())
        
        X_train2, X_test2, Y_train2, Y_test2 = train_test_split(X2, Y, test_size=0.2,random_state=0)
        svc_rbf2 = SVC(kernel='rbf',decision_function_shape='ovo')
        f12=np.append(f12,cross_val_score(svc_rbf2 , X_train2, Y_train2, scoring='f1_micro',cv=5).mean())
    return f11,f12

# %%
orignal_svm_lstm,denoised_svm_lstm=svmf1_real(GSPC_test,pure_mm_lstm,5)
plt.figure(figsize=(20,6))
plt.plot(np.arange(0,1500,5),orignal_svm_lstm,label='orignal_svm_lstm', color='red', linewidth=2.0)
plt.plot(np.arange(0,1500,5),denoised_svm_lstm,label='denoised_svm_lstm', color='blue', linewidth=4.0, linestyle='--')
plt.xticks(np.arange(0,1501,100))
plt.xlabel('threshold*10000')
plt.ylabel('f1_value')
plt.legend()
# Out:
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(

# %%
orignal_svm_cnn,denoised_svm_cnn=svmf1_real(GSPC_test,pure_mm_cnn,5)
plt.figure(figsize=(20,6))
plt.plot(np.arange(0,1500,5),orignal_svm_cnn,label='orignal_svm_cnn', color='red', linewidth=2.0)
plt.plot(np.arange(0,1500,5),denoised_svm_cnn,label='denoised_svm_cnn', color='blue', linewidth=4.0, linestyle='--')
plt.xticks(np.arange(0,1501,100))
plt.xlabel('threshold*10000')
plt.ylabel('f1_value')
plt.legend()
# Out:
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(

# %%
def svmf1_real_label(dataset1, dataset2,long_predict=10):
    daily_log_rets1 = np.diff(np.log(dataset1).T)
    daily_log_rets1=daily_log_rets1.reshape(len(dataset1)-1)
    daily_rets_series1 = pd.DataFrame(daily_log_rets1)#calculate the log return
    daily_log_rets2 = np.diff(np.log(dataset2).T)
    daily_log_rets2=daily_log_rets2.reshape(len(dataset2)-1)
    daily_rets_series2 = pd.DataFrame(daily_log_rets2)#calculate the log return
    
    f11=np.empty(0)
    f12=np.empty(0)
    
    for n in np.arange(0.0, 0.04, 0.0005):#get multiple threshold
        threshold = n
        daily_label=np.empty(0)#make the data labelled
        for i in range(0,len(daily_rets_series1)):
            if daily_rets_series1.iloc[i,0]<-threshold:
                n=-1
                daily_label=np.append(daily_label,n)
            elif abs(daily_rets_series1.iloc[i,0])<=threshold:
                n=0
                daily_label=np.append(daily_label,n)
            else:
                n=1
                daily_label=np.append(daily_label,n)
        
        daily_label2=np.empty(0)#make the data labelled
        for i in range(0,len(daily_rets_series2)):
            if daily_rets_series2.iloc[i,0]<-threshold:
                n=-1
                daily_label2=np.append(daily_label2,n)
            elif abs(daily_rets_series2.iloc[i,0])<=threshold:
                n=0
                daily_label2=np.append(daily_label2,n)
            else:
                n=1
                daily_label2=np.append(daily_label2,n)
        
        X1=pd.DataFrame()
        X2=pd.DataFrame()
        Y=pd.DataFrame()
        for i in range(len(daily_rets_series1)-long_predict):
            X1=pd.concat([X1, pd.DataFrame(daily_label[i:i+long_predict]).T],ignore_index=True)#n values of log return to predict trends
            X2=pd.concat([X2, pd.DataFrame(daily_label2[i:i+long_predict]).T],ignore_index=True)#n values of log return to predict trends
            Y=pd.concat([Y, pd.DataFrame(daily_label[i+long_predict:i+long_predict+1]).T],ignore_index=True)#labels of trends
        X1=np.array(X1)
        X2=np.array(X2)
        Y=np.array(Y[0])
        
        X_train1, X_test1, Y_train1, Y_test1 = train_test_split(X1, Y, test_size=0.2,random_state=0)
        svc_rbf1 = SVC(kernel='rbf',decision_function_shape='ovo')
        f11=np.append(f11,cross_val_score(svc_rbf1 , X1, Y, scoring='f1_micro',cv=2).mean())
        
        X_train2, X_test2, Y_train2, Y_test2 = train_test_split(X2, Y, test_size=0.2,random_state=0)
        svc_rbf2 = SVC(kernel='rbf',decision_function_shape='ovo')
        f12=np.append(f12,cross_val_score(svc_rbf2 , X2, Y, scoring='f1_micro',cv=2).mean())
    return f11,f12

# %%
orignal_svm_cnn,denoised_svm_cnn=svmf1_real_label(GSPC_test,pure_mm_cnn,5)
# Out:
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=2.
#   warnings.warn(
# E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 1 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "E:\ANACONDA\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 199, in fit
#     y = self._validate_targets(y)
#   File "E:\ANACONDA\lib\site-packages\sklearn\svm\_base.py", line 720, in _validate_targets
#     raise ValueError(
# ValueError: The number of classes has to be greater than one; got 1 class
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)

# %%
plt.figure(figsize=(20,6))
plt.plot(np.arange(0.0, 0.04, 0.0005),orignal_svm_cnn,label='orignal_svm_cnn', color='red', linewidth=2.0)
plt.plot(np.arange(0.0, 0.04, 0.0005),denoised_svm_cnn,label='denoised_svm_cnn', color='blue', linewidth=4.0, linestyle='--')
plt.xticks(np.arange(0.0, 0.04, 0.005))
plt.xlabel('threshold')
plt.ylabel('f1_value')
plt.legend()
