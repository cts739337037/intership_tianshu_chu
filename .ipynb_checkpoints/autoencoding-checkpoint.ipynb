# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"   
import cv2
from keras import callbacks
from keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler, Normalizer
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv1D, MaxPooling1D, UpSampling1D, Dropout, BatchNormalization, Input
from tensorflow.keras.callbacks import EarlyStopping
from pandas_datareader import data#Download data from the web via this package
# %matplotlib inline

# %%
GSPC = pd.read_csv('GSPC_index_close_test123.csv')
del GSPC['Date']
GSPC=GSPC.T
GSPC_noisy = pd.DataFrame(np.repeat(GSPC.values,100,axis=0))
GSPC_noisy=GSPC_noisy.iloc[:, 52:]

# %%
GSPC_noisy
# Out:
#             52          53           54           55          56   \
# 0   2373.469971  2344.02002  2348.449951  2345.959961  2343.97998
# 1   2373.469971  2344.02002  2348.449951  2345.959961  2343.97998
# 2   2373.469971  2344.02002  2348.449951  2345.959961  2343.97998
# 3   2373.469971  2344.02002  2348.449951  2345.959961  2343.97998
# 4   2373.469971  2344.02002  2348.449951  2345.959961  2343.97998
# ..          ...         ...          ...          ...         ...
# 95  2373.469971  2344.02002  2348.449951  2345.959961  2343.97998
# 96  2373.469971  2344.02002  2348.449951  2345.959961  2343.97998
# 97  2373.469971  2344.02002  2348.449951  2345.959961  2343.97998
# 98  2373.469971  2344.02002  2348.449951  2345.959961  2343.97998
# 99  2373.469971  2344.02002  2348.449951  2345.959961  2343.97998
#
#             57           58           59           60           61   ...  \
# 0   2341.590088  2358.570068  2361.129883  2368.060059  2362.719971  ...
# 1   2341.590088  2358.570068  2361.129883  2368.060059  2362.719971  ...
# 2   2341.590088  2358.570068  2361.129883  2368.060059  2362.719971  ...
# 3   2341.590088  2358.570068  2361.129883  2368.060059  2362.719971  ...
# 4   2341.590088  2358.570068  2361.129883  2368.060059  2362.719971  ...
# ..          ...          ...          ...          ...          ...  ...
# 95  2341.590088  2358.570068  2361.129883  2368.060059  2362.719971  ...
# 96  2341.590088  2358.570068  2361.129883  2368.060059  2362.719971  ...
# 97  2341.590088  2358.570068  2361.129883  2368.060059  2362.719971  ...
# 98  2341.590088  2358.570068  2361.129883  2368.060059  2362.719971  ...
# 99  2341.590088  2358.570068  2361.129883  2368.060059  2362.719971  ...
#
#             492          493          494          495          496  \
# 0   2545.939941  2546.159912  2506.959961  2467.419922  2416.620117
# 1   2545.939941  2546.159912  2506.959961  2467.419922  2416.620117
# 2   2545.939941  2546.159912  2506.959961  2467.419922  2416.620117
# 3   2545.939941  2546.159912  2506.959961  2467.419922  2416.620117
# 4   2545.939941  2546.159912  2506.959961  2467.419922  2416.620117
# ..          ...          ...          ...          ...          ...
# 95  2545.939941  2546.159912  2506.959961  2467.419922  2416.620117
# 96  2545.939941  2546.159912  2506.959961  2467.419922  2416.620117
# 97  2545.939941  2546.159912  2506.959961  2467.419922  2416.620117
# 98  2545.939941  2546.159912  2506.959961  2467.419922  2416.620117
# 99  2545.939941  2546.159912  2506.959961  2467.419922  2416.620117
#
#             497          498          499         500          501
# 0   2351.100098  2467.699951  2488.830078  2485.73999  2506.850098
# 1   2351.100098  2467.699951  2488.830078  2485.73999  2506.850098
# 2   2351.100098  2467.699951  2488.830078  2485.73999  2506.850098
# 3   2351.100098  2467.699951  2488.830078  2485.73999  2506.850098
# 4   2351.100098  2467.699951  2488.830078  2485.73999  2506.850098
# ..          ...          ...          ...         ...          ...
# 95  2351.100098  2467.699951  2488.830078  2485.73999  2506.850098
# 96  2351.100098  2467.699951  2488.830078  2485.73999  2506.850098
# 97  2351.100098  2467.699951  2488.830078  2485.73999  2506.850098
# 98  2351.100098  2467.699951  2488.830078  2485.73999  2506.850098
# 99  2351.100098  2467.699951  2488.830078  2485.73999  2506.850098
#
# [100 rows x 450 columns]

# %%
plt.plot(GSPC_noisy.iloc[0])

# %%
close=np.array(GSPC)[0]
GSPC_pure=pd.DataFrame()
for i in range(2,52):#SMA
    #print(i)
    n=np.ones(i)
    weights_sma=n/i
    empty=np.ones(i-1)
    sma=np.convolve(weights_sma, close, mode='valid')
    sma_full=np.hstack((empty,sma))
    GSPC_pure=pd.concat([GSPC_pure, pd.DataFrame(sma_full).T],ignore_index=True)
    weights_ema=np.exp(np.linspace(0,1,i))
    weights_ema =weights_ema/np.sum(weights_ema)
    ema=np.convolve(weights_ema, close, mode='valid')
    ema_full=np.hstack((empty,sma))
    GSPC_pure=pd.concat([GSPC_pure, pd.DataFrame(ema_full).T],ignore_index=True)
GSPC_pure=GSPC_pure.iloc[:, 52:]

# %%
GSPC_pure
# Out:
#             52           53           54           55           56   \
# 0   2375.859985  2358.744995  2346.234985  2347.204956  2344.969971
# 1   2375.859985  2358.744995  2346.234985  2347.204956  2344.969971
# 2   2377.699951  2365.246663  2355.313314  2346.143311  2346.129964
# 3   2377.699951  2365.246663  2355.313314  2346.143311  2346.129964
# 4   2379.589966  2369.279968  2361.047485  2352.974976  2345.602478
# ..          ...          ...          ...          ...          ...
# 95  2325.683464  2327.216528  2328.839998  2330.281629  2331.782446
# 96  2324.709395  2326.050195  2327.641196  2329.182397  2330.555596
# 97  2324.709395  2326.050195  2327.641196  2329.182397  2330.555596
# 98  2323.617053  2325.088034  2326.489406  2328.000388  2329.472546
# 99  2323.617053  2325.088034  2326.489406  2328.000388  2329.472546
#
#             57           58           59           60           61   ...  \
# 0   2342.785034  2350.080078  2359.849976  2364.594971  2365.390015  ...
# 1   2342.785034  2350.080078  2359.849976  2364.594971  2365.390015  ...
# 2   2343.843343  2348.046712  2353.763346  2362.586670  2363.969971  ...
# 3   2343.843343  2348.046712  2353.763346  2362.586670  2363.969971  ...
# 4   2344.994995  2347.525024  2351.317505  2357.337524  2362.619995  ...
# ..          ...          ...          ...          ...          ...  ...
# 95  2333.148776  2334.999392  2336.820616  2338.950619  2340.816127  ...
# 96  2331.978599  2333.657202  2335.522002  2337.445405  2339.426006  ...
# 97  2331.978599  2333.657202  2335.522002  2337.445405  2339.426006  ...
# 98  2330.771958  2332.500000  2334.195882  2336.160003  2337.940985  ...
# 99  2330.771958  2332.500000  2334.195882  2336.160003  2337.940985  ...
#
#             492          493          494          495          496  \
# 0   2572.944946  2546.049927  2526.559937  2487.189941  2442.020020
# 1   2572.944946  2546.049927  2526.559937  2487.189941  2442.020020
# 2   2598.809977  2564.016602  2533.019938  2506.846598  2463.666667
# 3   2598.809977  2564.016602  2533.019938  2506.846598  2463.666667
# 4   2611.875000  2585.647461  2549.752441  2516.619934  2484.289978
# ..          ...          ...          ...          ...          ...
# 95  2719.067343  2712.163873  2704.543871  2698.048768  2691.686523
# 96  2722.397397  2715.609194  2708.059795  2699.801392  2692.420195
# 97  2722.397397  2715.609194  2708.059795  2699.801392  2692.420195
# 98  2725.911372  2718.941760  2711.518033  2703.341366  2694.248818
# 99  2725.911372  2718.941760  2711.518033  2703.341366  2694.248818
#
#             497          498          499          500          501
# 0   2383.860107  2409.400024  2478.265015  2487.285034  2496.295044
# 1   2383.860107  2409.400024  2478.265015  2487.285034  2496.295044
# 2   2411.713379  2411.806722  2435.876709  2480.756673  2493.806722
# 3   2411.713379  2411.806722  2435.876709  2480.756673  2493.806722
# 4   2435.525024  2425.710022  2431.062561  2448.342529  2487.280029
# ..          ...          ...          ...          ...          ...
# 95  2683.196120  2677.418771  2670.865917  2664.264489  2658.918980
# 96  2684.874795  2678.886196  2673.646997  2667.163398  2661.116201
# 97  2684.874795  2678.886196  2673.646997  2667.163398  2661.116201
# 98  2685.727644  2680.616465  2675.159606  2669.962546  2664.020000
# 99  2685.727644  2680.616465  2675.159606  2669.962546  2664.020000
#
# [100 rows x 450 columns]

# %% [markdown]
# ## MinMaxScaler

# %%
mm = MinMaxScaler()
noise_mm = mm.fit_transform(GSPC_noisy.T).T
prue_mm=mm.transform(GSPC_pure.T).T

# %%
train_cleaned_mm=np.reshape(prue_mm, (100, 450, 1))
train_mm=np.reshape(noise_mm, (100, 450, 1))

# %%
# convert list to numpy array
X_train_mm = np.asarray(train_mm)
Y_train_mm = np.asarray(train_cleaned_mm)
X_train_mm, X_val_mm, Y_train_mm, Y_val_mm = train_test_split(X_train_mm, Y_train_mm, test_size=0.2)

# %%
def set_model_encoding_mm():
    model = Sequential()
    #encoding
    model.add(Conv1D(128, kernel_size=3, activation='relu', padding='same',input_shape=(450, 1)))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(5, padding='same'))
    model.add(Conv1D(256, kernel_size=3,activation='relu',padding='same'))
    model.add(BatchNormalization())
    #Use the normalization preprocessing of the data as mentioned before, so that the input x does not vary too much
    model.add(MaxPooling1D(2, padding='same'))
    #model.add(Dropout(0.3))
    #decoding
    model.add(Conv1D(256, kernel_size=3, activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(UpSampling1D(5))
    model.add(Conv1D(128, kernel_size=3,activation='relu',padding='same'))
    model.add(BatchNormalization())
    model.add(UpSampling1D(2))
    
    model.add(Conv1D(1,kernel_size=3,activation='sigmoid', padding='same'))
    model.compile(optimizer='adam' , loss='mean_squared_error', metrics=['mse'])
    
    return model

# %%
modelen_mm = set_model_encoding_mm()
modelen_mm.summary()
# Out:
# Model: "sequential_45"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_225 (Conv1D)         (None, 450, 128)          512
#
#  batch_normalization_114 (Ba  (None, 450, 128)         512
#  tchNormalization)
#
#  max_pooling1d_49 (MaxPoolin  (None, 90, 128)          0
#  g1D)
#
#  conv1d_226 (Conv1D)         (None, 90, 256)           98560
#
#  batch_normalization_115 (Ba  (None, 90, 256)          1024
#  tchNormalization)
#
#  max_pooling1d_50 (MaxPoolin  (None, 45, 256)          0
#  g1D)
#
#  conv1d_227 (Conv1D)         (None, 45, 256)           196864
#
#  batch_normalization_116 (Ba  (None, 45, 256)          1024
#  tchNormalization)
#
#  up_sampling1d_49 (UpSamplin  (None, 225, 256)         0
#  g1D)
#
#  conv1d_228 (Conv1D)         (None, 225, 128)          98432
#
#  batch_normalization_117 (Ba  (None, 225, 128)         512
#  tchNormalization)
#
#  up_sampling1d_50 (UpSamplin  (None, 450, 128)         0
#  g1D)
#
#  conv1d_229 (Conv1D)         (None, 450, 1)            385
#
# =================================================================
# Total params: 397,825
# Trainable params: 396,289
# Non-trainable params: 1,536
# _________________________________________________________________

# %%
callback = EarlyStopping(monitor='loss', patience=100)
history_mm = modelen_mm.fit(X_train_mm, Y_train_mm, validation_data = (X_val_mm, Y_val_mm), epochs=500, batch_size=32, verbose=0, callbacks=[callback])

# %%
modelen_mm.save_weights('model_weights_mm.h5', overwrite=True)

# %%
# Check how loss & mae went down
epoch_loss = history_mm.history['loss']
epoch_val_loss = history_mm.history['val_loss']
epoch_mse = history_mm.history['mse']
epoch_val_mse = history_mm.history['val_mse']

plt.figure(figsize=(20,6))
plt.subplot(1,2,1)
plt.plot(range(0,len(epoch_loss)), epoch_loss, 'b-', linewidth=2, label='Train Loss')
plt.plot(range(0,len(epoch_val_loss)), epoch_val_loss, 'r-', linewidth=2, label='Val Loss')
plt.title('Evolution of loss on train & validation datasets over epochs')
plt.legend(loc='best')

plt.subplot(1,2,2)
plt.plot(range(0,len(epoch_mse)), epoch_mse, 'b-', linewidth=2, label='Train MSE')
plt.plot(range(0,len(epoch_val_mse)), epoch_val_mse, 'r-', linewidth=2,label='Val MSE')
plt.title('Evolution of MSE on train & validation datasets over epochs')
plt.legend(loc='best')

plt.show()

# %%
GSPC_test = pd.read_csv('GSPC_index_close_test123.csv')
del GSPC_test['Date']
#GSPC_test=GSPC_test.T
GSPC_test=GSPC_test[0:450]

# %%
mm_t = MinMaxScaler()
noise_mm_T=mm_t.fit_transform(GSPC_test)
noise_mm_T.shape
# Out:
# (450, 1)

# %%
Y_test_mm = modelen_mm.predict(noise_mm_T.T, batch_size=32)
# Out:
# 1/1 [==============================] - 0s 154ms/step

# %%
Y_test_mm=Y_test_mm.reshape((450,1))
pure_mm = mm_t.inverse_transform(Y_test_mm)

# %%
plt.figure(figsize=(10,6))
plt.plot(pure_mm,'r')
plt.plot(GSPC_test)
plt.legend(['denoised', 'original'], loc='upper left')

# %%
GSPC_test = pd.read_csv('GSPC_index_close_test_201922.csv')
Date=pd.to_datetime(GSPC_test['Date'])
del GSPC_test['Date']
#GSPC_test=GSPC_test.T
GSPC_test=GSPC_test[0:450]

# %%
mm_t = MinMaxScaler()
noise_mm_T=mm_t.fit_transform(GSPC_test)
Y_test_mm = modelen_mm.predict(noise_mm_T.T, batch_size=32)
Y_test_mm=Y_test_mm.reshape((450,1))
pure_mm = mm_t.inverse_transform(Y_test_mm)
plt.figure(figsize=(10,6))
plt.plot(pure_mm,'r')
plt.plot(GSPC_test)
plt.legend(['denoised', 'original'], loc='upper left')
# Out:
# 1/1 [==============================] - 0s 19ms/step

# %%
a=pd.DataFrame(pure_mm)

# %%
daily_log_rets = np.diff(np.log(a.T))

# %%
daily_log_rets
# Out:
# array([[ 1.11465454e-02,  5.47885895e-04, -6.14500046e-03,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          6.72340393e-04,  2.39477158e-02, -1.43861771e-02,
#          1.91340446e-02,  2.78711319e-03,  5.39159775e-03,
#         -2.32458115e-03,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  7.14206696e-03, -5.04827499e-03,
#          8.87966156e-03,  5.69820404e-03, -8.31174850e-03,
#         -2.12192535e-04,  1.37519836e-03,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  7.53879547e-03,
#          2.15625763e-03,  5.20086288e-03,  1.51634216e-03,
#          2.78711319e-03,  1.54495239e-04,  8.80432129e-03,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          3.32641602e-03,  1.72853470e-03, -2.40230560e-03,
#          4.63104248e-03,  2.22778320e-03,  1.31177902e-03,
#          1.71136856e-03,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  2.53868103e-03,  6.61373138e-04,
#         -3.53765488e-03,  2.70843506e-03,  1.83296204e-03,
#          6.76631927e-04,  2.68602371e-03,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  3.07226181e-03,
#         -1.54542923e-03,  4.15658951e-03,  3.55339050e-03,
#         -2.54821777e-03, -2.93827057e-03,  7.59077072e-03,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          3.63349915e-04,  6.97135925e-04, -3.51858139e-03,
#          4.08220291e-03, -6.86645508e-05,  1.59025192e-03,
#          7.94744492e-03,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -2.58922577e-03,  1.00994110e-03,
#          4.90379333e-03,  3.30591202e-03, -6.17027283e-04,
#          2.35271454e-03, -1.38616562e-03,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -3.60918045e-03,
#          1.59358978e-03,  2.76422501e-03, -1.21207237e-02,
#          1.08571053e-02,  3.17573547e-04, -8.23497772e-03,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          8.88824463e-04,  1.79433823e-03, -3.14140320e-03,
#          8.58306885e-04, -1.11770630e-03, -5.61332703e-03,
#         -5.87415695e-03,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  2.72369385e-03, -2.14242935e-03,
#         -3.95488739e-03,  4.31299210e-03,  1.49059296e-03,
#         -1.74903870e-03,  1.61833763e-02,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  2.18009949e-03,
#          3.89671326e-03,  8.21590424e-04,  7.18688965e-03,
#          2.11763382e-03, -2.36463547e-03,  2.51197815e-03,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          3.20672989e-03, -1.22547150e-04,  6.01339340e-03,
#          2.87532806e-03, -1.87158585e-03, -2.00986862e-03,
#          5.88035583e-03,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  6.07156754e-03, -2.22396851e-03,
#          6.09302521e-03,  4.04310226e-03, -5.52463531e-03,
#          1.23167038e-03,  5.14507294e-04,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -2.43186951e-03,
#          1.61600113e-03,  9.76133347e-03, -1.14254951e-02,
#          1.30653381e-03,  4.80985641e-03, -2.01988220e-03,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -8.10146332e-03,  7.61985779e-04, -1.13286972e-02,
#          2.58779526e-03,  4.34923172e-03,  1.26409531e-03,
#         -6.82926178e-03,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  2.47859955e-03, -2.84814835e-03,
#         -5.65338135e-03,  6.27422333e-03, -3.17573547e-04,
#         -4.97055054e-03,  4.25529480e-03,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  4.58860397e-03,
#          1.67369843e-03,  1.10244751e-02, -3.28493118e-03,
#         -4.10556793e-04, -6.93321228e-04,  1.56068802e-03,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -2.98643112e-03,  1.23929977e-03,  2.57539749e-03,
#         -2.61449814e-03,  4.47273254e-04,  2.30360031e-03,
#         -2.53534317e-03,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  2.09808350e-04, -3.74174118e-03,
#         -3.11994553e-03,  1.41811371e-03,  2.62403488e-03,
#         -1.52826309e-03, -3.55720520e-04,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  5.29956818e-03,
#          3.06272507e-03,  1.06668472e-03,  5.42640686e-04,
#          4.11415100e-03,  1.41143799e-04,  6.45685196e-03,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          4.29630280e-03, -4.10079956e-04,  8.00132751e-04,
#          2.36320496e-03,  3.22437286e-03,  3.78990173e-03,
#          1.60884857e-03,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  3.70025635e-04,  6.71672821e-03,
#          2.49862671e-03, -1.68514252e-03,  1.74713135e-03,
#         -1.95026398e-03, -3.81469727e-06,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  2.88009644e-03,
#          2.45761871e-03, -1.92260742e-03, -3.59725952e-03,
#          7.99942017e-03,  3.64875793e-03,  6.84642792e-03,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          4.03213501e-03,  4.73403931e-03, -2.42233276e-04,
#          3.09085846e-03,  1.60980225e-03,  2.47097015e-03,
#          7.00473785e-03,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  1.89781189e-03,  2.88677216e-03,
#          3.59630585e-03, -2.06947327e-04,  2.51960754e-03,
#          2.52056122e-03,  4.17232513e-03,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  4.58908081e-03,
#          7.20024109e-04,  2.44712830e-03, -1.43051147e-05,
#          7.93457031e-04,  1.31511688e-03,  3.12900543e-03,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          4.74452972e-03, -2.38323212e-03,  1.09806061e-02,
#          2.26306915e-03,  7.41577148e-03, -1.17301941e-04,
#         -5.95092773e-03,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -1.72424316e-02, -7.95459747e-03,
#          3.06129456e-04, -2.51302719e-02, -4.41741943e-03,
#         -7.91454315e-03, -3.10297012e-02,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -7.60483742e-02,
#          4.23278809e-02, -1.61247253e-02, -3.08914185e-02,
#          6.46591187e-04, -4.90698814e-02,  2.24266052e-02,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -3.13138962e-02,  5.79533577e-02, -3.02124023e-02,
#         -1.39093399e-02, -2.41708755e-03,  1.04823112e-02,
#         -1.04303360e-02,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  2.31375694e-02, -1.43084526e-02,
#          2.10661888e-02, -6.00337982e-04, -2.35900879e-02,
#          5.30576706e-03,  1.04742050e-02,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  7.70187378e-03,
#          2.02608109e-03,  6.98471069e-03, -6.20603561e-03,
#          1.42436028e-02,  7.24792480e-03,  3.78274918e-03,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          2.84719467e-03, -3.28779221e-03,  1.99804306e-02,
#          2.86102295e-03,  1.74045563e-04,  7.68804550e-03,
#          3.22628021e-03,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  7.82012939e-05, -3.51428986e-03,
#         -3.94344330e-03,  9.91916656e-03, -1.13492012e-02,
#         -4.78124619e-03,  6.20031357e-03,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  1.51314735e-02,
#          5.53989410e-03,  1.33876801e-02,  8.63170624e-03,
#          1.94330215e-02,  1.28555298e-03,  1.50775909e-03,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -3.08609009e-03, -3.14712524e-03,  3.33499908e-03,
#         -2.38418579e-04, -4.94575500e-03, -1.59931183e-03,
#          1.56974792e-03,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  1.25217438e-03, -1.04904175e-04,
#         -2.88963318e-03,  1.98364258e-04,  1.12628937e-03,
#          3.59249115e-03,  4.61959839e-03,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  4.86183167e-03,
#          6.31618500e-03, -8.06999207e-03,  2.67124176e-03,
#          3.79848480e-03,  4.60910797e-03,  8.31985474e-03,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          3.33023071e-03,  3.03363800e-03,  6.32572174e-03,
#          1.56784058e-03,  4.00924683e-03,  1.90544128e-03,
#          6.86359406e-03,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  6.60133362e-03,  6.23703003e-04,
#          5.55992126e-03,  2.58827209e-03,  5.36155701e-03,
#          9.07897949e-04,  5.01632690e-03,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  6.89601898e-03,
#          2.24971771e-03,  4.50325012e-03, -3.75747681e-04,
#          7.86113739e-03,  1.87015533e-03,  3.07083130e-04,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          7.24983215e-03,  1.11293793e-03,  4.52041626e-03,
#          1.03282928e-03, -4.78744507e-03,  2.12383270e-03,
#          2.58636475e-03,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -1.19276047e-02, -5.24234772e-03,
#         -4.66346741e-04, -5.81455231e-03,  1.79862976e-03,
#         -1.33972168e-02, -4.09288406e-02,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -6.38008118e-02,
#         -2.41088867e-02, -9.15050507e-04]], dtype=float32)

# %%
daily_rets_series = pd.DataFrame(daily_log_rets.reshape(449), index=Date[1:450])

# %%
plt.title('Log turn from 2019 to 2021')
plt.plot(daily_rets_series)

# %%
Date
# Out:
# 0      2019-01-02
# 1      2019-01-03
# 2      2019-01-04
# 3      2019-01-07
# 4      2019-01-08
#           ...
# 752    2021-12-27
# 753    2021-12-28
# 754    2021-12-29
# 755    2021-12-30
# 756    2021-12-31
# Name: Date, Length: 757, dtype: object
