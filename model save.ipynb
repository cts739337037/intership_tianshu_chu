# %%
def set_model_encoding_mm():
    model = Sequential()
    #encoding
    model.add(Conv1D(64, kernel_size=2, activation='tanh', padding='same',input_shape=(None, 1)))
    # model.add(BatchNormalization())
    # model.add(Dropout(0.1))
    model.add(Conv1D(32, kernel_size=2,activation='tanh',padding='same'))
    # model.add(BatchNormalization())
    # model.add(Dropout(0.1))
    #Use the normalization preprocessing of the data as mentioned before, so that the input x does not vary too much
    # model.add(AveragePooling1D(2, padding='same'))
    #decoding
    model.add(Conv1D(32, kernel_size=2, activation='tanh', padding='same'))
    # model.add(BatchNormalization())
    # model.add(Dropout(0.1))
    model.add(Conv1D(64, kernel_size=2,activation='tanh',padding='same'))
    # model.add(BatchNormalization())
    # model.add(Dropout(0.1))
    # model.add(UpSampling1D(2))
    
    model.add(Conv1D(1,kernel_size=2,activation='sigmoid', padding='same'))
    model.compile(optimizer='adam' , loss='mse', metrics=['mae'])
    
    return model
modelen_mm = set_model_encoding_mm()
modelen_mm.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_65 (Conv1D)          (None, None, 64)          192
#
#  conv1d_66 (Conv1D)          (None, None, 32)          4128
#
#  conv1d_67 (Conv1D)          (None, None, 32)          2080
#
#  conv1d_68 (Conv1D)          (None, None, 64)          6208
#
#  conv1d_69 (Conv1D)          (None, None, 1)           129
#
# =================================================================
# Total params: 12,737
# Trainable params: 12,737
# Non-trainable params: 0
# _________________________________________________________________

# %%
mm_t = MinMaxScaler()
noise_mm_T=mm_t.fit_transform(GSPC_test)
Y_test_mm_cnn = modelen_mm.predict(noise_mm_T.T)
Y_test_mm_cnn=Y_test_mm_cnn.reshape((len(GSPC_test),1))
pure_mm_cnn = mm_t.inverse_transform(Y_test_mm_cnn)
pure_mm_cnn=pd.DataFrame(pure_mm_cnn,columns=['Close'],index=GSPC_test.index)
plt.figure(figsize=(15,4),dpi=200)
plt.plot(pure_mm_cnn,'r')
plt.plot(GSPC_test)
plt.title('2017-2019 close price')
plt.legend(['denoised', 'original'], loc='upper left')
# Out:
# 1/1 [==============================] - 0s 63ms/step

# %%
def set_model_encoding_mm():
    model = Sequential()
    #encoding
    model.add(Conv1D(64, kernel_size=2, activation='tanh', padding='same',input_shape=(None, 1)))
    # model.add(BatchNormalization())
    # model.add(Dropout(0.1))
    model.add(Conv1D(32, kernel_size=2,activation='tanh',padding='same'))
    # model.add(BatchNormalization())
    # model.add(Dropout(0.1))
    #Use the normalization preprocessing of the data as mentioned before, so that the input x does not vary too much
    # model.add(AveragePooling1D(2, padding='same'))
    #decoding
    model.add(Conv1D(32, kernel_size=2, activation='tanh', padding='same'))
    # model.add(BatchNormalization())
    # model.add(Dropout(0.1))
    model.add(Conv1D(64, kernel_size=2,activation='tanh',padding='same'))
    # model.add(BatchNormalization())
    # model.add(Dropout(0.1))
    # model.add(UpSampling1D(2))
    
    model.add(Conv1D(1,kernel_size=2,activation='sigmoid', padding='same'))
    model.compile(optimizer='adam' , loss='mse', metrics=['mae'])
    
    return model
modelen_mm = set_model_encoding_mm()
modelen_mm.summary()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_70 (Conv1D)          (None, None, 64)          192
#
#  conv1d_71 (Conv1D)          (None, None, 32)          4128
#
#  conv1d_72 (Conv1D)          (None, None, 32)          2080
#
#  conv1d_73 (Conv1D)          (None, None, 64)          4160
#
#  conv1d_74 (Conv1D)          (None, None, 1)           129
#
# =================================================================
# Total params: 10,689
# Trainable params: 10,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
mm_t = MinMaxScaler()
noise_mm_T=mm_t.fit_transform(GSPC_test)
Y_test_mm_cnn = modelen_mm.predict(noise_mm_T.T)
Y_test_mm_cnn=Y_test_mm_cnn.reshape((len(GSPC_test),1))
pure_mm_cnn = mm_t.inverse_transform(Y_test_mm_cnn)
pure_mm_cnn=pd.DataFrame(pure_mm_cnn,columns=['Close'],index=GSPC_test.index)
plt.figure(figsize=(15,4),dpi=200)
plt.plot(pure_mm_cnn,'r')
plt.plot(GSPC_test)
plt.title('2017-2019 close price')
plt.legend(['denoised', 'original'], loc='upper left')
# Out:
# 1/1 [==============================] - 0s 64ms/step

# %%
def set_model_encoding_mm():
    model = Sequential()
    #encoding
    model.add(Conv1D(64, kernel_size=2, activation='tanh', padding='same',input_shape=(None, 1)))
    # model.add(BatchNormalization())
    # model.add(Dropout(0.1))
    model.add(Conv1D(32, kernel_size=2,activation='tanh',padding='same'))
    # model.add(BatchNormalization())
    # model.add(Dropout(0.1))
    #Use the normalization preprocessing of the data as mentioned before, so that the input x does not vary too much
    # model.add(AveragePooling1D(2, padding='same'))
    #decoding
    model.add(Conv1D(32, kernel_size=2, activation='tanh', padding='same'))
    # model.add(BatchNormalization())
    # model.add(Dropout(0.1))
    model.add(Conv1D(64, kernel_size=2,activation='tanh',padding='same'))
    # model.add(BatchNormalization())
    # model.add(Dropout(0.1))
    # model.add(UpSampling1D(2))
    
    model.add(Conv1D(1,kernel_size=2,activation='relu', padding='same'))
    model.compile(optimizer='adam' , loss='mse', metrics=['mae'])
    
    return model
modelen_mm = set_model_encoding_mm()
modelen_mm.summary()
# Out:
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_90 (Conv1D)          (None, None, 64)          192
#
#  conv1d_91 (Conv1D)          (None, None, 32)          4128
#
#  conv1d_92 (Conv1D)          (None, None, 32)          2080
#
#  conv1d_93 (Conv1D)          (None, None, 64)          4160
#
#  conv1d_94 (Conv1D)          (None, None, 1)           129
#
# =================================================================
# Total params: 10,689
# Trainable params: 10,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
def set_model_encoding_mm():
    model = Sequential()
    #encoding
    #model.add(Dense(512, kernel_initializer=initializers.glorot_normal(seed=None),input_shape=(None, 1)))
    model.add(Conv1D(256, kernel_size=2, activation='tanh', padding='same',input_shape=(None, 1)))
    # model.add(Dropout(0.1))
    model.add(Conv1D(64, kernel_size=2,activation='tanh',padding='same'))
    model.add(Conv1D(32, kernel_size=2,activation='tanh',padding='same'))
    model.add(Conv1D(32, kernel_size=2,activation='tanh',padding='same'))
    #model.add(Dropout(0.5))
    #Use the normalization preprocessing of the data as mentioned before, so that the input x does not vary too much
    # model.add(AveragePooling1D(2, padding='same'))
    #decoding
    model.add(Conv1D(64, kernel_size=2, activation='tanh', padding='same'))
    # model.add(Dropout(0.1))
    model.add(Conv1D(256, kernel_size=2,activation='tanh',padding='same'))
    # model.add(Dropout(0.1))
    # model.add(UpSampling1D(2))
    
    model.add(Conv1D(1,kernel_size=2,activation='sigmoid', padding='same'))
    model.compile(optimizer='adam' , loss='mse', metrics=['mae'])
    
    return model
modelen_mm = set_model_encoding_mm()
modelen_mm.summary()
# Out:
# Model: "sequential_53"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_219 (Conv1D)         (None, None, 256)         768
#
#  conv1d_220 (Conv1D)         (None, None, 64)          32832
#
#  conv1d_221 (Conv1D)         (None, None, 32)          4128
#
#  conv1d_222 (Conv1D)         (None, None, 32)          2080
#
#  conv1d_223 (Conv1D)         (None, None, 64)          4160
#
#  conv1d_224 (Conv1D)         (None, None, 256)         33024
#
#  conv1d_225 (Conv1D)         (None, None, 1)           513
#
# =================================================================
# Total params: 77,505
# Trainable params: 77,505
# Non-trainable params: 0
# _________________________________________________________________

# %%
mm_t = MinMaxScaler()
noise_mm_T=mm_t.fit_transform(GSPC_test)
Y_test_mm_cnn = modelen_mm.predict(noise_mm_T.T)
Y_test_mm_cnn=Y_test_mm_cnn.reshape((len(GSPC_test),1))
pure_mm_cnn = mm_t.inverse_transform(Y_test_mm_cnn)
pure_mm_cnn=pd.DataFrame(pure_mm_cnn,columns=['Close'],index=GSPC_test.index)
plt.figure(figsize=(15,4),dpi=200)
plt.plot(pure_mm_cnn,'r')
plt.plot(GSPC_test)
plt.title('2017-2019 close price')
plt.legend(['denoised', 'original'], loc='upper left')
# Out:
# 1/1 [==============================] - 0s 84ms/step

# %%
mm_t = MinMaxScaler()
noise_mm_T=mm_t.fit_transform(GSPC_test)
Y_test_mm_cnn = modelen_mm.predict(noise_mm_T.T)
Y_test_mm_cnn=Y_test_mm_cnn.reshape((len(GSPC_test),1))
pure_mm_cnn = mm_t.inverse_transform(Y_test_mm_cnn)
pure_mm_cnn=pd.DataFrame(pure_mm_cnn,columns=['Close'],index=GSPC_test.index)
plt.figure(figsize=(15,4),dpi=200)
plt.plot(pure_mm_cnn,'r')
plt.plot(GSPC_test)
plt.title('2017-2019 close price')
plt.legend(['denoised', 'original'], loc='upper left')
# Out:
# 1/1 [==============================] - 0s 62ms/step

# %%
def set_model_encoding_mm():
    model = Sequential()
    #encoding
    #model.add(Dense(128, kernel_initializer=initializers.glorot_normal(seed=None),input_shape=(None, 1)))
    model.add(Conv1D(256, kernel_size=2, activation='tanh', padding='same',input_shape=(None, 1)))
    # model.add(Dropout(0.1))
    model.add(Conv1D(64, kernel_size=2,activation='tanh',padding='same'))
    # model.add(Dropout(0.1))
    #Use the normalization preprocessing of the data as mentioned before, so that the input x does not vary too much
    # model.add(AveragePooling1D(2, padding='same'))
    #decoding
    model.add(Conv1D(64, kernel_size=2, activation='tanh', padding='same'))
    # model.add(Dropout(0.1))
    model.add(Conv1D(256, kernel_size=2,activation='tanh',padding='same'))
    # model.add(Dropout(0.1))
    # model.add(UpSampling1D(2))
    
    model.add(Conv1D(1,kernel_size=2,activation='sigmoid', padding='same'))
    model.compile(optimizer='adam' , loss='mse', metrics=['mae'])
    
    return model
modelen_mm = set_model_encoding_mm()
modelen_mm.summary()
# Out:
# Model: "sequential_38"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_150 (Conv1D)         (None, None, 256)         768
#
#  conv1d_151 (Conv1D)         (None, None, 64)          32832
#
#  conv1d_152 (Conv1D)         (None, None, 64)          8256
#
#  conv1d_153 (Conv1D)         (None, None, 256)         33024
#
#  conv1d_154 (Conv1D)         (None, None, 1)           513
#
# =================================================================
# Total params: 75,393
# Trainable params: 75,393
# Non-trainable params: 0
# _________________________________________________________________

# %%
mm_t = MinMaxScaler()
noise_mm_T=mm_t.fit_transform(GSPC_test)
Y_test_mm_cnn = modelen_mm.predict(noise_mm_T.T)
Y_test_mm_cnn=Y_test_mm_cnn.reshape((len(GSPC_test),1))
pure_mm_cnn = mm_t.inverse_transform(Y_test_mm_cnn)
pure_mm_cnn=pd.DataFrame(pure_mm_cnn,columns=['Close'],index=GSPC_test.index)
plt.figure(figsize=(15,4),dpi=200)
plt.plot(pure_mm_cnn,'r')
plt.plot(GSPC_test)
plt.title('2017-2019 close price')
plt.legend(['denoised', 'original'], loc='upper left')
# Out:
# 1/1 [==============================] - 0s 71ms/step

# %%
def set_model_encoding_mm():
    model = Sequential()
    #encoding
    #model.add(Dense(512, kernel_initializer=initializers.glorot_normal(seed=None),input_shape=(None, 1)))
    model.add(Conv1D(128, kernel_size=2, activation='tanh', padding='same',input_shape=(None, 1)))
    # model.add(Dropout(0.1))
    model.add(Conv1D(64, kernel_size=2,activation='tanh',padding='same'))
    # model.add(Conv1D(32, kernel_size=2,activation='tanh',padding='same'))
    # # model.add(Conv1D(16, kernel_size=2,activation='tanh',padding='same'))
    # # model.add(Conv1D(16, kernel_size=2,activation='tanh',padding='same'))
    # model.add(Conv1D(32, kernel_size=2,activation='tanh',padding='same'))
    #model.add(Dropout(0.5))
    #Use the normalization preprocessing of the data as mentioned before, so that the input x does not vary too much
    # model.add(AveragePooling1D(2, padding='same'))
    #decoding
    model.add(Conv1D(64, kernel_size=2, activation='tanh', padding='same'))
    # model.add(Dropout(0.1))
    model.add(Conv1D(128, kernel_size=2,activation='tanh',padding='same'))
    # model.add(Dropout(0.1))
    # model.add(UpSampling1D(2))
    
    model.add(Conv1D(1,kernel_size=2,activation='sigmoid', padding='same'))
    model.compile(optimizer='adam' , loss='mse', metrics=['mae'])
    
    return model
modelen_mm = set_model_encoding_mm()
modelen_mm.summary()
# Out:
# Model: "sequential_59"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_263 (Conv1D)         (None, None, 128)         384
#
#  conv1d_264 (Conv1D)         (None, None, 64)          16448
#
#  conv1d_265 (Conv1D)         (None, None, 64)          8256
#
#  conv1d_266 (Conv1D)         (None, None, 128)         16512
#
#  conv1d_267 (Conv1D)         (None, None, 1)           257
#
# =================================================================
# Total params: 41,857
# Trainable params: 41,857
# Non-trainable params: 0
# _________________________________________________________________

# %%
mm_t = MinMaxScaler()
noise_mm_T=mm_t.fit_transform(GSPC_test)
Y_test_mm_cnn = modelen_mm.predict(noise_mm_T.T)
Y_test_mm_cnn=Y_test_mm_cnn.reshape((len(GSPC_test),1))
pure_mm_cnn = mm_t.inverse_transform(Y_test_mm_cnn)
pure_mm_cnn=pd.DataFrame(pure_mm_cnn,columns=['Close'],index=GSPC_test.index)
plt.figure(figsize=(15,4),dpi=200)
plt.plot(pure_mm_cnn,'r')
plt.plot(GSPC_test)
plt.title('2017-2019 close price')
plt.legend(['denoised', 'original'], loc='upper left')
# Out:
# 1/1 [==============================] - 0s 72ms/step

# %%
original_svmb,denoised_svmb=svmf1(bit_test_n,pure_mm_cnnb)

# %%
plt.figure(figsize=(20,6))
max_t=0
if bit_test_n['log_ret'].max()>pure_mm_cnnb['log_ret'].max():
    max_t=bit_test_n['log_ret'].max()
else:
    max_t=pure_mm_cnnb['log_ret'].max()
plt.plot(np.arange(0.0, 0.5*max_t,  0.5*max_t/50),original_svmb,label='orignal_svm', color='red', linewidth=2.0)
plt.plot(np.arange(0.0, 0.5*max_t,  0.5*max_t/50),denoised_svmb,label='denoised_svm', color='blue', linewidth=4.0, linestyle='--')

plt.xticks(np.arange(0.0,0.5*max_t, 0.5*max_t/6))
plt.xlabel('threshold')
plt.ylabel('f1_value')
plt.legend()
